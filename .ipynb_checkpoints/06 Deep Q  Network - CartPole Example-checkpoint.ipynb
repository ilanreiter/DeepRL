# %% [markdown]
# # Deep Q-Networks
#
# In this chapter, we'll try to apply the same theory to problems of much greater complexity: arcade games from the Atari 2600 platform, which are the de-facto benchmark of the RL research community. To deal with this new and more challenging goal, we'll talk about problems with the Value iteration method and introduce its variation, called Q-learning. In particular, we'll look at the application of Q-learning to so-called "grid world" environments, which is called tabular Q-learning, and then we'll discuss Q-learning in conjunction with neural networks. This combination has the name DQN. At the end of the chapter, we'll reimplement a DQN algorithm from the famous paper, Playing Atari with Deep Reinforcement Learning by V. Mnih and others, published in 2013, which started a new era in RL development.

# %% [markdown]
# ## Deep Q-learning
#
# For enviroment with continues states, we can use **a nonlinear representation that maps both state and action onto a value**. In machine learning this is called a **"regression problem"**. The concrete way to represent and train such a representation can vary, but, as you may have already guessed from this section's title, using a deep neural network is one of the most popular options, especially when dealing with observations represented as screen images. With this in mind, let's make modifications to the Q-learning algorithm:
# We do a modifcation to the Tabluar Q-Learninng Algorithem above to accomudate very large state,action space and to use DNN:
#
# 1. Initialize $Q(s, a)$ with some initial approximation
# 2. By interacting with the environment, obtain the tuple $(s, a, r, s′)$
# 3. Calculate loss: $L =(Q_{s,a} − r)^2$ if episode has ended or $L =(Q_{s,a} − (r + \gamma \max_{a' \in A} Q_{s',a'}))^2$ otherwise
# 4. Update $Q(s, a)$ using the stochastic gradient descent (SGD) algorithm, by minimizing the loss with respect to the model parameters
# 5. Repeat from step 2 until converged
#
# ### Interaction with the environment
#
# First of all, we need to interact with the environment somehow to receive data to train on. In simple environments, such as FrozenLake, we can act randomly, but is this the best strategy to use? Imagine the game of Pong. What's the probability of winning a single point by randomly moving the paddle? It's not zero but it's extremely small, which just means that we'll need to wait for a very long time for such a rare situation. As an alternative, we can use our Q function approximation as a source of behavior (as we did before in the value iteration method, when we remembered our experience during testing).
#
# If our representation of Q is good, then the experience that we get from the environment will show the agent relevant data to train on. However, we're in trouble when our approximation is not perfect (at the beginning of the training, for example). In such a case, our agent can be stuck with bad actions for some states without ever trying to behave differently. This **exploration versus exploitation dilemma** was mentioned briefly in Chapter 1, What is Reinforcement Learning?. On the one hand, our agent needs to explore the environment to build a complete picture of transitions and action outcomes. On the other hand, we should use interaction with the environment efficiently: we shouldn't waste time by randomly trying actions we've already tried and have learned their outcomes. As you can see, random behavior is better at the beginning of the training when our Q approximation is bad, as it gives us more uniformly distributed information about the environment states. As our training progresses, random behavior becomes inefficient and we want to fall back to our Q approximation to decide how to act.
#
# A method which performs such a mix of two extreme behaviors is known as an **epsilon-greedy method**, which just means switching between random and $Q$ policy using the probability hyperparameter $\epsilon$. By varying $\epsilon$ we can select the ratio of random actions. The usual practice is to start with $\epsilon = 1.0$ (100% random actions) and slowly decrease it to some small value such as 5% or 2% of random actions. Using an epsilon-greedy method helps both to explore the environment in the beginning and to stick to good policy at the end of the training. There are other solutions to the **"exploration versus exploitation"** problem, and we'll discuss some of them in part three of the book. This problem is **one of the fundamental open questions in RL and an active area of research, which is not even close to being resolved completely**.
#
# ### SGD optimization
# The core of our Q-learning procedure is borrowed from the supervised learning. Indeed, we are trying to approximate a complex, nonlinear function $Q(s, a)$ with a neural network. To do this, we calculate targets for this function using the Bellman equation and then pretend that we have a supervised learning problem at hand. That's okay, but one of the fundamental requirements for SGD optimization is that the training data is **independent and identically distributed (i.i.d)**.
#
# In our case, data that we're going to use for the SGD update doesn't fulfill these criteria:
# 1. Our samples are not independent. Even if we accumulate a large batch of data samples, they all will be very close to each other, as they belong to the same episode.
# 2. Distribution of our training data won't be identical to samples provided by the optimal policy that we want to learn. Data that we have is a result of some other policy (our current policy, random, or both in the case of $\epsilon$-greedy), but we don't want to learn how to play randomly: we want an optimal policy with the best reward.
#
# To deal with this nuisance, we usually need to use a **large buffer of our past experience and sample training data from it, instead of using our latest experience**. This method is called **replay buffer**. The simplest implementation is a buffer of **fixed size**, with new data added to the end of the buffer so that it pushes the oldest experience out of it.
#
# **Replay buffer** allows us to train on more-or-less independent data, but data will still be fresh enough to train on samples generated by our recent policy.
#
# ### Correlation between steps
# Another practical issue with the default training procedure is also related to the lack of
# i.i.d in our data, but in a slightly different manner. The Bellman equation provides us with the value of $Q(s, a)$ via $Q(s′, a′)$ (which has the name of **bootstrapping**). However, both states $s$ and $s′$ have only one step between them. This makes them very similar and it's really hard for neural networks to distinguish between them. When we perform an update of our network's parameters, to make $Q(s, a)$ closer to the desired result, we indirectly can alter the value produced for $Q(s′, a′)$ and other states nearby. This can make our training really unstable, like chasing our own tail: when we update $Q$ for state $s$, then on subsequent states we discover that $Q(s′, a′)$ becomes worse, but attempts to update it can spoil our $Q(s, a)$ approximation, and so on.
#
# To make training more stable, there is a **trick, called target network**, when we keep a copy of our network and use it for the $Q(s′, a′)$ value in the Bellman equation. This network is synchronized with our main network only periodically, for example, once in $N$ steps (where $N$ is usually quite a large hyperparameter, such as 1k or 10k training iterations).
#
# ### The Markov property
# Our RL methods use MDP formalism as their basis, which **assumes that the environment obeys the Markov property**: observation from the environment is all that we need to act optimally (in other words, our observations allow us to distinguish states from one another). As we've seen on the preceding Pong's screenshot, one single image from the Atari game is not enough to capture all important information (using only one image we have no idea about the speed and direction of objects, like the ball and our opponent's paddle). This obviously violates the Markov property and moves our single-frame Pong environment into the area of **partially observable MDPs (POMDP)**. A POMDP is basically MDP without the Markov property and they are very important in practice. For example, for most card games where you don't see your opponents' cards, game observations are POMDPs, because current observation (your cards and cards on the table) could correspond to different cards in your opponents' hands.
# We'll not discuss POMPDs in detail in this book, so, for now, we'll use a small technique to push our environment back into the MDP domain. **The solution is maintaining several observations from the past and using them as a state**. In the case of Atari games, we usually stack $k$ subsequent frames together and use them as the observation at every state. This **allows our agent to deduct the dynamics of the current state**, for instance, to get the speed of the ball and its direction. The usual "classical" **number of $k$ for Atari is four**. Of course, it's just a hack, as there can be longer dependencies in the environment, but for most of the games it works well.
#
# ## The final form of DQN (Deep Q-Learning) training
# There are many more tips and tricks that researchers have discovered to make **DQN** training more stable and efficient, and we'll cover the best of them in the next chapter. However, **$\epsilon$-greedy**, **replay buffer**, and **target network** form the basis that allows DeepMind to successfully train a DQN on a set of 49 Atari games and demonstrate the efficiency of this approach applied to complicated environments.
#
# The original paper (without target network) was published at the end of 2013 ([Playing Atari with Deep Reinforcement Learning 1312.5602v1, Mnih and others.)](https://arxiv.org/pdf/1312.5602.pdf), and they used seven games for testing. Later, at the beginning of 2015, a revised version of the article, with 49 different games, was published in Nature ([Human-Level Control Through Deep Reinforcement Learning doi:10.1038/nature14236, Mnih and others.](https://www.nature.com/articles/nature14236))
#
# The algorithm for DQN from the preceding papers has the following steps:
# 1. Initialize parameters for $Q(s, a)$ and $\hat Q (s, a)$ with random weights, **$\epsilon\leftarrow 1.0$**, and **empty replay buffer**
# 2. With probability $\epsilon$, select a random action $a$, otherwise $a = \arg \max_a Q_{s,a}$
# 3. Execute action $a$ in an **emulator** and observe reward $r$ and the next state $s′$
# 4. Store transition $(s, a, r, s′)$ in the **replay buffer**
# 5. Sample a random **minibatch** of transitions from the **replay buffer**
# 6. For every transition in the buffer, calculate target $y = r$ if the episode has ended at this step or $y = r + \gamma \max_{a' \in A} \hat Q_{s',a'}$ otherwise
# 7. Calculate loss: $L = (Q_{s,a} − y)^2$
# 8. Update $Q(s, a)$ using the **SGD algorithm** by minimizing the loss in respect to model parameters
# 9. Every $N$ steps copy weights from $Q$ to $\hat Q_t$
# 10. Repeat from step 2 until converged
#
#
# ## DQN on FrozenLake
# ### DQN Model

# %%
import torch
import torch.nn as nn

import numpy as np



#Class for setting the Deep Q-Learning Network
#For the FrozenLake game the w use as simple fully connected single hidden layer dnn
class DQN(nn.Module):
    #Method to intialize the DNN
    def __init__(self, obs_size, hidden_size, output_size):
        super(DQN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, output_size)
        )

    #method to perform a single forward operation
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ### DQN  Training on FrozenLake

# %%
#!/usr/bin/env python3

import gym

import argparse
import time
import numpy as np
import collections

import torch
import torch.nn as nn
import torch.optim as optim

from tensorboardX import SummaryWriter


#DEFAULT_ENV_NAME = "PongNoFrameskip-v4"
DEFAULT_ENV_NAME = "CartPole-v0"
#DEFAULT_ENV_NAME = "FrozenLake8x8-v0"

LEARNING_RATE = 1e-3 #1e-4

MEAN_REWARD_BOUND = 19.5

GAMMA = 0.99 #0.99 #reward discount
BATCH_SIZE = 32 #32
REPLAY_SIZE = 10000 #10000
REPLAY_START_SIZE = 10000 #10000
SYNC_TARGET_FRAMES = 1000 #1000

HIDDEN_SIZE = 128 #Hidden layer size

#Epsilon control parameters - to control explore/exploite decision
EPSILON_DECAY_LAST_FRAME = 10**5 #10**5
EPSILON_START = .99
EPSILON_FINAL = 0.05


#Create a name tuppled object
Experience = collections.namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])

#A class for replay buffer
class ExperienceBuffer:
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience):
        self.buffer.append(experience)
        self

    def sample(self, batch_size): #Method to append results from a mini batch of a given batch_size
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])
        return np.array(states), np.array(actions), np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), np.array(next_states)

#Ineriting class from Gym's ObservationWraper class
#It converts the descrite inputs will have 16 float numbers, zero everywhere, except the currenl loction of the agent (as float 1)
class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
#         assert isinstance(env.observation_space, gym.spaces.Discrete)
#         self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        res = np.array(observation)
        return res


#The Agent class
class Agent:
    def __init__(self, env, exp_buffer): #method to intialize the Agent
        self.env = env
        self.exp_buffer = exp_buffer #Init the experience buffer
        self._reset()
        
    def _reset(self): #method to reset the agent
        self.state = env.reset()
        self.total_reward = 0.0
        
    def best_action(self, net):
        #state_a = np.array([self.state], copy=False) #Convert the state to np array
        #state_v = torch.tensor(state_a).to(device) 
        state_v = torch.FloatTensor([self.state]).to(device) 
        
        #print(state_v)
        #get the best action for the current state
        q_vals_v = net(state_v) # sm(net(state_v))
        _, act_v = torch.max(q_vals_v, dim=1)
        action = int(act_v.item())
        return action


    def play_step(self, net, epsilon=0.0, device = 'cpu'): #A method to play a single step
        done_reward = None
        #make an explore/exploit decision
        if np.random.random() < epsilon: #Explor: sampling from a unfied and check if result is below epsilon
            action = self.env.action_space.sample() # sample a random action from the environment 
        else: #Exploit: pick an action by scoring the nn
            action = self.best_action(net)
        # Make a step in the environment
        new_state, reward, is_done, _ = self.env.step(action) #perfrom a step on the agent's environment with the selected action
        self.total_reward += reward #increment the total reward with the new reward received
        #print('reward=', reward)
        #new_state = new_state #Seems redundant...

        exp = Experience(self.state, action, reward, is_done, new_state) #Create a new experiance entry
        self.exp_buffer.append(exp) #append the experiance entry
        self.state = new_state 
        if is_done:
            done_reward = self.total_reward
            self._reset()
        return done_reward
    
    def play_episode(self, net):
        self._reset() #reset the environment
        steps = 0
        reward = None
        while reward is None:
            reward = self.play_step(net, epsilon=0.0)#mae a step in the env with the best action
            steps += 1
        return reward, steps


#Calculate loos on a given mini-batch for net and tgt_net
def calc_loss(batch, net, tgt_net, device="cpu"):
    states, actions, rewards, dones, next_states = batch
    
    #Create tensors for states, next_states, actions, rewards and done flags
    states_v = torch.FloatTensor(states) .to(device)
    #print('states_v.shape=',states_v.shape,' states_v=', states_v)
    
    next_states_v = torch.FloatTensor(next_states).to(device)
    #print('next_states_v.shape=',next_states_v.shape,' next_states_v=', next_states_v)
    actions_v = torch.tensor(actions) .to(device)
    rewards_v = torch.tensor(rewards) .to(device)
    done_mask = torch.ByteTensor(dones) .to(device)

    #state_action_values = sm(net(states_v)).gather(1, actions_v.unsqueeze(-1)).squeeze(-1) # Applying the net on sates as input and then extract the Q-values based on the action taken
    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1) # Applying the net on sates as input and then extract the Q-values based on the action taken
    #print('net(states_v)', net(states_v), 'actions_v=', actions_v, 'actions_v.unsqueeze(-1)=', actions_v.unsqueeze(-1),
    #      'net(states_v).gather(1, actions_v.unsqueeze(-1))=', net(states_v).gather(1, actions_v.unsqueeze(-1)),
    #      'net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)=', net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1))
    
    #next_state_values = sm(tgt_net(next_states_v)).max(1)[0] #apply the target network to our next state observations and calculate the maximum Q-value along the same action dimension 1. Function max() returns both maximum values and indices of those values (so it calculates both max and argmax), which is very convenient. However, in this case, we're interested only in values, so we take the first entry of the result.
    next_state_values = tgt_net(next_states_v).max(1)[0] #apply the target network to our next state observations and calculate the maximum Q-value along the same action dimension 1. Function max() returns both maximum values and indices of those values (so it calculates both max and argmax), which is very convenient. However, in this case, we're interested only in values, so we take the first entry of the result.
    next_state_values[done_mask] = 0.0 #Zero next state value in case current state is the last 1
    next_state_values = next_state_values.detach() #detach the value from its computation graph to prevent gradients from flowing into the neural network
    expected_state_action_values = next_state_values * GAMMA + rewards_v #Calculating the expected state action values based on Bellman equation 
    #print('next_state_values:', next_state_values, 'expected_state_action_values:', expected_state_action_values)
    
    
    loss = nn.MSELoss()(state_action_values, expected_state_action_values) #calculate the loss and return it
    #print('loss:', loss)
    #print('====================================================================')

    return loss


if __name__ == "__main__":
#  Setup for GPU
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--cuda", default=False, action="store_true", help="Enable cuda")
#     parser.add_argument("--env", default=DEFAULT_ENV_NAME,
#                         help="Name of the environment, default=" + DEFAULT_ENV_NAME)
#     parser.add_argument("--reward", type=float, default=MEAN_REWARD_BOUND,
#                         help="Mean reward boundary for stop of training, default=%.2f" % MEAN_REWARD_BOUND)
#     args = parser.parse_args()
#     device = torch.device("cuda" if args.cuda else "cpu")

#     env = wrappers.make_env(args.env)
    device = 'cpu'

#    env = wrappers.make_env(args.env)

#    env = DiscreteOneHotWrapper(gym.make(DEFAULT_ENV_NAME)) #creating a new environment 
    env = DiscreteOneHotWrapper(gym.make(DEFAULT_ENV_NAME)) #creating a new environment 
    
#    env = gym.make("CartPole-v0") #using CartPole as environment
    
    obs_size = env.observation_space.shape[0] #4 in the case of CartPole
    n_actions = env.action_space.n  # 2 actions (left, right) in the case of CartPole

    net = DQN(obs_size, HIDDEN_SIZE, n_actions) .to(device)
    tgt_net = DQN(obs_size, HIDDEN_SIZE, n_actions).to(device)

    writer = SummaryWriter(comment="-") #(comment="-" + args.env)
    print(net)

    exp_buffer = ExperienceBuffer(REPLAY_SIZE)
    agent = Agent(env, buffer) #Creating a new instance of an agent
    epsilon = EPSILON_START #Init the greed factor - higer value means more explor and less exploit

    optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
    total_rewards = []
    iter_idx = 0
    ts_frame = 0
    ts = time.time()
    best_mean_reward = None
    
    #sm = nn.Softmax(dim=1) #creating a softmax function 
    prev_idx = 0
    prev_games = 0

    while True:
        iter_idx += 1
        epsilon = max(EPSILON_FINAL, EPSILON_START - iter_idx / EPSILON_DECAY_LAST_FRAME) #Update epslion (greed factor) by reducing it baed on the iter  

        reward = agent.play_step(net, epsilon, device=device)

        if reward is not None:
            total_rewards.append(reward)
            speed = (iter_idx - ts_frame) / (time.time() - ts)
            ts_frame = iter_idx
            ts = time.time()
            mean_reward = np.mean(total_rewards[-100:])/200
            writer.add_scalar("epsilon", epsilon, iter_idx)
            writer.add_scalar("speed", speed, iter_idx)
            writer.add_scalar("reward_100", mean_reward, iter_idx)
            writer.add_scalar("reward", reward, iter_idx)
            if best_mean_reward is None or best_mean_reward < mean_reward:
                #torch.save(net.state_dict(), "-best.dat") #Save (serialize the model parameters) - not sure why needed
                #print('net state_dict saved >>>>>>')
                if best_mean_reward is not None:
                    print("total_iter=%d, delta_iteration=%d, games=%d, mean reward=%.3f, eps=%.2f" 
                          % (iter_idx, iter_idx - prev_idx, len(total_rewards) - prev_games, mean_reward, epsilon))
                best_mean_reward = mean_reward
                prev_idx = iter_idx
                prev_games = len(total_rewards)

            if mean_reward >= 1: # args.reward:
                #print("Solved in %d frames!" % iter_idx)
                break

        if len(exp_buffer) < REPLAY_START_SIZE:
            continue

        if iter_idx % SYNC_TARGET_FRAMES == 0:
            tgt_net.load_state_dict(net.state_dict()) #sync the net model parameters to the target net
            #print('total_iter=', iter_idx, 'mean_reward=', mean_reward, ' best_mean_reward=', best_mean_reward)
            #print('net state_dict loaded <<<<<')


        optimizer.zero_grad()
        batch = exp_buffer.sample(BATCH_SIZE) #sample from the experiance buffer 
        loss_t = calc_loss(batch, net, tgt_net, device=device)
        #print('loss=',loss_t.abs())
        loss_t.backward()
        optimizer.step()
        
    writer.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# DQN(
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# total_iter=104, delta_iteration=85, games=3, mean reward=0.130, eps=0.99
# total_iter=14805, delta_iteration=14701, games=695, mean reward=0.132, eps=0.84
# total_iter=14846, delta_iteration=41, games=1, mean reward=0.133, eps=0.84
# total_iter=15869, delta_iteration=1023, games=41, mean reward=0.133, eps=0.83
# total_iter=16102, delta_iteration=233, games=9, mean reward=0.134, eps=0.83
# total_iter=16412, delta_iteration=310, games=10, mean reward=0.134, eps=0.83
# total_iter=16432, delta_iteration=20, games=1, mean reward=0.134, eps=0.83
# total_iter=16489, delta_iteration=57, games=1, mean reward=0.136, eps=0.83
# total_iter=16559, delta_iteration=70, games=2, mean reward=0.137, eps=0.82
# total_iter=16606, delta_iteration=47, games=1, mean reward=0.139, eps=0.82
# total_iter=16715, delta_iteration=109, games=5, mean reward=0.139, eps=0.82
# total_iter=16771, delta_iteration=56, games=1, mean reward=0.140, eps=0.82
# total_iter=16803, delta_iteration=32, games=1, mean reward=0.141, eps=0.82
# total_iter=16899, delta_iteration=96, games=2, mean reward=0.143, eps=0.82
# total_iter=16975, delta_iteration=76, games=1, mean reward=0.145, eps=0.82
# total_iter=17073, delta_iteration=98, games=3, mean reward=0.146, eps=0.82
# total_iter=17492, delta_iteration=419, games=14, mean reward=0.147, eps=0.82
# total_iter=17551, delta_iteration=59, games=2, mean reward=0.148, eps=0.81
# total_iter=17951, delta_iteration=400, games=13, mean reward=0.150, eps=0.81
# total_iter=17973, delta_iteration=22, games=1, mean reward=0.150, eps=0.81
# total_iter=18017, delta_iteration=44, games=1, mean reward=0.152, eps=0.81
# total_iter=18185, delta_iteration=168, games=5, mean reward=0.152, eps=0.81
# total_iter=18229, delta_iteration=44, games=2, mean reward=0.153, eps=0.81
# total_iter=18366, delta_iteration=137, games=5, mean reward=0.155, eps=0.81
# total_iter=18470, delta_iteration=104, games=1, mean reward=0.159, eps=0.81
# total_iter=18570, delta_iteration=100, games=3, mean reward=0.159, eps=0.80
# total_iter=18617, delta_iteration=47, games=2, mean reward=0.160, eps=0.80
# total_iter=18643, delta_iteration=26, games=1, mean reward=0.160, eps=0.80
# total_iter=18682, delta_iteration=39, games=1, mean reward=0.161, eps=0.80
# total_iter=19061, delta_iteration=379, games=11, mean reward=0.163, eps=0.80
# total_iter=19392, delta_iteration=331, games=12, mean reward=0.163, eps=0.80
# total_iter=19442, delta_iteration=50, games=1, mean reward=0.164, eps=0.80
# total_iter=19479, delta_iteration=37, games=1, mean reward=0.165, eps=0.80
# total_iter=19569, delta_iteration=90, games=1, mean reward=0.169, eps=0.79
# total_iter=19591, delta_iteration=22, games=1, mean reward=0.169, eps=0.79
# total_iter=21693, delta_iteration=2102, games=64, mean reward=0.169, eps=0.77
# total_iter=23476, delta_iteration=1783, games=52, mean reward=0.171, eps=0.76
# total_iter=23616, delta_iteration=140, games=3, mean reward=0.171, eps=0.75
# total_iter=24137, delta_iteration=521, games=15, mean reward=0.174, eps=0.75
# total_iter=24222, delta_iteration=85, games=3, mean reward=0.174, eps=0.75
# total_iter=24262, delta_iteration=40, games=1, mean reward=0.176, eps=0.75
# total_iter=24441, delta_iteration=179, games=4, mean reward=0.178, eps=0.75
# total_iter=24654, delta_iteration=213, games=6, mean reward=0.178, eps=0.74
# total_iter=24804, delta_iteration=150, games=3, mean reward=0.179, eps=0.74
# total_iter=24821, delta_iteration=17, games=1, mean reward=0.180, eps=0.74
# total_iter=24903, delta_iteration=82, games=2, mean reward=0.181, eps=0.74
# total_iter=24953, delta_iteration=50, games=1, mean reward=0.182, eps=0.74
# total_iter=25331, delta_iteration=378, games=6, mean reward=0.187, eps=0.74
# total_iter=25392, delta_iteration=61, games=1, mean reward=0.188, eps=0.74
# total_iter=25479, delta_iteration=87, games=1, mean reward=0.191, eps=0.74
# total_iter=25591, delta_iteration=112, games=1, mean reward=0.195, eps=0.73
# total_iter=25698, delta_iteration=107, games=3, mean reward=0.196, eps=0.73
# total_iter=25721, delta_iteration=23, games=1, mean reward=0.196, eps=0.73
# total_iter=25858, delta_iteration=137, games=1, mean reward=0.202, eps=0.73
# total_iter=25904, delta_iteration=46, games=1, mean reward=0.202, eps=0.73
# total_iter=26130, delta_iteration=226, games=5, mean reward=0.205, eps=0.73
# total_iter=26567, delta_iteration=437, games=9, mean reward=0.212, eps=0.72
# total_iter=26662, delta_iteration=95, games=2, mean reward=0.213, eps=0.72
# total_iter=26696, delta_iteration=34, games=1, mean reward=0.214, eps=0.72
# total_iter=26807, delta_iteration=111, games=2, mean reward=0.217, eps=0.72
# total_iter=26890, delta_iteration=83, games=1, mean reward=0.220, eps=0.72
# total_iter=27039, delta_iteration=149, games=4, mean reward=0.221, eps=0.72
# total_iter=27084, delta_iteration=45, games=1, mean reward=0.221, eps=0.72
# total_iter=27277, delta_iteration=193, games=3, mean reward=0.225, eps=0.72
# total_iter=27460, delta_iteration=183, games=4, mean reward=0.227, eps=0.72
# total_iter=27575, delta_iteration=115, games=1, mean reward=0.231, eps=0.71
# total_iter=28397, delta_iteration=822, games=22, mean reward=0.232, eps=0.71
# total_iter=28439, delta_iteration=42, games=1, mean reward=0.233, eps=0.71
# total_iter=29081, delta_iteration=642, games=15, mean reward=0.235, eps=0.70
# total_iter=29272, delta_iteration=191, games=4, mean reward=0.237, eps=0.70
# total_iter=29446, delta_iteration=174, games=5, mean reward=0.238, eps=0.70
# total_iter=29895, delta_iteration=449, games=9, mean reward=0.240, eps=0.69
# total_iter=34160, delta_iteration=4265, games=88, mean reward=0.241, eps=0.65
# total_iter=34236, delta_iteration=76, games=1, mean reward=0.244, eps=0.65
# total_iter=34288, delta_iteration=52, games=1, mean reward=0.245, eps=0.65
# total_iter=34371, delta_iteration=83, games=2, mean reward=0.246, eps=0.65
# total_iter=34497, delta_iteration=126, games=1, mean reward=0.250, eps=0.65
# total_iter=34622, delta_iteration=125, games=1, mean reward=0.255, eps=0.64
# total_iter=34854, delta_iteration=232, games=2, mean reward=0.260, eps=0.64
# total_iter=34899, delta_iteration=45, games=1, mean reward=0.261, eps=0.64
# total_iter=34986, delta_iteration=87, games=1, mean reward=0.263, eps=0.64
# total_iter=35062, delta_iteration=76, games=1, mean reward=0.265, eps=0.64
# total_iter=35276, delta_iteration=214, games=4, mean reward=0.265, eps=0.64
# total_iter=35569, delta_iteration=293, games=4, mean reward=0.273, eps=0.63
# total_iter=35608, delta_iteration=39, games=1, mean reward=0.273, eps=0.63
# total_iter=35802, delta_iteration=194, games=4, mean reward=0.273, eps=0.63
# total_iter=35864, delta_iteration=62, games=1, mean reward=0.275, eps=0.63
# total_iter=35909, delta_iteration=45, games=1, mean reward=0.276, eps=0.63
# total_iter=36048, delta_iteration=139, games=1, mean reward=0.280, eps=0.63
# total_iter=36492, delta_iteration=444, games=8, mean reward=0.280, eps=0.63
# total_iter=36513, delta_iteration=21, games=1, mean reward=0.280, eps=0.62
# total_iter=36534, delta_iteration=21, games=1, mean reward=0.281, eps=0.62
# total_iter=36704, delta_iteration=170, games=1, mean reward=0.288, eps=0.62
# total_iter=36772, delta_iteration=68, games=2, mean reward=0.289, eps=0.62
# total_iter=36826, delta_iteration=54, games=1, mean reward=0.290, eps=0.62
# total_iter=36904, delta_iteration=78, games=1, mean reward=0.293, eps=0.62
# total_iter=36948, delta_iteration=44, games=1, mean reward=0.294, eps=0.62
# total_iter=37167, delta_iteration=219, games=4, mean reward=0.294, eps=0.62
# total_iter=37365, delta_iteration=198, games=2, mean reward=0.300, eps=0.62
# total_iter=37425, delta_iteration=60, games=1, mean reward=0.301, eps=0.62
# total_iter=37475, delta_iteration=50, games=1, mean reward=0.301, eps=0.62
# total_iter=38314, delta_iteration=839, games=13, mean reward=0.306, eps=0.61
# total_iter=38327, delta_iteration=13, games=1, mean reward=0.306, eps=0.61
# total_iter=38461, delta_iteration=134, games=1, mean reward=0.310, eps=0.61
# total_iter=38664, delta_iteration=203, games=3, mean reward=0.311, eps=0.60
# total_iter=38728, delta_iteration=64, games=1, mean reward=0.313, eps=0.60
# total_iter=38859, delta_iteration=131, games=3, mean reward=0.315, eps=0.60
# total_iter=39059, delta_iteration=200, games=1, mean reward=0.324, eps=0.60
# total_iter=39167, delta_iteration=108, games=1, mean reward=0.328, eps=0.60
# total_iter=39250, delta_iteration=83, games=1, mean reward=0.331, eps=0.60
# total_iter=39357, delta_iteration=107, games=1, mean reward=0.333, eps=0.60
# total_iter=39472, delta_iteration=115, games=2, mean reward=0.334, eps=0.60
# total_iter=39666, delta_iteration=194, games=3, mean reward=0.338, eps=0.59
# total_iter=39802, delta_iteration=136, games=2, mean reward=0.339, eps=0.59
# total_iter=40002, delta_iteration=200, games=1, mean reward=0.346, eps=0.59
# total_iter=40159, delta_iteration=157, games=1, mean reward=0.349, eps=0.59
# total_iter=40348, delta_iteration=189, games=1, mean reward=0.353, eps=0.59
# total_iter=40461, delta_iteration=113, games=1, mean reward=0.358, eps=0.59
# total_iter=41168, delta_iteration=707, games=10, mean reward=0.362, eps=0.58
# total_iter=41281, delta_iteration=113, games=1, mean reward=0.363, eps=0.58
# total_iter=41456, delta_iteration=175, games=1, mean reward=0.365, eps=0.58
# total_iter=41664, delta_iteration=208, games=2, mean reward=0.369, eps=0.57
# total_iter=41720, delta_iteration=56, games=1, mean reward=0.370, eps=0.57
# total_iter=41772, delta_iteration=52, games=1, mean reward=0.370, eps=0.57
# total_iter=42859, delta_iteration=1087, games=14, mean reward=0.375, eps=0.56
# total_iter=43595, delta_iteration=736, games=11, mean reward=0.375, eps=0.55
# total_iter=43712, delta_iteration=117, games=1, mean reward=0.377, eps=0.55
# total_iter=43847, delta_iteration=135, games=1, mean reward=0.378, eps=0.55
# total_iter=43986, delta_iteration=139, games=1, mean reward=0.384, eps=0.55
# total_iter=44043, delta_iteration=57, games=1, mean reward=0.386, eps=0.55
# total_iter=44218, delta_iteration=175, games=1, mean reward=0.393, eps=0.55
# total_iter=44413, delta_iteration=195, games=3, mean reward=0.394, eps=0.55
# total_iter=44613, delta_iteration=200, games=1, mean reward=0.395, eps=0.54
# total_iter=44677, delta_iteration=64, games=1, mean reward=0.398, eps=0.54
# total_iter=44777, delta_iteration=100, games=1, mean reward=0.400, eps=0.54
# total_iter=44879, delta_iteration=102, games=1, mean reward=0.403, eps=0.54
# total_iter=44984, delta_iteration=105, games=1, mean reward=0.404, eps=0.54
# total_iter=45132, delta_iteration=148, games=1, mean reward=0.409, eps=0.54
# total_iter=45332, delta_iteration=200, games=1, mean reward=0.417, eps=0.54
# total_iter=45391, delta_iteration=59, games=1, mean reward=0.418, eps=0.54
# total_iter=45591, delta_iteration=200, games=1, mean reward=0.423, eps=0.53
# total_iter=45693, delta_iteration=102, games=1, mean reward=0.426, eps=0.53
# total_iter=45812, delta_iteration=119, games=1, mean reward=0.431, eps=0.53
# total_iter=46222, delta_iteration=410, games=4, mean reward=0.435, eps=0.53
# total_iter=46422, delta_iteration=200, games=1, mean reward=0.443, eps=0.53
# total_iter=46515, delta_iteration=93, games=1, mean reward=0.447, eps=0.52
# total_iter=46697, delta_iteration=182, games=2, mean reward=0.451, eps=0.52
# total_iter=46831, delta_iteration=134, games=1, mean reward=0.456, eps=0.52
# total_iter=46909, delta_iteration=78, games=1, mean reward=0.458, eps=0.52
# total_iter=47109, delta_iteration=200, games=1, mean reward=0.465, eps=0.52
# total_iter=47157, delta_iteration=48, games=1, mean reward=0.466, eps=0.52
# total_iter=47357, delta_iteration=200, games=1, mean reward=0.470, eps=0.52
# total_iter=47485, delta_iteration=128, games=1, mean reward=0.472, eps=0.52
# total_iter=47685, delta_iteration=200, games=1, mean reward=0.478, eps=0.51
# total_iter=48065, delta_iteration=380, games=2, mean reward=0.487, eps=0.51
# total_iter=48210, delta_iteration=145, games=1, mean reward=0.487, eps=0.51
# total_iter=48630, delta_iteration=420, games=6, mean reward=0.493, eps=0.50
# total_iter=48801, delta_iteration=171, games=1, mean reward=0.497, eps=0.50
# total_iter=49474, delta_iteration=673, games=8, mean reward=0.499, eps=0.50
# total_iter=51037, delta_iteration=1563, games=16, mean reward=0.499, eps=0.48
# total_iter=51275, delta_iteration=238, games=2, mean reward=0.500, eps=0.48
# total_iter=51640, delta_iteration=365, games=2, mean reward=0.506, eps=0.47
# total_iter=51795, delta_iteration=155, games=1, mean reward=0.507, eps=0.47
# total_iter=52048, delta_iteration=253, games=2, mean reward=0.514, eps=0.47
# total_iter=52243, delta_iteration=195, games=3, mean reward=0.515, eps=0.47
# total_iter=52432, delta_iteration=189, games=1, mean reward=0.523, eps=0.47
# total_iter=52593, delta_iteration=161, games=1, mean reward=0.528, eps=0.46
# total_iter=52789, delta_iteration=196, games=1, mean reward=0.533, eps=0.46
# total_iter=52853, delta_iteration=64, games=1, mean reward=0.534, eps=0.46
# total_iter=52921, delta_iteration=68, games=1, mean reward=0.536, eps=0.46
# total_iter=53303, delta_iteration=382, games=3, mean reward=0.543, eps=0.46
# total_iter=53464, delta_iteration=161, games=1, mean reward=0.547, eps=0.46
# total_iter=53893, delta_iteration=429, games=3, mean reward=0.550, eps=0.45
# total_iter=54093, delta_iteration=200, games=1, mean reward=0.558, eps=0.45
# total_iter=54291, delta_iteration=198, games=1, mean reward=0.565, eps=0.45
# total_iter=54378, delta_iteration=87, games=1, mean reward=0.565, eps=0.45
# total_iter=54574, delta_iteration=196, games=1, mean reward=0.570, eps=0.44
# total_iter=54774, delta_iteration=200, games=1, mean reward=0.575, eps=0.44
# total_iter=54943, delta_iteration=169, games=1, mean reward=0.582, eps=0.44
# total_iter=55079, delta_iteration=136, games=1, mean reward=0.586, eps=0.44
# total_iter=55279, delta_iteration=200, games=1, mean reward=0.595, eps=0.44
# total_iter=55433, delta_iteration=154, games=1, mean reward=0.602, eps=0.44
# total_iter=56427, delta_iteration=994, games=8, mean reward=0.605, eps=0.43
# total_iter=56627, delta_iteration=200, games=1, mean reward=0.611, eps=0.42
# total_iter=57027, delta_iteration=400, games=2, mean reward=0.618, eps=0.42
# total_iter=57227, delta_iteration=200, games=1, mean reward=0.623, eps=0.42
# total_iter=58567, delta_iteration=1340, games=11, mean reward=0.627, eps=0.40
# total_iter=62534, delta_iteration=3967, games=36, mean reward=0.630, eps=0.36
# total_iter=63199, delta_iteration=665, games=5, mean reward=0.638, eps=0.36
# total_iter=63360, delta_iteration=161, games=1, mean reward=0.642, eps=0.36
# total_iter=63535, delta_iteration=175, games=1, mean reward=0.646, eps=0.35
# total_iter=63674, delta_iteration=139, games=1, mean reward=0.652, eps=0.35
# total_iter=64259, delta_iteration=585, games=3, mean reward=0.659, eps=0.35
# total_iter=65429, delta_iteration=1170, games=8, mean reward=0.664, eps=0.34
# total_iter=65629, delta_iteration=200, games=1, mean reward=0.669, eps=0.33
# total_iter=66245, delta_iteration=616, games=4, mean reward=0.670, eps=0.33
# total_iter=66445, delta_iteration=200, games=1, mean reward=0.676, eps=0.33
# total_iter=66622, delta_iteration=177, games=1, mean reward=0.681, eps=0.32
# total_iter=66735, delta_iteration=113, games=1, mean reward=0.682, eps=0.32
# total_iter=69252, delta_iteration=2517, games=16, mean reward=0.685, eps=0.30
# total_iter=69452, delta_iteration=200, games=1, mean reward=0.693, eps=0.30
# total_iter=69652, delta_iteration=200, games=1, mean reward=0.695, eps=0.29
# total_iter=69852, delta_iteration=200, games=1, mean reward=0.697, eps=0.29
# total_iter=70252, delta_iteration=400, games=2, mean reward=0.701, eps=0.29
# total_iter=71441, delta_iteration=1189, games=7, mean reward=0.702, eps=0.28
# total_iter=71641, delta_iteration=200, games=1, mean reward=0.705, eps=0.27
# total_iter=71839, delta_iteration=198, games=1, mean reward=0.714, eps=0.27
# total_iter=72002, delta_iteration=163, games=1, mean reward=0.719, eps=0.27
# total_iter=72202, delta_iteration=200, games=1, mean reward=0.723, eps=0.27
# total_iter=72393, delta_iteration=191, games=1, mean reward=0.724, eps=0.27
# total_iter=72593, delta_iteration=200, games=1, mean reward=0.728, eps=0.26
# total_iter=72793, delta_iteration=200, games=1, mean reward=0.730, eps=0.26
# total_iter=72993, delta_iteration=200, games=1, mean reward=0.731, eps=0.26
# total_iter=73362, delta_iteration=369, games=2, mean reward=0.739, eps=0.26
# total_iter=73562, delta_iteration=200, games=1, mean reward=0.741, eps=0.25
# total_iter=73917, delta_iteration=355, games=2, mean reward=0.744, eps=0.25
# total_iter=74117, delta_iteration=200, games=1, mean reward=0.752, eps=0.25
# total_iter=74317, delta_iteration=200, games=1, mean reward=0.754, eps=0.25
# total_iter=74482, delta_iteration=165, games=1, mean reward=0.761, eps=0.25
# total_iter=74678, delta_iteration=196, games=1, mean reward=0.767, eps=0.24
# total_iter=74878, delta_iteration=200, games=1, mean reward=0.768, eps=0.24
# total_iter=75078, delta_iteration=200, games=1, mean reward=0.778, eps=0.24
# total_iter=75278, delta_iteration=200, games=1, mean reward=0.787, eps=0.24
# total_iter=75638, delta_iteration=360, games=3, mean reward=0.791, eps=0.23
# total_iter=75784, delta_iteration=146, games=1, mean reward=0.795, eps=0.23
# total_iter=75984, delta_iteration=200, games=1, mean reward=0.799, eps=0.23
# total_iter=76149, delta_iteration=165, games=1, mean reward=0.804, eps=0.23
# total_iter=76349, delta_iteration=200, games=1, mean reward=0.809, eps=0.23
# total_iter=76537, delta_iteration=188, games=1, mean reward=0.814, eps=0.22
# total_iter=76845, delta_iteration=308, games=2, mean reward=0.818, eps=0.22
# total_iter=76995, delta_iteration=150, games=1, mean reward=0.823, eps=0.22
# total_iter=77137, delta_iteration=142, games=1, mean reward=0.828, eps=0.22
# total_iter=77337, delta_iteration=200, games=1, mean reward=0.836, eps=0.22
# total_iter=78611, delta_iteration=1274, games=8, mean reward=0.842, eps=0.20
# total_iter=79454, delta_iteration=843, games=5, mean reward=0.844, eps=0.20
# total_iter=79622, delta_iteration=168, games=1, mean reward=0.846, eps=0.19
# total_iter=79807, delta_iteration=185, games=1, mean reward=0.847, eps=0.19
# total_iter=79952, delta_iteration=145, games=1, mean reward=0.848, eps=0.19
# total_iter=80490, delta_iteration=538, games=3, mean reward=0.848, eps=0.19
# total_iter=80634, delta_iteration=144, games=1, mean reward=0.848, eps=0.18
# total_iter=81344, delta_iteration=710, games=4, mean reward=0.851, eps=0.18
# total_iter=81544, delta_iteration=200, games=1, mean reward=0.853, eps=0.17
# total_iter=81744, delta_iteration=200, games=1, mean reward=0.857, eps=0.17
# total_iter=81944, delta_iteration=200, games=1, mean reward=0.857, eps=0.17
# total_iter=82144, delta_iteration=200, games=1, mean reward=0.866, eps=0.17
# total_iter=84168, delta_iteration=2024, games=12, mean reward=0.867, eps=0.15
# total_iter=84368, delta_iteration=200, games=1, mean reward=0.875, eps=0.15
# total_iter=85390, delta_iteration=1022, games=7, mean reward=0.877, eps=0.14
# total_iter=157528, delta_iteration=72138, games=427, mean reward=0.879, eps=0.05
# total_iter=157728, delta_iteration=200, games=1, mean reward=0.882, eps=0.05
# total_iter=157928, delta_iteration=200, games=1, mean reward=0.885, eps=0.05
# total_iter=158128, delta_iteration=200, games=1, mean reward=0.889, eps=0.05
# total_iter=158328, delta_iteration=200, games=1, mean reward=0.893, eps=0.05
# total_iter=158528, delta_iteration=200, games=1, mean reward=0.896, eps=0.05
# total_iter=158728, delta_iteration=200, games=1, mean reward=0.900, eps=0.05
# total_iter=159128, delta_iteration=400, games=2, mean reward=0.904, eps=0.05
# total_iter=159328, delta_iteration=200, games=1, mean reward=0.908, eps=0.05
# total_iter=159528, delta_iteration=200, games=1, mean reward=0.912, eps=0.05
# total_iter=159728, delta_iteration=200, games=1, mean reward=0.916, eps=0.05
# total_iter=159928, delta_iteration=200, games=1, mean reward=0.919, eps=0.05
# total_iter=160128, delta_iteration=200, games=1, mean reward=0.922, eps=0.05
# total_iter=160328, delta_iteration=200, games=1, mean reward=0.926, eps=0.05
# total_iter=160528, delta_iteration=200, games=1, mean reward=0.929, eps=0.05
# total_iter=160728, delta_iteration=200, games=1, mean reward=0.934, eps=0.05
# total_iter=160900, delta_iteration=172, games=1, mean reward=0.935, eps=0.05
# total_iter=161700, delta_iteration=800, games=4, mean reward=0.938, eps=0.05
# total_iter=162100, delta_iteration=400, games=2, mean reward=0.942, eps=0.05
# total_iter=162300, delta_iteration=200, games=1, mean reward=0.944, eps=0.05
# total_iter=162500, delta_iteration=200, games=1, mean reward=0.947, eps=0.05
# total_iter=162700, delta_iteration=200, games=1, mean reward=0.949, eps=0.05
# total_iter=163100, delta_iteration=400, games=2, mean reward=0.949, eps=0.05
# total_iter=163300, delta_iteration=200, games=1, mean reward=0.950, eps=0.05
# total_iter=163500, delta_iteration=200, games=1, mean reward=0.953, eps=0.05
# total_iter=163700, delta_iteration=200, games=1, mean reward=0.954, eps=0.05
# total_iter=163900, delta_iteration=200, games=1, mean reward=0.958, eps=0.05
# total_iter=164300, delta_iteration=400, games=2, mean reward=0.962, eps=0.05
# total_iter=164500, delta_iteration=200, games=1, mean reward=0.964, eps=0.05
# total_iter=164700, delta_iteration=200, games=1, mean reward=0.968, eps=0.05
# total_iter=164900, delta_iteration=200, games=1, mean reward=0.972, eps=0.05
# total_iter=165100, delta_iteration=200, games=1, mean reward=0.974, eps=0.05
# total_iter=165500, delta_iteration=400, games=2, mean reward=0.977, eps=0.05
# total_iter=165700, delta_iteration=200, games=1, mean reward=0.979, eps=0.05
# total_iter=165900, delta_iteration=200, games=1, mean reward=0.982, eps=0.05
# total_iter=166100, delta_iteration=200, games=1, mean reward=0.985, eps=0.05
# total_iter=166300, delta_iteration=200, games=1, mean reward=0.987, eps=0.05
# total_iter=166898, delta_iteration=598, games=3, mean reward=0.989, eps=0.05
# total_iter=167098, delta_iteration=200, games=1, mean reward=0.990, eps=0.05
# total_iter=167498, delta_iteration=400, games=2, mean reward=0.993, eps=0.05
# total_iter=167698, delta_iteration=200, games=1, mean reward=0.995, eps=0.05
# total_iter=169098, delta_iteration=1400, games=7, mean reward=0.998, eps=0.05
# total_iter=180898, delta_iteration=11800, games=59, mean reward=1.000, eps=0.05
# total_iter=186898, delta_iteration=6000, games=30, mean reward=1.000, eps=0.05

# %%
total_rewards[-10:]
# Out:
# [47.0, 15.0, 89.0, 35.0, 76.0, 118.0, 38.0, 25.0, 26.0, 19.0]

# %%
TEST_EPISODES = 100
#env = DiscreteOneHotWrapper(gym.make(DEFAULT_ENV_NAME)) #creating a new environment
total_steps = 0
total_rewards = 0
for i in range(TEST_EPISODES):
    reward, steps = agent.play_episode(net)
    #print('Episode: ',i,' Reward=', reward, ' Steps=', steps)
    total_steps += steps
    total_rewards += reward
print('Average reward=', total_rewards/TEST_EPISODES, ' Av. steps per episode = ', total_steps/TEST_EPISODES)
# Out:
# Average reward= 54.51  Av. steps per episode =  54.51

# %% [markdown]
# This chart shows the change in Epsilon and mean rewards through the iterations.
# ![](img/fig6-2.png)
