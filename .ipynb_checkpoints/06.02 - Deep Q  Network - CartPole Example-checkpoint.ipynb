# %% [markdown]
# # Deep Q-Networks
#
# In this chapter, we'll try to apply the same theory to problems of much greater complexity: arcade games from the Atari 2600 platform, which are the de-facto benchmark of the RL research community. To deal with this new and more challenging goal, we'll talk about problems with the Value iteration method and introduce its variation, called Q-learning. In particular, we'll look at the application of Q-learning to so-called "grid world" environments, which is called tabular Q-learning, and then we'll discuss Q-learning in conjunction with neural networks. This combination has the name DQN. At the end of the chapter, we'll reimplement a DQN algorithm from the famous paper, Playing Atari with Deep Reinforcement Learning by V. Mnih and others, published in 2013, which started a new era in RL development.

# %% [markdown]
# ## Deep Q-learning
#
# For enviroment with continues states, we can use **a nonlinear representation that maps both state and action onto a value**. In machine learning this is called a **"regression problem"**. The concrete way to represent and train such a representation can vary, but, as you may have already guessed from this section's title, using a deep neural network is one of the most popular options, especially when dealing with observations represented as screen images. With this in mind, let's make modifications to the Q-learning algorithm:
# We do a modifcation to the Tabluar Q-Learninng Algorithem above to accomudate very large state,action space and to use DNN:
#
# 1. Initialize $Q(s, a)$ with some initial approximation
# 2. By interacting with the environment, obtain the tuple $(s, a, r, s′)$
# 3. Calculate loss: $L =(Q_{s,a} − r)^2$ if episode has ended or $L =(Q_{s,a} − (r + \gamma \max_{a' \in A} Q_{s',a'}))^2$ otherwise
# 4. Update $Q(s, a)$ using the stochastic gradient descent (SGD) algorithm, by minimizing the loss with respect to the model parameters
# 5. Repeat from step 2 until converged
#
# ### Interaction with the environment
#
# First of all, we need to interact with the environment somehow to receive data to train on. In simple environments, such as FrozenLake, we can act randomly, but is this the best strategy to use? Imagine the game of Pong. What's the probability of winning a single point by randomly moving the paddle? It's not zero but it's extremely small, which just means that we'll need to wait for a very long time for such a rare situation. As an alternative, we can use our Q function approximation as a source of behavior (as we did before in the value iteration method, when we remembered our experience during testing).
#
# If our representation of Q is good, then the experience that we get from the environment will show the agent relevant data to train on. However, we're in trouble when our approximation is not perfect (at the beginning of the training, for example). In such a case, our agent can be stuck with bad actions for some states without ever trying to behave differently. This **exploration versus exploitation dilemma** was mentioned briefly in Chapter 1, What is Reinforcement Learning?. On the one hand, our agent needs to explore the environment to build a complete picture of transitions and action outcomes. On the other hand, we should use interaction with the environment efficiently: we shouldn't waste time by randomly trying actions we've already tried and have learned their outcomes. As you can see, random behavior is better at the beginning of the training when our Q approximation is bad, as it gives us more uniformly distributed information about the environment states. As our training progresses, random behavior becomes inefficient and we want to fall back to our Q approximation to decide how to act.
#
# A method which performs such a mix of two extreme behaviors is known as an **epsilon-greedy method**, which just means switching between random and $Q$ policy using the probability hyperparameter $\epsilon$. By varying $\epsilon$ we can select the ratio of random actions. The usual practice is to start with $\epsilon = 1.0$ (100% random actions) and slowly decrease it to some small value such as 5% or 2% of random actions. Using an epsilon-greedy method helps both to explore the environment in the beginning and to stick to good policy at the end of the training. There are other solutions to the **"exploration versus exploitation"** problem, and we'll discuss some of them in part three of the book. This problem is **one of the fundamental open questions in RL and an active area of research, which is not even close to being resolved completely**.
#
# ### SGD optimization
# The core of our Q-learning procedure is borrowed from the supervised learning. Indeed, we are trying to approximate a complex, nonlinear function $Q(s, a)$ with a neural network. To do this, we calculate targets for this function using the Bellman equation and then pretend that we have a supervised learning problem at hand. That's okay, but one of the fundamental requirements for SGD optimization is that the training data is **independent and identically distributed (i.i.d)**.
#
# In our case, data that we're going to use for the SGD update doesn't fulfill these criteria:
# 1. Our samples are not independent. Even if we accumulate a large batch of data samples, they all will be very close to each other, as they belong to the same episode.
# 2. Distribution of our training data won't be identical to samples provided by the optimal policy that we want to learn. Data that we have is a result of some other policy (our current policy, random, or both in the case of $\epsilon$-greedy), but we don't want to learn how to play randomly: we want an optimal policy with the best reward.
#
# To deal with this nuisance, we usually need to use a **large buffer of our past experience and sample training data from it, instead of using our latest experience**. This method is called **replay buffer**. The simplest implementation is a buffer of **fixed size**, with new data added to the end of the buffer so that it pushes the oldest experience out of it.
#
# **Replay buffer** allows us to train on more-or-less independent data, but data will still be fresh enough to train on samples generated by our recent policy.
#
# ### Correlation between steps
# Another practical issue with the default training procedure is also related to the lack of
# i.i.d in our data, but in a slightly different manner. The Bellman equation provides us with the value of $Q(s, a)$ via $Q(s′, a′)$ (which has the name of **bootstrapping**). However, both states $s$ and $s′$ have only one step between them. This makes them very similar and it's really hard for neural networks to distinguish between them. When we perform an update of our network's parameters, to make $Q(s, a)$ closer to the desired result, we indirectly can alter the value produced for $Q(s′, a′)$ and other states nearby. This can make our training really unstable, like chasing our own tail: when we update $Q$ for state $s$, then on subsequent states we discover that $Q(s′, a′)$ becomes worse, but attempts to update it can spoil our $Q(s, a)$ approximation, and so on.
#
# To make training more stable, there is a **trick, called target network**, when we keep a copy of our network and use it for the $Q(s′, a′)$ value in the Bellman equation. This network is synchronized with our main network only periodically, for example, once in $N$ steps (where $N$ is usually quite a large hyperparameter, such as 1k or 10k training iterations).
#
# ### The Markov property
# Our RL methods use MDP formalism as their basis, which **assumes that the environment obeys the Markov property**: observation from the environment is all that we need to act optimally (in other words, our observations allow us to distinguish states from one another). As we've seen on the preceding Pong's screenshot, one single image from the Atari game is not enough to capture all important information (using only one image we have no idea about the speed and direction of objects, like the ball and our opponent's paddle). This obviously violates the Markov property and moves our single-frame Pong environment into the area of **partially observable MDPs (POMDP)**. A POMDP is basically MDP without the Markov property and they are very important in practice. For example, for most card games where you don't see your opponents' cards, game observations are POMDPs, because current observation (your cards and cards on the table) could correspond to different cards in your opponents' hands.
# We'll not discuss POMPDs in detail in this book, so, for now, we'll use a small technique to push our environment back into the MDP domain. **The solution is maintaining several observations from the past and using them as a state**. In the case of Atari games, we usually stack $k$ subsequent frames together and use them as the observation at every state. This **allows our agent to deduct the dynamics of the current state**, for instance, to get the speed of the ball and its direction. The usual "classical" **number of $k$ for Atari is four**. Of course, it's just a hack, as there can be longer dependencies in the environment, but for most of the games it works well.
#
# ## The final form of DQN (Deep Q-Learning) training
# There are many more tips and tricks that researchers have discovered to make **DQN** training more stable and efficient, and we'll cover the best of them in the next chapter. However, **$\epsilon$-greedy**, **replay buffer**, and **target network** form the basis that allows DeepMind to successfully train a DQN on a set of 49 Atari games and demonstrate the efficiency of this approach applied to complicated environments.
#
# The original paper (without target network) was published at the end of 2013 ([Playing Atari with Deep Reinforcement Learning 1312.5602v1, Mnih and others.)](https://arxiv.org/pdf/1312.5602.pdf), and they used seven games for testing. Later, at the beginning of 2015, a revised version of the article, with 49 different games, was published in Nature ([Human-Level Control Through Deep Reinforcement Learning doi:10.1038/nature14236, Mnih and others.](https://www.nature.com/articles/nature14236))
#
# The algorithm for DQN from the preceding papers has the following steps:
# 1. Initialize parameters for $Q(s, a)$ and $\hat Q (s, a)$ with random weights, **$\epsilon\leftarrow 1.0$**, and **empty replay buffer**
# 2. With probability $\epsilon$, select a random action $a$, otherwise $a = \arg \max_a Q_{s,a}$
# 3. Execute action $a$ in an **emulator** and observe reward $r$ and the next state $s′$
# 4. Store transition $(s, a, r, s′)$ in the **replay buffer**
# 5. Sample a random **minibatch** of transitions from the **replay buffer**
# 6. For every transition in the buffer, calculate target $y = r$ if the episode has ended at this step or $y = r + \gamma \max_{a' \in A} \hat Q_{s',a'}$ otherwise
# 7. Calculate loss: $L = (Q_{s,a} − y)^2$
# 8. Update $Q(s, a)$ using the **SGD algorithm** by minimizing the loss in respect to model parameters
# 9. Every $N$ steps copy weights from $Q$ to $\hat Q_t$
# 10. Repeat from step 2 until converged
#
#
# ## DQN on CartPole
# ### DQN Model

# %%
import torch
import torch.nn as nn
from IPython.core.debugger import Tracer

import numpy as np



#Class for setting the Deep Q-Learning Network
#For the FrozenLake game the w use as simple fully connected single hidden layer dnn
class DQN(nn.Module):
    #Method to intialize the DNN
    def __init__(self, obs_size, hidden_size, output_size):
        super(DQN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, output_size)
        )
 
    #method to perform a single forward operation
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ### DQN  Training on Cartpole

# %%
#!/usr/bin/env python3

import gym

import argparse
import time
import numpy as np
import collections

import torch
import torch.nn as nn
import torch.optim as optim

from tensorboardX import SummaryWriter


#DEFAULT_ENV_NAME = "PongNoFrameskip-v4"
DEFAULT_ENV_NAME = "CartPole-v0"
#DEFAULT_ENV_NAME = "FrozenLake8x8-v0"

LEARNING_RATE = 1e-3 #1e-4

MEAN_REWARD_BOUND = 19.5

GAMMA = 0.99 #0.99 #reward discount
BATCH_SIZE = 32 #32
REPLAY_SIZE = 10000 #10000
REPLAY_START_SIZE = 10000 #10000
SYNC_TARGET_FRAMES = 1000 #1000

HIDDEN_SIZE = 128 #Hidden layer size

#Epsilon control parameters - to control explore/exploite decision
EPSILON_DECAY_LAST_FRAME = 10**5 #10**5
EPSILON_START = .99
EPSILON_FINAL = 0.05


#Create a name tuppled object
Experience = collections.namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])

#A class for replay buffer
class ExperienceBuffer:
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience):
        self.buffer.append(experience)
        self

    def sample(self, batch_size): #Method to append results from a mini batch of a given batch_size
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])
        return np.array(states), np.array(actions), np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), np.array(next_states)

#Ineriting class from Gym's ObservationWraper class
#It converts the descrite inputs will have 16 float numbers, zero everywhere, except the currenl loction of the agent (as float 1)
class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
#         assert isinstance(env.observation_space, gym.spaces.Discrete)
#         self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        res = np.array(observation)
        return res


#The Agent class
class Agent:
    def __init__(self, env, exp_buffer): #method to intialize the Agent
        self.env = env
        self.exp_buffer = exp_buffer #Init the experience buffer
        self._reset()
        
    def _reset(self): #method to reset the agent
        self.state = env.reset()
        self.total_reward = 0.0
        
    def best_action(self, net):
        #state_a = np.array([self.state], copy=False) #Convert the state to np array
        #state_v = torch.tensor(state_a).to(device) 
        state_v = torch.FloatTensor([self.state]).to(device) 
        
        #print(state_v)
        #get the best action for the current state
        q_vals_v = net(state_v) # sm(net(state_v))
        _, act_v = torch.max(q_vals_v, dim=1)
        action = int(act_v.item())
        return action


    def play_step(self, net, epsilon=0.0, device = 'cpu'): #A method to play a single step
        done_reward = None
        #make an explore/exploit decision
        if np.random.random() < epsilon: #Explor: sampling from a unfied and check if result is below epsilon
            action = self.env.action_space.sample() # sample a random action from the environment 
        else: #Exploit: pick an action by scoring the nn
            action = self.best_action(net)
        # Make a step in the environment
        new_state, reward, is_done, _ = self.env.step(action) #perfrom a step on the agent's environment with the selected action
        self.total_reward += reward #increment the total reward with the new reward received
        #print('reward=', reward)
        #new_state = new_state #Seems redundant...

        exp = Experience(self.state, action, reward, is_done, new_state) #Create a new experiance entry
        self.exp_buffer.append(exp) #append the experiance entry
        self.state = new_state 
        if is_done:
            done_reward = self.total_reward
            self._reset()
        return done_reward
    
    def play_episode(self, net):
        self._reset() #reset the environment
        steps = 0
        reward = None
        while reward is None:
            reward = self.play_step(net, epsilon=0.0)#mae a step in the env with the best action
            steps += 1
        return reward, steps


#Calculate loos on a given mini-batch for net and tgt_net
def calc_loss(batch, net, tgt_net, device="cpu"):
    #Tracer()() #Start debugger
    states, actions, rewards, dones, next_states = batch
    
    #Create tensors for states, next_states, actions, rewards and done flags
    states_v = torch.FloatTensor(states) .to(device)
    #print('states_v.shape=',states_v.shape,' states_v=', states_v)
    
    next_states_v = torch.FloatTensor(next_states).to(device)
    #print('next_states_v.shape=',next_states_v.shape,' next_states_v=', next_states_v)
    actions_v = torch.tensor(actions) .to(device)
    rewards_v = torch.tensor(rewards) .to(device)
    done_mask = torch.ByteTensor(dones) .to(device)

    #state_action_values = sm(net(states_v)).gather(1, actions_v.unsqueeze(-1)).squeeze(-1) # Applying the net on sates as input and then extract the Q-values based on the action taken
    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1) # Applying the net on sates as input and then extract the Q-values based on the action taken
    #print('net(states_v)', net(states_v), 'actions_v=', actions_v, 'actions_v.unsqueeze(-1)=', actions_v.unsqueeze(-1),
    #      'net(states_v).gather(1, actions_v.unsqueeze(-1))=', net(states_v).gather(1, actions_v.unsqueeze(-1)),
    #      'net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)=', net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1))
    
    #next_state_values = sm(tgt_net(next_states_v)).max(1)[0] #apply the target network to our next state observations and calculate the maximum Q-value along the same action dimension 1. Function max() returns both maximum values and indices of those values (so it calculates both max and argmax), which is very convenient. However, in this case, we're interested only in values, so we take the first entry of the result.
    next_state_values = tgt_net(next_states_v).max(1)[0] #apply the target network to our next state observations and calculate the maximum Q-value along the same action dimension 1. Function max() returns both maximum values and indices of those values (so it calculates both max and argmax), which is very convenient. However, in this case, we're interested only in values, so we take the first entry of the result.
    next_state_values[done_mask] = 0.0 #Zero next state value in case current state is the last 1
    next_state_values = next_state_values.detach() #detach the value from its computation graph to prevent gradients from flowing into the neural network
    expected_state_action_values = next_state_values * GAMMA + rewards_v #Calculating the expected state action values based on Bellman equation 
    #print('next_state_values:', next_state_values, 'expected_state_action_values:', expected_state_action_values)
    
    
    loss = nn.MSELoss()(state_action_values, expected_state_action_values) #calculate the loss and return it
    #print('loss:', loss)
    #print('====================================================================')

    return loss


if __name__ == "__main__":
#  Setup for GPU
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--cuda", default=False, action="store_true", help="Enable cuda")
#     parser.add_argument("--env", default=DEFAULT_ENV_NAME,
#                         help="Name of the environment, default=" + DEFAULT_ENV_NAME)
#     parser.add_argument("--reward", type=float, default=MEAN_REWARD_BOUND,
#                         help="Mean reward boundary for stop of training, default=%.2f" % MEAN_REWARD_BOUND)
#     args = parser.parse_args()
#     device = torch.device("cuda" if args.cuda else "cpu")

#     env = wrappers.make_env(args.env)
    device = 'cpu'

#    env = wrappers.make_env(args.env)

#    env = DiscreteOneHotWrapper(gym.make(DEFAULT_ENV_NAME)) #creating a new environment 
    env = DiscreteOneHotWrapper(gym.make(DEFAULT_ENV_NAME)) #creating a new environment 
    
#    env = gym.make("CartPole-v0") #using CartPole as environment
    
    obs_size = env.observation_space.shape[0] #4 in the case of CartPole
    n_actions = env.action_space.n  # 2 actions (left, right) in the case of CartPole

    net = DQN(obs_size, HIDDEN_SIZE, n_actions) .to(device)
    tgt_net = DQN(obs_size, HIDDEN_SIZE, n_actions).to(device)

    writer = SummaryWriter(comment="-") #(comment="-" + args.env)
    print(net)

    exp_buffer = ExperienceBuffer(REPLAY_SIZE)
    agent = Agent(env,exp_buffer) #Creating a new instance of an agent
    epsilon = EPSILON_START #Init the greed factor - higer value means more explor and less exploit

    optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
    total_rewards = []
    iter_idx = 0
    ts_frame = 0
    ts = time.time()
    best_mean_reward = None
    
    #sm = nn.Softmax(dim=1) #creating a softmax function 
    prev_idx = 0
    prev_games = 0

    while True:
        iter_idx += 1
        epsilon = max(EPSILON_FINAL, EPSILON_START - iter_idx / EPSILON_DECAY_LAST_FRAME) #Update epslion (greed factor) by reducing it baed on the iter  

        reward = agent.play_step(net, epsilon, device=device)

        if reward is not None:
            total_rewards.append(reward)
            speed = (iter_idx - ts_frame) / (time.time() - ts)
            ts_frame = iter_idx
            ts = time.time()
            mean_reward = np.mean(total_rewards[-100:])/200
            writer.add_scalar("epsilon", epsilon, iter_idx)
            writer.add_scalar("speed", speed, iter_idx)
            writer.add_scalar("reward_100", mean_reward, iter_idx)
            writer.add_scalar("reward", reward, iter_idx)
            if best_mean_reward is None or best_mean_reward < mean_reward:
                #torch.save(net.state_dict(), "-best.dat") #Save (serialize the model parameters) - not sure why needed
                #print('net state_dict saved >>>>>>')
                if best_mean_reward is not None:
                    print("total_iter=%d, delta_iteration=%d, games=%d, mean reward=%.3f, eps=%.2f" 
                          % (iter_idx, iter_idx - prev_idx, len(total_rewards) - prev_games, mean_reward, epsilon))
                best_mean_reward = mean_reward
                prev_idx = iter_idx
                prev_games = len(total_rewards)

            if mean_reward >= .99: # args.reward:
                #print("Solved in %d frames!" % iter_idx)
                break

        if len(exp_buffer) < REPLAY_START_SIZE:
            continue

        if iter_idx % SYNC_TARGET_FRAMES == 0:
            tgt_net.load_state_dict(net.state_dict()) #sync the net model parameters to the target net
            #print('total_iter=', iter_idx, 'mean_reward=', mean_reward, ' best_mean_reward=', best_mean_reward)
            #print('net state_dict loaded <<<<<')


        optimizer.zero_grad()
        batch = exp_buffer.sample(BATCH_SIZE) #sample from the experiance buffer 
        loss_t = calc_loss(batch, net, tgt_net, device=device)
        #print('loss=',loss_t.abs())
        loss_t.backward()
        optimizer.step()
        
    writer.close()
# Out:
# DQN(
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# total_iter=46, delta_iteration=30, games=1, mean reward=0.115, eps=0.99
# total_iter=6029, delta_iteration=5983, games=271, mean reward=0.116, eps=0.93
# total_iter=6060, delta_iteration=31, games=1, mean reward=0.116, eps=0.93
# total_iter=6097, delta_iteration=37, games=2, mean reward=0.117, eps=0.93
# total_iter=13741, delta_iteration=7644, games=367, mean reward=0.117, eps=0.85
# total_iter=13759, delta_iteration=18, games=1, mean reward=0.117, eps=0.85
# total_iter=14037, delta_iteration=278, games=12, mean reward=0.117, eps=0.85
# total_iter=14078, delta_iteration=41, games=1, mean reward=0.118, eps=0.85
# total_iter=14135, delta_iteration=57, games=1, mean reward=0.119, eps=0.85
# total_iter=14224, delta_iteration=89, games=1, mean reward=0.122, eps=0.85
# total_iter=14234, delta_iteration=10, games=1, mean reward=0.122, eps=0.85
# total_iter=14271, delta_iteration=37, games=1, mean reward=0.123, eps=0.85
# total_iter=14353, delta_iteration=82, games=2, mean reward=0.124, eps=0.85
# total_iter=14377, delta_iteration=24, games=1, mean reward=0.125, eps=0.85
# total_iter=14398, delta_iteration=21, games=1, mean reward=0.125, eps=0.85
# total_iter=14549, delta_iteration=151, games=7, mean reward=0.126, eps=0.84
# total_iter=14581, delta_iteration=32, games=1, mean reward=0.126, eps=0.84
# total_iter=14604, delta_iteration=23, games=1, mean reward=0.127, eps=0.84
# total_iter=14648, delta_iteration=44, games=1, mean reward=0.127, eps=0.84
# total_iter=14678, delta_iteration=30, games=1, mean reward=0.128, eps=0.84
# total_iter=14742, delta_iteration=64, games=3, mean reward=0.128, eps=0.84
# total_iter=14895, delta_iteration=153, games=5, mean reward=0.128, eps=0.84
# total_iter=14919, delta_iteration=24, games=1, mean reward=0.128, eps=0.84
# total_iter=14958, delta_iteration=39, games=1, mean reward=0.129, eps=0.84
# total_iter=15027, delta_iteration=69, games=2, mean reward=0.129, eps=0.84
# total_iter=15052, delta_iteration=25, games=1, mean reward=0.130, eps=0.84
# total_iter=15072, delta_iteration=20, games=1, mean reward=0.131, eps=0.84
# total_iter=15139, delta_iteration=67, games=2, mean reward=0.133, eps=0.84
# total_iter=15185, delta_iteration=46, games=2, mean reward=0.133, eps=0.84
# total_iter=15317, delta_iteration=132, games=3, mean reward=0.136, eps=0.84
# total_iter=15366, delta_iteration=49, games=2, mean reward=0.136, eps=0.84
# total_iter=15492, delta_iteration=126, games=3, mean reward=0.139, eps=0.84
# total_iter=15516, delta_iteration=24, games=1, mean reward=0.139, eps=0.83
# total_iter=15534, delta_iteration=18, games=1, mean reward=0.140, eps=0.83
# total_iter=15575, delta_iteration=41, games=1, mean reward=0.140, eps=0.83
# total_iter=15591, delta_iteration=16, games=1, mean reward=0.141, eps=0.83
# total_iter=15636, delta_iteration=45, games=1, mean reward=0.141, eps=0.83
# total_iter=15651, delta_iteration=15, games=1, mean reward=0.142, eps=0.83
# total_iter=15688, delta_iteration=37, games=1, mean reward=0.142, eps=0.83
# total_iter=15713, delta_iteration=25, games=1, mean reward=0.142, eps=0.83
# total_iter=15808, delta_iteration=95, games=2, mean reward=0.144, eps=0.83
# total_iter=15939, delta_iteration=131, games=3, mean reward=0.146, eps=0.83
# total_iter=15986, delta_iteration=47, games=1, mean reward=0.146, eps=0.83
# total_iter=16020, delta_iteration=34, games=1, mean reward=0.147, eps=0.83
# total_iter=16329, delta_iteration=309, games=11, mean reward=0.148, eps=0.83
# total_iter=16353, delta_iteration=24, games=1, mean reward=0.148, eps=0.83
# total_iter=16412, delta_iteration=59, games=2, mean reward=0.149, eps=0.83
# total_iter=16480, delta_iteration=68, games=1, mean reward=0.150, eps=0.83
# total_iter=16505, delta_iteration=25, games=1, mean reward=0.151, eps=0.82
# total_iter=16594, delta_iteration=89, games=2, mean reward=0.153, eps=0.82
# total_iter=16670, delta_iteration=76, games=3, mean reward=0.154, eps=0.82
# total_iter=16700, delta_iteration=30, games=1, mean reward=0.154, eps=0.82
# total_iter=16749, delta_iteration=49, games=1, mean reward=0.156, eps=0.82
# total_iter=16766, delta_iteration=17, games=1, mean reward=0.156, eps=0.82
# total_iter=16941, delta_iteration=175, games=5, mean reward=0.158, eps=0.82
# total_iter=17024, delta_iteration=83, games=1, mean reward=0.161, eps=0.82
# total_iter=17081, delta_iteration=57, games=1, mean reward=0.163, eps=0.82
# total_iter=17098, delta_iteration=17, games=1, mean reward=0.163, eps=0.82
# total_iter=17126, delta_iteration=28, games=1, mean reward=0.164, eps=0.82
# total_iter=17151, delta_iteration=25, games=1, mean reward=0.164, eps=0.82
# total_iter=17195, delta_iteration=44, games=1, mean reward=0.164, eps=0.82
# total_iter=17329, delta_iteration=134, games=3, mean reward=0.166, eps=0.82
# total_iter=17758, delta_iteration=429, games=12, mean reward=0.166, eps=0.81
# total_iter=17810, delta_iteration=52, games=1, mean reward=0.168, eps=0.81
# total_iter=17870, delta_iteration=60, games=3, mean reward=0.168, eps=0.81
# total_iter=17911, delta_iteration=41, games=1, mean reward=0.168, eps=0.81
# total_iter=17985, delta_iteration=74, games=2, mean reward=0.169, eps=0.81
# total_iter=18141, delta_iteration=156, games=5, mean reward=0.170, eps=0.81
# total_iter=18181, delta_iteration=40, games=1, mean reward=0.171, eps=0.81
# total_iter=19145, delta_iteration=964, games=30, mean reward=0.172, eps=0.80
# total_iter=19164, delta_iteration=19, games=1, mean reward=0.172, eps=0.80
# total_iter=21954, delta_iteration=2790, games=78, mean reward=0.176, eps=0.77
# total_iter=22008, delta_iteration=54, games=1, mean reward=0.177, eps=0.77
# total_iter=22077, delta_iteration=69, games=2, mean reward=0.178, eps=0.77
# total_iter=22139, delta_iteration=62, games=1, mean reward=0.180, eps=0.77
# total_iter=22192, delta_iteration=53, games=2, mean reward=0.180, eps=0.77
# total_iter=22815, delta_iteration=623, games=17, mean reward=0.182, eps=0.76
# total_iter=22853, delta_iteration=38, games=1, mean reward=0.183, eps=0.76
# total_iter=22926, delta_iteration=73, games=1, mean reward=0.185, eps=0.76
# total_iter=23252, delta_iteration=326, games=8, mean reward=0.186, eps=0.76
# total_iter=23282, delta_iteration=30, games=1, mean reward=0.187, eps=0.76
# total_iter=23303, delta_iteration=21, games=1, mean reward=0.187, eps=0.76
# total_iter=23431, delta_iteration=128, games=3, mean reward=0.188, eps=0.76
# total_iter=23511, delta_iteration=80, games=1, mean reward=0.191, eps=0.75
# total_iter=23610, delta_iteration=99, games=1, mean reward=0.194, eps=0.75
# total_iter=23723, delta_iteration=113, games=1, mean reward=0.199, eps=0.75
# total_iter=23823, delta_iteration=100, games=2, mean reward=0.201, eps=0.75
# total_iter=23852, delta_iteration=29, games=1, mean reward=0.202, eps=0.75
# total_iter=23931, delta_iteration=79, games=1, mean reward=0.205, eps=0.75
# total_iter=24020, delta_iteration=89, games=1, mean reward=0.207, eps=0.75
# total_iter=24596, delta_iteration=576, games=18, mean reward=0.209, eps=0.74
# total_iter=24763, delta_iteration=167, games=2, mean reward=0.212, eps=0.74
# total_iter=24786, delta_iteration=23, games=1, mean reward=0.213, eps=0.74
# total_iter=24834, delta_iteration=48, games=1, mean reward=0.214, eps=0.74
# total_iter=24983, delta_iteration=149, games=2, mean reward=0.217, eps=0.74
# total_iter=26588, delta_iteration=1605, games=39, mean reward=0.217, eps=0.72
# total_iter=26653, delta_iteration=65, games=1, mean reward=0.220, eps=0.72
# total_iter=26751, delta_iteration=98, games=2, mean reward=0.220, eps=0.72
# total_iter=26855, delta_iteration=104, games=1, mean reward=0.224, eps=0.72
# total_iter=26928, delta_iteration=73, games=1, mean reward=0.227, eps=0.72
# total_iter=26975, delta_iteration=47, games=1, mean reward=0.229, eps=0.72
# total_iter=27059, delta_iteration=84, games=1, mean reward=0.233, eps=0.72
# total_iter=27122, delta_iteration=63, games=1, mean reward=0.234, eps=0.72
# total_iter=27283, delta_iteration=161, games=1, mean reward=0.239, eps=0.72
# total_iter=29167, delta_iteration=1884, games=40, mean reward=0.241, eps=0.70
# total_iter=29219, delta_iteration=52, games=1, mean reward=0.243, eps=0.70
# total_iter=29360, delta_iteration=141, games=2, mean reward=0.247, eps=0.70
# total_iter=30243, delta_iteration=883, games=18, mean reward=0.251, eps=0.69
# total_iter=30317, delta_iteration=74, games=1, mean reward=0.253, eps=0.69
# total_iter=30461, delta_iteration=144, games=1, mean reward=0.258, eps=0.69
# total_iter=30520, delta_iteration=59, games=1, mean reward=0.258, eps=0.68
# total_iter=30571, delta_iteration=51, games=1, mean reward=0.259, eps=0.68
# total_iter=31065, delta_iteration=494, games=10, mean reward=0.260, eps=0.68
# total_iter=31111, delta_iteration=46, games=1, mean reward=0.261, eps=0.68
# total_iter=31204, delta_iteration=93, games=1, mean reward=0.265, eps=0.68
# total_iter=31683, delta_iteration=479, games=9, mean reward=0.267, eps=0.67
# total_iter=31819, delta_iteration=136, games=1, mean reward=0.271, eps=0.67
# total_iter=31922, delta_iteration=103, games=1, mean reward=0.274, eps=0.67
# total_iter=32030, delta_iteration=108, games=1, mean reward=0.277, eps=0.67
# total_iter=36196, delta_iteration=4166, games=80, mean reward=0.277, eps=0.63
# total_iter=36366, delta_iteration=170, games=2, mean reward=0.281, eps=0.63
# total_iter=38540, delta_iteration=2174, games=36, mean reward=0.284, eps=0.60
# total_iter=38605, delta_iteration=65, games=2, mean reward=0.284, eps=0.60
# total_iter=38720, delta_iteration=115, games=3, mean reward=0.285, eps=0.60
# total_iter=39083, delta_iteration=363, games=4, mean reward=0.289, eps=0.60
# total_iter=39167, delta_iteration=84, games=1, mean reward=0.291, eps=0.60
# total_iter=39318, delta_iteration=151, games=2, mean reward=0.294, eps=0.60
# total_iter=39604, delta_iteration=286, games=4, mean reward=0.297, eps=0.59
# total_iter=39678, delta_iteration=74, games=1, mean reward=0.300, eps=0.59
# total_iter=39748, delta_iteration=70, games=1, mean reward=0.302, eps=0.59
# total_iter=39948, delta_iteration=200, games=1, mean reward=0.311, eps=0.59
# total_iter=39976, delta_iteration=28, games=1, mean reward=0.311, eps=0.59
# total_iter=40352, delta_iteration=376, games=7, mean reward=0.312, eps=0.59
# total_iter=40412, delta_iteration=60, games=1, mean reward=0.312, eps=0.59
# total_iter=40516, delta_iteration=104, games=1, mean reward=0.316, eps=0.58
# total_iter=40716, delta_iteration=200, games=1, mean reward=0.325, eps=0.58
# total_iter=41140, delta_iteration=424, games=7, mean reward=0.331, eps=0.58
# total_iter=41422, delta_iteration=282, games=3, mean reward=0.336, eps=0.58
# total_iter=42142, delta_iteration=720, games=9, mean reward=0.338, eps=0.57
# total_iter=42283, delta_iteration=141, games=2, mean reward=0.340, eps=0.57
# total_iter=42414, delta_iteration=131, games=3, mean reward=0.342, eps=0.57
# total_iter=42464, delta_iteration=50, games=1, mean reward=0.343, eps=0.57
# total_iter=42497, delta_iteration=33, games=1, mean reward=0.343, eps=0.57
# total_iter=42777, delta_iteration=280, games=2, mean reward=0.346, eps=0.56
# total_iter=42971, delta_iteration=194, games=2, mean reward=0.351, eps=0.56
# total_iter=43066, delta_iteration=95, games=1, mean reward=0.353, eps=0.56
# total_iter=43359, delta_iteration=293, games=2, mean reward=0.357, eps=0.56
# total_iter=43906, delta_iteration=547, games=8, mean reward=0.359, eps=0.55
# total_iter=44105, delta_iteration=199, games=3, mean reward=0.364, eps=0.55
# total_iter=44201, delta_iteration=96, games=1, mean reward=0.368, eps=0.55
# total_iter=44375, delta_iteration=174, games=1, mean reward=0.371, eps=0.55
# total_iter=44575, delta_iteration=200, games=1, mean reward=0.374, eps=0.54
# total_iter=44737, delta_iteration=162, games=1, mean reward=0.381, eps=0.54
# total_iter=44820, delta_iteration=83, games=1, mean reward=0.383, eps=0.54
# total_iter=44960, delta_iteration=140, games=1, mean reward=0.383, eps=0.54
# total_iter=45005, delta_iteration=45, games=1, mean reward=0.384, eps=0.54
# total_iter=45113, delta_iteration=108, games=1, mean reward=0.387, eps=0.54
# total_iter=45402, delta_iteration=289, games=4, mean reward=0.388, eps=0.54
# total_iter=45511, delta_iteration=109, games=2, mean reward=0.389, eps=0.53
# total_iter=45701, delta_iteration=190, games=2, mean reward=0.394, eps=0.53
# total_iter=45932, delta_iteration=231, games=2, mean reward=0.400, eps=0.53
# total_iter=46030, delta_iteration=98, games=1, mean reward=0.403, eps=0.53
# total_iter=46184, delta_iteration=154, games=1, mean reward=0.409, eps=0.53
# total_iter=46329, delta_iteration=145, games=1, mean reward=0.415, eps=0.53
# total_iter=46795, delta_iteration=466, games=4, mean reward=0.422, eps=0.52
# total_iter=47040, delta_iteration=245, games=2, mean reward=0.424, eps=0.52
# total_iter=47151, delta_iteration=111, games=1, mean reward=0.427, eps=0.52
# total_iter=47276, delta_iteration=125, games=1, mean reward=0.432, eps=0.52
# total_iter=47370, delta_iteration=94, games=2, mean reward=0.432, eps=0.52
# total_iter=47462, delta_iteration=92, games=1, mean reward=0.436, eps=0.52
# total_iter=47561, delta_iteration=99, games=1, mean reward=0.436, eps=0.51
# total_iter=47761, delta_iteration=200, games=1, mean reward=0.444, eps=0.51
# total_iter=48128, delta_iteration=367, games=2, mean reward=0.448, eps=0.51
# total_iter=48376, delta_iteration=248, games=3, mean reward=0.451, eps=0.51
# total_iter=48457, delta_iteration=81, games=1, mean reward=0.452, eps=0.51
# total_iter=48693, delta_iteration=236, games=2, mean reward=0.454, eps=0.50
# total_iter=48893, delta_iteration=200, games=1, mean reward=0.461, eps=0.50
# total_iter=49093, delta_iteration=200, games=1, mean reward=0.467, eps=0.50
# total_iter=49541, delta_iteration=448, games=4, mean reward=0.473, eps=0.49
# total_iter=49685, delta_iteration=144, games=1, mean reward=0.479, eps=0.49
# total_iter=49823, delta_iteration=138, games=1, mean reward=0.481, eps=0.49
# total_iter=49874, delta_iteration=51, games=1, mean reward=0.483, eps=0.49
# total_iter=50074, delta_iteration=200, games=1, mean reward=0.490, eps=0.49
# total_iter=50274, delta_iteration=200, games=1, mean reward=0.496, eps=0.49
# total_iter=50474, delta_iteration=200, games=1, mean reward=0.503, eps=0.49
# total_iter=50674, delta_iteration=200, games=1, mean reward=0.508, eps=0.48
# total_iter=51040, delta_iteration=366, games=4, mean reward=0.511, eps=0.48
# total_iter=51103, delta_iteration=63, games=1, mean reward=0.512, eps=0.48
# total_iter=51303, delta_iteration=200, games=1, mean reward=0.522, eps=0.48
# total_iter=51503, delta_iteration=200, games=1, mean reward=0.526, eps=0.47
# total_iter=51679, delta_iteration=176, games=1, mean reward=0.527, eps=0.47
# total_iter=51723, delta_iteration=44, games=1, mean reward=0.527, eps=0.47
# total_iter=52157, delta_iteration=434, games=4, mean reward=0.532, eps=0.47
# total_iter=52253, delta_iteration=96, games=1, mean reward=0.535, eps=0.47
# total_iter=52352, delta_iteration=99, games=1, mean reward=0.539, eps=0.47
# total_iter=52552, delta_iteration=200, games=1, mean reward=0.545, eps=0.46
# total_iter=53082, delta_iteration=530, games=4, mean reward=0.547, eps=0.46
# total_iter=53194, delta_iteration=112, games=1, mean reward=0.549, eps=0.46
# total_iter=53367, delta_iteration=173, games=2, mean reward=0.553, eps=0.46
# total_iter=53384, delta_iteration=17, games=1, mean reward=0.553, eps=0.46
# total_iter=53541, delta_iteration=157, games=1, mean reward=0.556, eps=0.45
# total_iter=53620, delta_iteration=79, games=1, mean reward=0.558, eps=0.45
# total_iter=53820, delta_iteration=200, games=1, mean reward=0.566, eps=0.45
# total_iter=54020, delta_iteration=200, games=1, mean reward=0.569, eps=0.45
# total_iter=54220, delta_iteration=200, games=1, mean reward=0.572, eps=0.45
# total_iter=54420, delta_iteration=200, games=1, mean reward=0.581, eps=0.45
# total_iter=55143, delta_iteration=723, games=6, mean reward=0.583, eps=0.44
# total_iter=55216, delta_iteration=73, games=1, mean reward=0.584, eps=0.44
# total_iter=55327, delta_iteration=111, games=1, mean reward=0.588, eps=0.44
# total_iter=55548, delta_iteration=221, games=2, mean reward=0.591, eps=0.43
# total_iter=55684, delta_iteration=136, games=1, mean reward=0.596, eps=0.43
# total_iter=55917, delta_iteration=233, games=3, mean reward=0.597, eps=0.43
# total_iter=56117, delta_iteration=200, games=1, mean reward=0.601, eps=0.43
# total_iter=57427, delta_iteration=1310, games=12, mean reward=0.601, eps=0.42
# total_iter=57627, delta_iteration=200, games=1, mean reward=0.608, eps=0.41
# total_iter=57827, delta_iteration=200, games=1, mean reward=0.616, eps=0.41
# total_iter=58040, delta_iteration=213, games=2, mean reward=0.617, eps=0.41
# total_iter=58196, delta_iteration=156, games=1, mean reward=0.623, eps=0.41
# total_iter=58596, delta_iteration=400, games=2, mean reward=0.628, eps=0.40
# total_iter=59055, delta_iteration=459, games=4, mean reward=0.629, eps=0.40
# total_iter=59255, delta_iteration=200, games=1, mean reward=0.633, eps=0.40
# total_iter=59529, delta_iteration=274, games=2, mean reward=0.634, eps=0.39
# total_iter=59893, delta_iteration=364, games=2, mean reward=0.637, eps=0.39
# total_iter=60093, delta_iteration=200, games=1, mean reward=0.641, eps=0.39
# total_iter=60293, delta_iteration=200, games=1, mean reward=0.650, eps=0.39
# total_iter=60493, delta_iteration=200, games=1, mean reward=0.656, eps=0.39
# total_iter=60693, delta_iteration=200, games=1, mean reward=0.662, eps=0.38
# total_iter=61420, delta_iteration=727, games=5, mean reward=0.664, eps=0.38
# total_iter=61660, delta_iteration=240, games=2, mean reward=0.664, eps=0.37
# total_iter=61860, delta_iteration=200, games=1, mean reward=0.670, eps=0.37
# total_iter=61963, delta_iteration=103, games=1, mean reward=0.673, eps=0.37
# total_iter=62953, delta_iteration=990, games=6, mean reward=0.681, eps=0.36
# total_iter=63487, delta_iteration=534, games=4, mean reward=0.681, eps=0.36
# total_iter=64320, delta_iteration=833, games=5, mean reward=0.681, eps=0.35
# total_iter=64520, delta_iteration=200, games=1, mean reward=0.690, eps=0.34
# total_iter=64720, delta_iteration=200, games=1, mean reward=0.691, eps=0.34
# total_iter=64979, delta_iteration=259, games=2, mean reward=0.694, eps=0.34
# total_iter=66642, delta_iteration=1663, games=13, mean reward=0.696, eps=0.32
# total_iter=67345, delta_iteration=703, games=6, mean reward=0.698, eps=0.32
# total_iter=67545, delta_iteration=200, games=1, mean reward=0.700, eps=0.31
# total_iter=67745, delta_iteration=200, games=1, mean reward=0.706, eps=0.31
# total_iter=68751, delta_iteration=1006, games=6, mean reward=0.710, eps=0.30
# total_iter=68951, delta_iteration=200, games=1, mean reward=0.714, eps=0.30
# total_iter=69351, delta_iteration=400, games=2, mean reward=0.720, eps=0.30
# total_iter=70140, delta_iteration=789, games=7, mean reward=0.722, eps=0.29
# total_iter=70340, delta_iteration=200, games=1, mean reward=0.725, eps=0.29
# total_iter=70443, delta_iteration=103, games=1, mean reward=0.726, eps=0.29
# total_iter=70843, delta_iteration=400, games=2, mean reward=0.734, eps=0.28
# total_iter=71252, delta_iteration=409, games=3, mean reward=0.740, eps=0.28
# total_iter=71413, delta_iteration=161, games=1, mean reward=0.747, eps=0.28
# total_iter=71980, delta_iteration=567, games=3, mean reward=0.754, eps=0.27
# total_iter=72180, delta_iteration=200, games=1, mean reward=0.759, eps=0.27
# total_iter=73027, delta_iteration=847, games=6, mean reward=0.759, eps=0.26
# total_iter=73427, delta_iteration=400, games=2, mean reward=0.762, eps=0.26
# total_iter=74027, delta_iteration=600, games=3, mean reward=0.771, eps=0.25
# total_iter=74227, delta_iteration=200, games=1, mean reward=0.779, eps=0.25
# total_iter=75000, delta_iteration=773, games=4, mean reward=0.784, eps=0.24
# total_iter=75400, delta_iteration=400, games=2, mean reward=0.785, eps=0.24
# total_iter=118926, delta_iteration=43526, games=320, mean reward=0.786, eps=0.05
# total_iter=119126, delta_iteration=200, games=1, mean reward=0.790, eps=0.05
# total_iter=119271, delta_iteration=145, games=1, mean reward=0.792, eps=0.05
# total_iter=119419, delta_iteration=148, games=1, mean reward=0.794, eps=0.05
# total_iter=119570, delta_iteration=151, games=1, mean reward=0.795, eps=0.05
# total_iter=119726, delta_iteration=156, games=1, mean reward=0.797, eps=0.05
# total_iter=119872, delta_iteration=146, games=1, mean reward=0.799, eps=0.05
# total_iter=120008, delta_iteration=136, games=1, mean reward=0.800, eps=0.05
# total_iter=120148, delta_iteration=140, games=1, mean reward=0.800, eps=0.05
# total_iter=120310, delta_iteration=162, games=1, mean reward=0.803, eps=0.05
# total_iter=120633, delta_iteration=323, games=2, mean reward=0.804, eps=0.05
# total_iter=120769, delta_iteration=136, games=1, mean reward=0.805, eps=0.05
# total_iter=120952, delta_iteration=183, games=1, mean reward=0.806, eps=0.05
# total_iter=121130, delta_iteration=178, games=1, mean reward=0.809, eps=0.05
# total_iter=121656, delta_iteration=526, games=3, mean reward=0.810, eps=0.05
# total_iter=121820, delta_iteration=164, games=1, mean reward=0.812, eps=0.05
# total_iter=122181, delta_iteration=361, games=2, mean reward=0.815, eps=0.05
# total_iter=122381, delta_iteration=200, games=1, mean reward=0.819, eps=0.05
# total_iter=122546, delta_iteration=165, games=1, mean reward=0.820, eps=0.05
# total_iter=123266, delta_iteration=720, games=4, mean reward=0.821, eps=0.05
# total_iter=123802, delta_iteration=536, games=3, mean reward=0.822, eps=0.05
# total_iter=123978, delta_iteration=176, games=1, mean reward=0.823, eps=0.05
# total_iter=145881, delta_iteration=21903, games=137, mean reward=0.824, eps=0.05
# total_iter=146081, delta_iteration=200, games=1, mean reward=0.827, eps=0.05
# total_iter=146281, delta_iteration=200, games=1, mean reward=0.830, eps=0.05
# total_iter=146481, delta_iteration=200, games=1, mean reward=0.832, eps=0.05
# total_iter=146681, delta_iteration=200, games=1, mean reward=0.835, eps=0.05
# total_iter=146881, delta_iteration=200, games=1, mean reward=0.837, eps=0.05
# total_iter=147081, delta_iteration=200, games=1, mean reward=0.839, eps=0.05
# total_iter=147281, delta_iteration=200, games=1, mean reward=0.842, eps=0.05
# total_iter=147481, delta_iteration=200, games=1, mean reward=0.845, eps=0.05
# total_iter=147681, delta_iteration=200, games=1, mean reward=0.848, eps=0.05
# total_iter=147881, delta_iteration=200, games=1, mean reward=0.850, eps=0.05
# total_iter=148081, delta_iteration=200, games=1, mean reward=0.852, eps=0.05
# total_iter=148281, delta_iteration=200, games=1, mean reward=0.855, eps=0.05
# total_iter=148481, delta_iteration=200, games=1, mean reward=0.858, eps=0.05
# total_iter=148681, delta_iteration=200, games=1, mean reward=0.860, eps=0.05
# total_iter=148881, delta_iteration=200, games=1, mean reward=0.862, eps=0.05
# total_iter=149081, delta_iteration=200, games=1, mean reward=0.864, eps=0.05
# total_iter=149281, delta_iteration=200, games=1, mean reward=0.866, eps=0.05
# total_iter=149481, delta_iteration=200, games=1, mean reward=0.868, eps=0.05
# total_iter=149681, delta_iteration=200, games=1, mean reward=0.871, eps=0.05
# total_iter=149881, delta_iteration=200, games=1, mean reward=0.874, eps=0.05
# total_iter=150081, delta_iteration=200, games=1, mean reward=0.877, eps=0.05
# total_iter=150281, delta_iteration=200, games=1, mean reward=0.880, eps=0.05
# total_iter=150481, delta_iteration=200, games=1, mean reward=0.883, eps=0.05
# total_iter=150681, delta_iteration=200, games=1, mean reward=0.886, eps=0.05
# total_iter=150881, delta_iteration=200, games=1, mean reward=0.889, eps=0.05
# total_iter=151081, delta_iteration=200, games=1, mean reward=0.893, eps=0.05
# total_iter=151281, delta_iteration=200, games=1, mean reward=0.896, eps=0.05
# total_iter=151481, delta_iteration=200, games=1, mean reward=0.899, eps=0.05
# total_iter=151681, delta_iteration=200, games=1, mean reward=0.902, eps=0.05
# total_iter=151881, delta_iteration=200, games=1, mean reward=0.905, eps=0.05
# total_iter=152081, delta_iteration=200, games=1, mean reward=0.909, eps=0.05
# total_iter=152221, delta_iteration=140, games=1, mean reward=0.909, eps=0.05
# total_iter=152564, delta_iteration=343, games=2, mean reward=0.911, eps=0.05
# total_iter=153165, delta_iteration=601, games=4, mean reward=0.912, eps=0.05
# total_iter=153365, delta_iteration=200, games=1, mean reward=0.915, eps=0.05
# total_iter=153565, delta_iteration=200, games=1, mean reward=0.918, eps=0.05
# total_iter=153765, delta_iteration=200, games=1, mean reward=0.920, eps=0.05
# total_iter=153965, delta_iteration=200, games=1, mean reward=0.922, eps=0.05
# total_iter=154592, delta_iteration=627, games=4, mean reward=0.924, eps=0.05
# total_iter=154792, delta_iteration=200, games=1, mean reward=0.926, eps=0.05
# total_iter=154968, delta_iteration=176, games=1, mean reward=0.926, eps=0.05
# total_iter=155168, delta_iteration=200, games=1, mean reward=0.929, eps=0.05
# total_iter=155368, delta_iteration=200, games=1, mean reward=0.930, eps=0.05
# total_iter=155568, delta_iteration=200, games=1, mean reward=0.932, eps=0.05
# total_iter=155768, delta_iteration=200, games=1, mean reward=0.933, eps=0.05
# total_iter=155968, delta_iteration=200, games=1, mean reward=0.935, eps=0.05
# total_iter=156168, delta_iteration=200, games=1, mean reward=0.936, eps=0.05
# total_iter=156368, delta_iteration=200, games=1, mean reward=0.938, eps=0.05
# total_iter=156568, delta_iteration=200, games=1, mean reward=0.939, eps=0.05
# total_iter=156768, delta_iteration=200, games=1, mean reward=0.940, eps=0.05
# total_iter=156968, delta_iteration=200, games=1, mean reward=0.942, eps=0.05
# total_iter=157168, delta_iteration=200, games=1, mean reward=0.944, eps=0.05
# total_iter=157368, delta_iteration=200, games=1, mean reward=0.945, eps=0.05
# total_iter=157568, delta_iteration=200, games=1, mean reward=0.947, eps=0.05
# total_iter=157768, delta_iteration=200, games=1, mean reward=0.949, eps=0.05
# total_iter=157968, delta_iteration=200, games=1, mean reward=0.950, eps=0.05
# total_iter=158168, delta_iteration=200, games=1, mean reward=0.952, eps=0.05
# total_iter=158368, delta_iteration=200, games=1, mean reward=0.953, eps=0.05
# total_iter=158568, delta_iteration=200, games=1, mean reward=0.954, eps=0.05
# total_iter=158768, delta_iteration=200, games=1, mean reward=0.956, eps=0.05
# total_iter=158968, delta_iteration=200, games=1, mean reward=0.958, eps=0.05
# total_iter=159168, delta_iteration=200, games=1, mean reward=0.959, eps=0.05
# total_iter=159368, delta_iteration=200, games=1, mean reward=0.959, eps=0.05
# total_iter=160358, delta_iteration=990, games=5, mean reward=0.962, eps=0.05
# total_iter=160909, delta_iteration=551, games=3, mean reward=0.963, eps=0.05
# total_iter=161109, delta_iteration=200, games=1, mean reward=0.965, eps=0.05
# total_iter=161509, delta_iteration=400, games=2, mean reward=0.967, eps=0.05
# total_iter=161709, delta_iteration=200, games=1, mean reward=0.968, eps=0.05
# total_iter=161909, delta_iteration=200, games=1, mean reward=0.971, eps=0.05
# total_iter=162509, delta_iteration=600, games=3, mean reward=0.971, eps=0.05
# total_iter=171709, delta_iteration=9200, games=46, mean reward=0.974, eps=0.05
# total_iter=171909, delta_iteration=200, games=1, mean reward=0.977, eps=0.05
# total_iter=172309, delta_iteration=400, games=2, mean reward=0.986, eps=0.05
# total_iter=172709, delta_iteration=400, games=2, mean reward=0.987, eps=0.05
# total_iter=173909, delta_iteration=1200, games=6, mean reward=0.993, eps=0.05

# %%
TEST_EPISODES = 100
#env = DiscreteOneHotWrapper(gym.make(DEFAULT_ENV_NAME)) #creating a new environment
total_steps = 0
total_rewards = 0
for i in range(TEST_EPISODES):
    reward, steps = agent.play_episode(net)
    #print('Episode: ',i,' Reward=', reward, ' Steps=', steps)
    total_steps += steps
    total_rewards += reward
print('Average reward=', total_rewards/TEST_EPISODES, ' Av. steps per episode = ', total_steps/TEST_EPISODES)
# Out:
# Average reward= 200.0  Av. steps per episode =  200.0

# %% [markdown]
# This chart shows the change in Epsilon and mean rewards through the iterations.
# ![](img/fig6-2.png)
