# %% [markdown]
# # Chapter 4 - The Cross Entropy Method
#
#
# ## Taxonomy of RL methods
#
# The cross-entropy method falls into the model-free and policy-based category of methods. These notions are new, so let's spend some time exploring them. All methods in RL can be classified into various aspects:
#
# * Model-free or model-based
# * Value-based or policy-based
# * On-policy or off-policy
#
# There are other ways that you can taxonomize RL methods, but for now we're interested in the preceding three.
# Let's define them, as your problem specifics can influence your decision on a particular method.
#
# The term **model-free** means that the method **doesn't build a model** of the environment or reward; it just directly connects observations to actions (or values that are related to actions). In other words, the agent takes current observations and does some computations on them, and the result is the action that it should take. In contrast, **model-based** methods try to **predict what the next observation and/ or reward will be**. Based on this prediction, the agent is trying to choose the best possible action to take, very often making such predictions multiple times to **look more and more steps into the future**.
#
# Both classes of methods have strong and weak sides, but usually pure **model-based methods are used in deterministic environments**, such as board games with strict rules. On the other hand, model-free methods are usually easier to train as it's hard to build good models of complex environments with rich observations.
#
# All of the methods described in this book are from the **model-free** category, as those methods have been the most active area of research for the past few years. Only recently have researchers started to mix the benefits from both worlds (for example, refer to DeepMind's papers on imagination in agents. This approach will be described in Chapter 17, Beyond Model-Free – Imagination).
#
# By looking from an other angle, **policy-based methods** are directly approximating the policy of the agent, that is, what **actions the agent should carry out at every step**. Policy is usually represented by **probability distribution over the available actions**.
#
# In contrast, the method could be **value-based**. In this case, instead of the probability of actions, the agent calculates the **value of every possible action** and chooses the action with the best value. Both of those families of methods are equally popular and we'll discuss value-based methods in the next part of the book. Policy methods will be the topic of part three.
#
# The third important classification of methods is on-policy versus off-policy. We'll discuss this distinction more in parts two and three of the book, but for now, it will be enough to explain **off-policy** as the ability of the method to **learn on old historical data** (obtained by a previous version of the agent or recorded by human demonstration or just seen by the same agent several episodes ago).
# So, our **cross-entropy method is model-free, policy-based, and on-policy**, which means the following:
#
# * It **doesn't build any model** of the environment; it just says to the agent what to do at every step
# * It **approximates the policy of the agent**
# * It requires **fresh data** obtained from the environment
#
# ## Practical cross-entropy
#
# The cross-entropy method description is split into two unequal parts: practical and theoretical.
# The practical part is intuitive in its nature, while the theoretical explanation of why cross-entropy works, and what's happening is more sophisticated.
# You may remember that the central, trickiest thing in RL is the agent, which is trying to accumulate as much total reward as possible by communicating with the environment. In practice, we follow a common ML approach and replace all of the complications of the agent with some kind of nonlinear trainable function, which maps the agent's input (observations from the environment) to some output. The details of the output that this function produces may depend on a particular method or a family of methods, as described in the previous section (such as value-based versus policy-based methods). As our cross-entropy method is policy-based, our **nonlinear function (neural network) produces policy**, which basically says for every observation which action the agent should take.
# ![](img/fig4-1.png)
#
#
# In practice, **policy** is usually represented as **probability distribution over actions**, which makes it very similar to a classification problem, with the amount of classes being equal to amount of actions we can carry out. This abstraction makes our agent very simple: it needs to pass an observation from the environment to the network, get probability distribution over actions, and **perform random sampling using probability distribution to get an action to carry out**. This random sampling adds randomness to our agent, which is a good thing, as at the beginning of the training when our weights are random, the agent behaves randomly. After the agent gets an action to issue, it fires the action to the environment and obtains the next observation and reward for the last action. Then the loop continues.
#
# During the agent's lifetime, its experience is present as **episodes**. Every episode is a **sequence of observations** that the agent has got from the environment, actions it has issued, and rewards for these actions. Imagine that our agent has played several such episodes. For every episode, we can calculate the total reward that the agent has claimed. It can be **discounted or not discounted**, but for simplicity, let's assume a discount factor of gamma = 1, which means just a sum of all local rewards for every episode. This total reward shows how good this episode was for the agent. Let's illustrate this with a diagram, which contains four episodes (note that different episodes have different values for Oi
# , ai , and ri ):
#
# ![](img/fig4-2.png)
#
# Every cell represents the agent's step in the episode. Due to randomness in the environment and the way that the agent selects actions to take, some episodes will be better than others. **The core of the cross-entropy method is to throw away bad episodes and train on better ones**. So, the steps of the method are as follows:
#
# 1. Play **N number of episodes** using our current model and environment.
# 2. Calculate the total **reward for every episode** and decide on a reward boundary. Usually, we use some percentile of all rewards, such as 50th or 70th.
# 3. Throw away all episodes with a reward below the boundary.
# 4. **Train on the remaining "elite" episodes** using observations as the input and issued actions as the desired output.
# 5. Repeat from step 1 until we become satisfied with the result.
#
# So, that's all about the cross-entropy method description. With the preceding procedure, **our neural network learns how to repeat actions, which leads to a larger reward**, constantly moving the boundary higher and higher. Despite the simplicity of this method, it works well in simple environments, it's easy to implement, and it's quite robust to hyperparameters changing, which makes it an ideal baseline method to try. Let's now apply it to our CartPole environment.
#
# ## Cross-entropy on CartPole
# The whole code for this example is in ``Chapter04/01_cartpole.py``, but the following are the most important parts. Our model's core is a one-hidden-layer neural network, with ReLU and 128 hidden neurons (which is absolutely arbitrary). Other hyperparameters are also set almost randomly and aren't tuned, as the method is robust and converges very quickly.
#
# ### The  network
# * Input - a single observation from the environment as an input vector
# * Output- a number for every action we can perform -
#
# The output from the network is a probability distribution over actions, so a straightforward way to proceed would be to include softmax nonlinearity after the last layer. However, in the preceding network we don't apply softmax to increase the numerical stability of the training process. Rather than calculating softmax (which uses exponentiation) and then calculating cross-entropy loss (which uses logarithm of probabilities), we'll use the PyTorch class, ``nn.CrossEntropyLoss``, which **combines both softmax and cross-entropy** in a single, more numerically stable expression. CrossEntropyLoss requires raw, unnormalized values from the network (also called logits), and the downside of this is that we need to remember to apply softmax every time we need to get probabilities from our network's output.

# %%
#!/usr/bin/env python3
import gym  #for environment simulation - CartPole
from collections import namedtuple #for helper clases (namedtuple)
import numpy as np
from tensorboardX import SummaryWriter #to allow loging into tensor board

import torch
import torch.nn as nn
import torch.optim as optim



#Creating a Net class that inherits nn.Module class
class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)

HIDDEN_SIZE = 128 #Hidden layer size
BATCH_SIZE = 16
PERCENTILE = 70 #70th percentile - 30% of episodes sorte by reward 

#Creating helper clasess which are named tupled
#Episode represent one single step that our agent made in the episode. We'll use episode steps from elite episodes as training data.
Episode = namedtuple('Episode', field_names=['reward', 'steps']) 
#EpisodeStep is a single episode stored as total undiscounted reward and a collection of EpisodeStep
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])

# %% [markdown]
# ### The batch loop
# One very important fact to understand in this function logic is that the training of our network and the generation of our episodes are performed at the same time. They are not completely in parallel, but every time our loop accumulates enough episodes (16), it passes control to this function caller, which is supposed to train the network using the gradient descent. So, when yield is returned, the network will have different, slightly better (we hope) behavior.
# We don't need to explore proper synchronization, as our training and data gathering activities are performed at the same thread of execution, but you need to understand those constant jumps from network training to its utilization.

# %%
## Function to generate batches with episodes
#Our function is a generator, so every time the yield operator is executed,
#the control is transferred to the outer iteration loop and then continues after the yield line.
def iterate_batches(env, net, batch_size):
    batch = [] #create empyty list for batches
    episode_reward = 0.0 #initial reward
    episode_steps = [] #create empyty list for episode steps
    
    obs = env.reset() #resting the environment - return a list of 4 observed numbers
    sm = nn.Softmax(dim=1) #creating a softmax function 
    
    
    #Infinite loop
    while True:
        obs_v = torch.FloatTensor([obs]) #create a float tensor from the new observation - 1x4 tensor
        act_probs_v = sm(net(obs_v)) # execute the nn on the new observation and apply softmax on it
        act_probs = act_probs_v.data.numpy()[0] #Obtain the action probablities by accessing the output tensor data filed and create a numpy array from it
        action = np.random.choice(len(act_probs), p=act_probs) #select the action (number btwn 0 - n) by sampling from the return probablities
        next_obs, reward, is_done, _ = env.step(action) #making the next step in the enviroment with the selected action
        episode_reward += reward #incrementing the episode reward with the reurned rewars
        episode_steps.append(EpisodeStep(observation=obs, action=action)) #append the the  episode step with the current obs and reward and not those returned as the next ones.
        
        #when the eppisodes ends - the episode ends when the stick has fallen down despite our efforts
        if is_done: #if the episode is done (As returned from the environment)
            batch.append(Episode(reward=episode_reward, steps=episode_steps)) #append the entire episode
            episode_reward = 0.0 #reset the episode rewards
            episode_steps = [] #create empyty list for episode steps
            next_obs = env.reset() #reset the enviornmnet
            if len(batch) == batch_size: 
                yield batch #return the currnt batch as a generator
                batch = [] #reset the batch
        obs = next_obs #assign next_obs to obs

# %% [markdown]
# ### Filter batch function
# This function is at the **core of the cross-entropy method**: from the given batch of episodes and percentile value, it calculates a boundary reward, which is used to filter elite episodes to train on. To obtain the boundary reward, we're using NumPy's percentile function, which from the list of values and the desired percentile, calculates the percentile's value. Then we will calculate mean reward, which is used only for monitoring.

# %%
#filters the batches to yield only the top best eposidoe above a given percentile
def filter_batch(batch, percentile):
    rewards = list(map(lambda s: s.reward, batch)) #for each episode in the batch, extract the rewards
    #print('rewards:', rewards)
    reward_bound = np.percentile(rewards, percentile) #claulate prentiles for all rewards in the batch 
    reward_mean = float(np.mean(rewards)) #calcualte the rewards mean

    train_obs = []
    train_act = []

    #Filter off our episodes. For every episode in the batch,
    #we will check that the episode has a higher total reward than our boundary and if it has,
    #we will populate lists of observations and actions that we will train on.
    #This code will reject 70% of the episodes and 
    for example in batch:
        if example.reward < reward_bound: #non qualified episode
            #print('rejected reward=',example.reward)
            continue
        #else:
            #print('accepted reward=',example.reward)

        #Accumilating steps only from qualifed episodes
        train_obs.extend(map(lambda step: step.observation, example.steps)) #append the qualified eppisode's observations
        train_act.extend(map(lambda step: step.action, example.steps))  #append the qualifiedd eppisode's actions

    train_obs_v = torch.FloatTensor(train_obs) #create a tenso rof the observations
    train_act_v = torch.LongTensor(train_act) #create a tensor of the actions
    return train_obs_v, train_act_v, reward_bound, reward_mean

# %% [markdown]
# ### Main code
#
# In the beginning, we will create all the required objects: the environment, our neural network, the objective function, the optimizer, and the summary writer for TensorBoard. The commented line creates a monitor to write videos of your agent's performance.
#
# In the training loop, we will iterate our batches (which are a list of Episode objects), then we perform filtering of the elite episodes using the filter_batch function. The result is variables of observations and taken actions, the reward boundary used for filtering and the mean reward. After that, we zero gradients of our network and pass observations to the network, obtaining its action scores. These scores are passed to the objective function, which calculates cross-entropy between the network output and the actions that the agent took. The idea of this is to reinforce our network to carry out those "elite" actions which have led to good rewards. Then, we will calculate gradients on the loss and ask the optimizer to adjust our network.

# %%
HIDDEN_SIZE = 128 #Hidden layer size
BATCH_SIZE = 16 #episods per batch
PERCENTILE = 70 #70th percentile - 30% of episodes sorte by reward 

if __name__ == "__main__":
    env = gym.make("CartPole-v0") #Initialize the env that is sourced from the gym package
    # env = gym.wrappers.Monitor(env, directory="mon", force=True) - 
    obs_size = env.observation_space.shape[0] #Get the observation size - 4 in the case of CartPole
    n_actions = env.action_space.n  # 2 actions (left, right) in the case of CartPole

    net = Net(obs_size, HIDDEN_SIZE, n_actions) #Create the nn from the Net class with input size = obs_size and output size = n_actions
            # Net(
            #   (net): Sequential(
            #     (0): Linear(in_features=4, out_features=128, bias=True)
            #     (1): ReLU()
            #     (2): Linear(in_features=128, out_features=2, bias=True)
            #   )
            # )
    objective = nn.CrossEntropyLoss() #populate the objective function to be CrossEntropy_Loss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.01) #Set the Optimizer to be Adam
    writer = SummaryWriter(comment="-cartpole") #intialize the logs for the tensorboard

    #This is the main loop for the nn training
    #==========================================
    #It loops of the generstor that is returned from the iterate_batches() function
    #Each bacth includes BATCH_SIZE episodes
    for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)): #iterate_batch returns the iteration number and the list of episods oas named-tuples
        obs_v, acts_v, reward_b, reward_m = filter_batch(batch, PERCENTILE) #Obtain the filter (top 30%) episodeds
        #obs_v - tensor of n x 4 of all observation - n is the number of all accumlated observation of the qualified episodes
        #acts_v - array of n actions (0 or 1)
        #reward_b - reward threshold that represnet the 70% perecntile for the bacth
        #reward_m - mean reward for the batch 
        
        optimizer.zero_grad() #Reset the gradient for the optimizer
        action_scores_v = net(obs_v) #Generate predited actions by applying the nn on all the batch's observations and getting the actions scores
                                     #action_scores_v is a tensor of shape n 2 (2 actions)
        loss_v = objective(action_scores_v, acts_v)  #calculating the loss by Cross Entropy between the current net output and the actual taken action
        loss_v.backward() #run back propagation
        loss_v.backward() #run back propagation
        optimizer.step() #run optimization 
        print("%d: loss=%.3f, reward_mean=%.1f, reward_bound=%.1f" % (
            iter_no, loss_v.item(), reward_m, reward_b)) #Print results 
        writer.add_scalar("loss", loss_v.item(), iter_no) #Add the loss as scallar to the tensorboard log
        writer.add_scalar("reward_bound", reward_b, iter_no) #Add  the reward_bound as scallar to the tensorboard log
        writer.add_scalar("reward_mean", reward_m, iter_no) #Add  the reward_mean as scallar to the tensorboard log
        if reward_m > 50: # > 199: #stop the loop if the mean reward has reached 199
            print("Solved!")
            break
    writer.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# 0: loss=0.680, reward_mean=22.6, reward_bound=21.0
# 1: loss=0.662, reward_mean=26.9, reward_bound=30.5
# 2: loss=0.660, reward_mean=34.2, reward_bound=36.5
# 3: loss=0.639, reward_mean=34.6, reward_bound=35.5
# 4: loss=0.651, reward_mean=43.2, reward_bound=47.0
# 5: loss=0.627, reward_mean=46.8, reward_bound=54.0
# 6: loss=0.632, reward_mean=45.2, reward_bound=53.5
# 7: loss=0.627, reward_mean=47.1, reward_bound=56.0
# 8: loss=0.612, reward_mean=55.3, reward_bound=77.5
# Solved!

# %%
loss_v.storage_typ
# Out:
#  0.6115224361419678
# [torch.FloatStorage of size 1]

# %% [markdown]
# To view the tensorboad charts:
#  ``$ cd C:\Users\ilanr_000\OneDrive\Python\DeepRL\DeepRL``
#  ``$ tensorboard --logdir .\runs --host localhost``
#  Should see somthing like:
# ![](img/Tensorboard-fig-1.png)

# %% [markdown]
# ## Cross-entropy on FrozenLake
# The next environment we'll try to solve using the cross-entropy method is FrozenLake. Its world is from the so-called "grid world" category, when your agent lives in a grid of size 4 × 4 and can move in four directions: up, down, left, and right. The agent always starts at a top-left position, and its goal is to reach the bottom-right cell of the grid. There are holes in the fixed cells of the grid and if you get into those holes, the episode ends and your reward is zero. If the agent reaches the destination cell, then it obtains the reward 1.0 and the episode ends.
# To make life more complicated, the world is slippery (it's a frozen lake after all), so the agent's actions do not always turn out as expected: there is a 33% chance that it will slip to the right or to the left. You want the agent to move left, for example, but there is a 33% probability that it will indeed move left, a 33% chance that it will end up in the cell above, and a 33% chance that it will end up in the cell below. As we'll see at the end of the section, this makes progress difficult.
#
# ![](img/Fig5-1.png)
#
# ### Gym Environment for FrozenLake
#
# Our observation space is discrete, which means that it's just a number from zero to 15 inclusive. Obviously, this number is our current position in the grid. The action space is also discrete, but can be from zero to three. Our network from the CartPole example expects a vector of numbers. To get this, we can apply the traditional "one-hot encoding" of discrete inputs, which means that input to our network will have 16 float numbers and zero everywhere, except the index that we'll encode. To minimize changes in our code, we can use the ObservationWrapper class from Gym and implement our DiscreteOneHotWrapper class.
# With that wrapper applied to the environment, both the observation space and action space are 100% compatible with our CartPole solution (source code Chapter04/02_ frozenlake_naive.py). So we can use the same code as above.
# However, by launching it, we can see that this doesn't improve the score over time.
# To understand what's going on, we need to look deeper at the reward structure of both environments. In CartPole, every step of the environment gives us the reward 1.0, until the moment that the pole falls. So, the longer our agent balanced the pole, the more reward it obtained. Due to randomness in our agent's behavior, different episodes were of different lengths, which gave us a pretty normal distribution of the episodes' rewards. After choosing a reward boundary, we rejected less successful episodes and learned how to repeat better ones (by training on successful episodes' data).
# This is shown in the following diagram:
# ![](img/Fig7-1.png)
# In the FrozenLake environment, episodes and their reward look different. We get the reward of 1.0 only when we reach the goal, and this reward says nothing about how good each episode was. Was it quick and efficient or did we make four rounds on the lake before we randomly stepped into the final cell? We don't know, it's just 1.0 reward and that's it. The distribution of rewards for our episodes are also problematic. There are only two kinds of episodes possible, with zero reward (failed) and one reward (successful), and failed episodes will obviously dominate in the beginning of the training. So, our percentile selection of "elite" episodes is totally wrong and gives us bad examples to train on. This is the reason for our training failure.
# ![](img/Fig8-1.png)
# This example shows us the limitations of the cross-entropy method:
# * For training, our **episodes** have to be **finite** and, preferably, **short**
# * The total reward for the **episodes** should have enough **variability** to **separate good episodes from bad ones**
# * There is no **intermediate indication** about whether the agent has succeeded or failed
#
# Later in the book, we'll become familiar with other methods, which address these limitations. For now, if you're curious about how FrozenLake can be solved using cross-entropy, here is a list of tweaks of the code that you need to make (the full example is in Chapter04/03_frozenlake_tweaked.py):
#
# * **Larger batches of played episodes:** In CartPole, it was enough to have 16 episodes on every iteration, but FrozenLake requires at least 100 just to get some successful episodes.
# * **Discount factor applied to reward:** To make the total reward for the episode depend on episode length, and add variety in episodes, we can use a discounted total reward with the discount factor 0.9 or 0.95. In this case, the reward for shorter episodes will be higher than the reward for longer ones.
# * **Keeping "elite" episodes for a longer time:** In the CartPole training, we sampled episodes from the environment, trained on the best ones, and threw them away. In FrozenLake, a successful episode is a much rarer animal, so we need to keep them for several iterations to train on them.
# * **Decrease learning rate:** This will give our network time to average more training samples.
# * **Much longer training time:** Due to the sparsity of successful episodes, and the random outcome of our actions, it's much harder for our network to get an idea of the best behavior to perform in any particular situation. To reach 50% successful episodes, about 5k training iterations are required.
#
# To incorporate all these into our code, we need to change the filter_batch function to calculate discounted reward and return "elite" episodes for us to keep:

# %%
#!/usr/bin/env python3
import random
import gym, gym.spaces
from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim



e = gym.make("FrozenLake-v0") #Creating a new Frozen Lake environment 
e.observation_space #Discrete(16) - one of the 16 possible poistions for the agent on a 4x4 grid
e.action_space #Discrete(4) - 4 possible directions: 0 to 3  the agent can move

e.reset() #reset the environment - output is 0 - intial position is top left corner of the grid
e.render() #renders the grid:(s - start, F-Free cell, H - hole, G - Goal)
# SFFF  
# FHFH
# FFFH
# HFFG
print(e.observation_space.n)

#Creating an heriting class from Gym's ObservationWraper class
#It converts the descrite inputs will have 16 float numbers, zero everywhere, except the currenl loction of the agent (as float 1)
class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res


#Creating a Net class that inherits nn.Module class
class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)

    
#==================================================================================================================
## Function to generate batches with episodes
#Our function is a generator, so every time the yield operator is executed,
#the control is transferred to the outer iteration loop and then continues after the yield line.
def iterate_batches(env, net, batch_size):
    batch = [] #create empyty list for batches
    episode_reward = 0.0 #initial reward
    episode_steps = [] #create empyty list for episode steps
    
    obs = env.reset() #resting the environment - return a list of 4 observed numbers
    sm = nn.Softmax(dim=1) #creating a softmax function 
    
    
    #Infinite loop
    while True:
        obs_v = torch.FloatTensor([obs]) #create a float tensor from the new observation - 1x16 tensor with theobserved loction of the tensor
        act_probs_v = sm(net(obs_v)) # execute the nn on the new observation and apply softmax on it
        act_probs = act_probs_v.data.numpy()[0] #Obtain the action probablities by accessing the output tensor data filed and create a numpy array from it
        #print('act_probs=', act_probs)
        action = np.random.choice(len(act_probs), p=act_probs) #select the action (number btwn 0 - n) by sampling from the return probablities
        #print('action=',action)
        next_obs, reward, is_done, _ = env.step(action) #making the next step on the enviroment with the selected action
        episode_reward += reward #incrementing the episode reward with the reurned rewars
        episode_steps.append(EpisodeStep(observation=obs, action=action)) #append the the  episode step with the current obs and reward and not those returned as the next ones.
        
        #when the eppisodes ends - the episode ends when the stick has fallen down despite our efforts
        if is_done: #if the episode is done (As returned from the environment)
            batch.append(Episode(reward=episode_reward, steps=episode_steps)) #append the entire episode results
            episode_reward = 0.0 #reset the episode rewards
            episode_steps = [] #create empyty list for episode steps
            next_obs = env.reset() #reset the enviornmnet
            if len(batch) == batch_size: #if max number of episodes have been executed
                yield batch #return the currnt batch as a generator
                batch = [] #reset the batch
        obs = next_obs #assign next_obs to obs

#==================================================================================================================

#filters the batches to yield only the top best eposidoe above a given percentile
def filter_batch(batch, percentile):
    disc_rewards = list(map(lambda s: s.reward * (GAMMA ** len(s.steps)), batch)) #for each episode in the batch, extract the rewards - here we also add Gamma for the discount rate
    #print('Disc rewards:', disc_rewards)
    reward_bound = np.percentile(disc_rewards, percentile) #claulate prentiles for all rewards in the batch 
    #print('reward bound=',  reward_bound)
    #reward_mean = float(np.mean(disc_rewards)) #calcualte the rewards mean

    train_obs = []
    train_act = []
    elite_batch = []

    #Filter off our episodes. For every episode in the batch,
    #we will check that the episode has a higher total reward than our boundary and if it has,
    #we will populate lists of observations and actions that we will train on.
    #This code will reject 70% of the episodes and 
    for example, discounted_reward in zip(batch, disc_rewards):
        #print('discounted_reward=', discounted_reward,' reward bound=',  reward_bound)
        if discounted_reward > reward_bound:
            train_obs.extend(map(lambda step: step.observation, example.steps))
            train_act.extend(map(lambda step: step.action, example.steps))
            elite_batch.append(example)

    return elite_batch, train_obs, train_act, reward_bound

HIDDEN_SIZE = 128 #Hidden layer size
BATCH_SIZE = 100 #batch size - number of episodes in a single batch
PERCENTILE = 5 #5th percentile - 30% of episodes sorte by reward 
GAMMA = 0.95 #Reward discount rate
MAX_MEAN_REWARD = 0.8

#Creating helper clasess which are named tupled
#Episode represent one single step that our agent made in the episode. We'll use episode steps from elite episodes as training data.
Episode = namedtuple('Episode', field_names=['reward', 'steps']) 
#EpisodeStep is a single episode stored as total undiscounted reward and a collection of EpisodeStep
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])


if __name__ == "__main__":
    random.seed(12345)
    env = DiscreteOneHotWrapper(gym.make("FrozenLake-v0")) #Initialize the env that is sourced from the gym package with a wraper to conver inputs and outputs
    # env = gym.wrappers.Monitor(env, directory="mon", force=True) - 
    obs_size = env.observation_space.shape[0] #Get the observation size - 16 in the case of FrozenLake
    n_actions = env.action_space.n  # 4 actions (left, right, up, down) in the case of FrozenLake

    net = Net(obs_size, HIDDEN_SIZE, n_actions) #Create the nn from the Net class with input size = obs_size and output size = n_actions
        # Net(
        #   (net): Sequential(
        #     (0): Linear(in_features=16, out_features=128, bias=True)
        #     (1): ReLU()
        #     (2): Linear(in_features=128, out_features=4, bias=True)
        #   )
        # )    

    objective = nn.CrossEntropyLoss() #populate the objective function to be CrossEntropy_Loss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.001) #Set the Optimizer to be Adam
    writer = SummaryWriter(comment="-frozenlake-tweaked") #intialize the logs for the tensorboard
    
    full_batch = []

    #This is the main loop for the nn training
    #==========================================
    #It loops of the generstor that is returned from the iterate_batches() function
    #Each bacth includes BATCH_SIZE episodes
    for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)): #iterate_batch returns the iteration number and the list of episods oas named-tuples
        reward_mean = float(np.mean(list(map(lambda s: s.reward, batch)))) #extratc the rewar and claulate  mean reward for all episodes the batch 
        full_batch, obs, acts, reward_bound = filter_batch(full_batch + batch, PERCENTILE) #Obtain the filter (top 30%) episodeds
        #reward_b - reward threshold that represnet the PERCENTILE perecntile for the bacth
        #print('filtered batch length=', len(acts),'length full batch=',len(full_batch))
        if not full_batch:
            continue
        
        obs_v = torch.FloatTensor(obs) #tensor of n x 16 of all observation - n is the number of all accumlated observation of the qualified episodes
        acts_v = torch.LongTensor(acts)  #acts_v - tensor of n actions (0 or 1,2,3)
        full_batch = full_batch[-500:]
        
        ## NN Retraining
        ##==============
        optimizer.zero_grad() #Reset the gradient for the optimizer
        #print('obs_v length=', len(obs_v),)
        action_scores_v = net(obs_v) #Generate predited actions by applying the nn on all the commulative batch's observations and getting the actions scores
                                     #action_scores_v is a tensor of shape n x 2 (2 actions)
        loss_v = objective(action_scores_v, acts_v) #calculating the loss by Cross Entropy between the current net output and the actual taken action
        loss_v.backward() #run back propagation
        optimizer.step() #run optimization 
        
        print("%d: loss=%.3f, reward_mean=%.3f, reward_bound=%.3f, batch=%d" % (
            iter_no, loss_v.item(), reward_mean, reward_bound, len(full_batch))) #Print results 
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_mean", reward_mean, iter_no)
        writer.add_scalar("reward_bound", reward_bound, iter_no)
#        if True: #reward_mean > 0.8: #stop the loop if the mean reward has reached 0.8
        if reward_mean > MAX_MEAN_REWARD: #stop the loop if the mean reward has reached 0.8
            print("Solved!")
            break
    writer.close()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# 16
# 0: loss=1.388, reward_mean=0.020, reward_bound=0.000, batch=2
# 1: loss=1.375, reward_mean=0.020, reward_bound=0.000, batch=4
# 2: loss=1.380, reward_mean=0.020, reward_bound=0.000, batch=6
# 3: loss=1.378, reward_mean=0.000, reward_bound=0.000, batch=6
# 4: loss=1.373, reward_mean=0.010, reward_bound=0.000, batch=7
# 5: loss=1.371, reward_mean=0.000, reward_bound=0.000, batch=7
# 6: loss=1.365, reward_mean=0.010, reward_bound=0.000, batch=8
# 7: loss=1.362, reward_mean=0.010, reward_bound=0.000, batch=9
# 8: loss=1.366, reward_mean=0.010, reward_bound=0.000, batch=10
# 9: loss=1.369, reward_mean=0.010, reward_bound=0.000, batch=11
# 10: loss=1.368, reward_mean=0.000, reward_bound=0.000, batch=11
# 11: loss=1.365, reward_mean=0.030, reward_bound=0.000, batch=14
# 12: loss=1.364, reward_mean=0.000, reward_bound=0.000, batch=14
# 13: loss=1.363, reward_mean=0.020, reward_bound=0.000, batch=16
# 14: loss=1.363, reward_mean=0.010, reward_bound=0.000, batch=17
# 15: loss=1.360, reward_mean=0.010, reward_bound=0.000, batch=18
# 16: loss=1.358, reward_mean=0.000, reward_bound=0.000, batch=18
# 17: loss=1.356, reward_mean=0.000, reward_bound=0.000, batch=18
# 18: loss=1.354, reward_mean=0.000, reward_bound=0.000, batch=18
# 19: loss=1.354, reward_mean=0.020, reward_bound=0.000, batch=20
# 20: loss=1.352, reward_mean=0.000, reward_bound=0.000, batch=20
# 21: loss=1.353, reward_mean=0.010, reward_bound=0.000, batch=21
# 22: loss=1.352, reward_mean=0.000, reward_bound=0.000, batch=21
# 23: loss=1.349, reward_mean=0.010, reward_bound=0.000, batch=22
# 24: loss=1.348, reward_mean=0.010, reward_bound=0.000, batch=23
# 25: loss=1.349, reward_mean=0.030, reward_bound=0.000, batch=26
# 26: loss=1.349, reward_mean=0.020, reward_bound=0.000, batch=28
# 27: loss=1.347, reward_mean=0.010, reward_bound=0.000, batch=29
# 28: loss=1.346, reward_mean=0.000, reward_bound=0.000, batch=29
# 29: loss=1.342, reward_mean=0.010, reward_bound=0.000, batch=30
# 30: loss=1.342, reward_mean=0.010, reward_bound=0.000, batch=31
# 31: loss=1.340, reward_mean=0.020, reward_bound=0.000, batch=33
# 32: loss=1.339, reward_mean=0.010, reward_bound=0.000, batch=34
# 33: loss=1.338, reward_mean=0.020, reward_bound=0.000, batch=36
# 34: loss=1.340, reward_mean=0.020, reward_bound=0.000, batch=38
# 35: loss=1.339, reward_mean=0.020, reward_bound=0.000, batch=40
# 36: loss=1.337, reward_mean=0.030, reward_bound=0.000, batch=43
# 37: loss=1.336, reward_mean=0.020, reward_bound=0.000, batch=45
# 38: loss=1.336, reward_mean=0.020, reward_bound=0.000, batch=47
# 39: loss=1.335, reward_mean=0.040, reward_bound=0.000, batch=51
# 40: loss=1.335, reward_mean=0.040, reward_bound=0.000, batch=55
# 41: loss=1.334, reward_mean=0.000, reward_bound=0.000, batch=55
# 42: loss=1.334, reward_mean=0.000, reward_bound=0.000, batch=55
# 43: loss=1.333, reward_mean=0.000, reward_bound=0.000, batch=55
# 44: loss=1.331, reward_mean=0.010, reward_bound=0.000, batch=56
# 45: loss=1.332, reward_mean=0.010, reward_bound=0.000, batch=57
# 46: loss=1.333, reward_mean=0.020, reward_bound=0.000, batch=59
# 47: loss=1.332, reward_mean=0.010, reward_bound=0.000, batch=60
# 48: loss=1.332, reward_mean=0.030, reward_bound=0.000, batch=63
# 49: loss=1.330, reward_mean=0.020, reward_bound=0.000, batch=65
# 50: loss=1.329, reward_mean=0.000, reward_bound=0.000, batch=65
# 51: loss=1.330, reward_mean=0.020, reward_bound=0.000, batch=67
# 52: loss=1.328, reward_mean=0.030, reward_bound=0.000, batch=70
# 53: loss=1.328, reward_mean=0.000, reward_bound=0.000, batch=70
# 54: loss=1.327, reward_mean=0.020, reward_bound=0.000, batch=72
# 55: loss=1.328, reward_mean=0.030, reward_bound=0.000, batch=75
# 56: loss=1.329, reward_mean=0.030, reward_bound=0.000, batch=78
# 57: loss=1.326, reward_mean=0.020, reward_bound=0.000, batch=80
# 58: loss=1.326, reward_mean=0.020, reward_bound=0.000, batch=82
# 59: loss=1.324, reward_mean=0.040, reward_bound=0.000, batch=86
# 60: loss=1.324, reward_mean=0.020, reward_bound=0.000, batch=88
# 61: loss=1.322, reward_mean=0.020, reward_bound=0.000, batch=90
# 62: loss=1.322, reward_mean=0.020, reward_bound=0.000, batch=92
# 63: loss=1.321, reward_mean=0.040, reward_bound=0.000, batch=96
# 64: loss=1.321, reward_mean=0.010, reward_bound=0.000, batch=97
# 65: loss=1.320, reward_mean=0.030, reward_bound=0.000, batch=100
# 66: loss=1.319, reward_mean=0.030, reward_bound=0.000, batch=103
# 67: loss=1.318, reward_mean=0.040, reward_bound=0.000, batch=107
# 68: loss=1.317, reward_mean=0.010, reward_bound=0.000, batch=108
# 69: loss=1.316, reward_mean=0.050, reward_bound=0.000, batch=113
# 70: loss=1.315, reward_mean=0.040, reward_bound=0.000, batch=117
# 71: loss=1.312, reward_mean=0.030, reward_bound=0.000, batch=120
# 72: loss=1.310, reward_mean=0.040, reward_bound=0.000, batch=124
# 73: loss=1.311, reward_mean=0.030, reward_bound=0.000, batch=127
# 74: loss=1.309, reward_mean=0.010, reward_bound=0.000, batch=128
# 75: loss=1.308, reward_mean=0.020, reward_bound=0.000, batch=130
# 76: loss=1.308, reward_mean=0.050, reward_bound=0.000, batch=135
# 77: loss=1.307, reward_mean=0.030, reward_bound=0.000, batch=138
# 78: loss=1.307, reward_mean=0.010, reward_bound=0.000, batch=139
# 79: loss=1.305, reward_mean=0.040, reward_bound=0.000, batch=143
# 80: loss=1.305, reward_mean=0.020, reward_bound=0.000, batch=145
# 81: loss=1.305, reward_mean=0.010, reward_bound=0.000, batch=146
# 82: loss=1.304, reward_mean=0.010, reward_bound=0.000, batch=147
# 83: loss=1.305, reward_mean=0.040, reward_bound=0.000, batch=151
# 84: loss=1.304, reward_mean=0.010, reward_bound=0.000, batch=152
# 85: loss=1.302, reward_mean=0.020, reward_bound=0.000, batch=154
# 86: loss=1.301, reward_mean=0.030, reward_bound=0.000, batch=157
# 87: loss=1.300, reward_mean=0.050, reward_bound=0.000, batch=162
# 88: loss=1.299, reward_mean=0.030, reward_bound=0.000, batch=165
# 89: loss=1.299, reward_mean=0.010, reward_bound=0.000, batch=166
# 90: loss=1.298, reward_mean=0.020, reward_bound=0.000, batch=168
# 91: loss=1.297, reward_mean=0.040, reward_bound=0.000, batch=172
# 92: loss=1.297, reward_mean=0.040, reward_bound=0.000, batch=176
# 93: loss=1.295, reward_mean=0.040, reward_bound=0.000, batch=180
# 94: loss=1.295, reward_mean=0.060, reward_bound=0.000, batch=186
# 95: loss=1.294, reward_mean=0.050, reward_bound=0.000, batch=191
# 96: loss=1.291, reward_mean=0.060, reward_bound=0.000, batch=197
# 97: loss=1.291, reward_mean=0.010, reward_bound=0.000, batch=198
# 98: loss=1.291, reward_mean=0.020, reward_bound=0.000, batch=200
# 99: loss=1.290, reward_mean=0.030, reward_bound=0.000, batch=203
# 100: loss=1.289, reward_mean=0.050, reward_bound=0.000, batch=208
# 101: loss=1.288, reward_mean=0.070, reward_bound=0.000, batch=215
# 102: loss=1.288, reward_mean=0.040, reward_bound=0.000, batch=219
# 103: loss=1.288, reward_mean=0.050, reward_bound=0.000, batch=224
# 104: loss=1.287, reward_mean=0.040, reward_bound=0.000, batch=228
# 105: loss=1.286, reward_mean=0.040, reward_bound=0.000, batch=232
# 106: loss=1.285, reward_mean=0.050, reward_bound=0.000, batch=237
# 107: loss=1.285, reward_mean=0.030, reward_bound=0.000, batch=240
# 108: loss=1.284, reward_mean=0.080, reward_bound=0.000, batch=248
# 109: loss=1.283, reward_mean=0.030, reward_bound=0.000, batch=251
# 110: loss=1.280, reward_mean=0.050, reward_bound=0.000, batch=256
# 111: loss=1.280, reward_mean=0.010, reward_bound=0.000, batch=257
# 112: loss=1.280, reward_mean=0.050, reward_bound=0.000, batch=262
# 113: loss=1.280, reward_mean=0.020, reward_bound=0.000, batch=264
# 114: loss=1.279, reward_mean=0.010, reward_bound=0.000, batch=265
# 115: loss=1.279, reward_mean=0.010, reward_bound=0.000, batch=266
# 116: loss=1.280, reward_mean=0.050, reward_bound=0.000, batch=271
# 117: loss=1.280, reward_mean=0.030, reward_bound=0.000, batch=274
# 118: loss=1.280, reward_mean=0.010, reward_bound=0.000, batch=275
# 119: loss=1.280, reward_mean=0.020, reward_bound=0.000, batch=277
# 120: loss=1.279, reward_mean=0.010, reward_bound=0.000, batch=278
# 121: loss=1.278, reward_mean=0.030, reward_bound=0.000, batch=281
# 122: loss=1.277, reward_mean=0.030, reward_bound=0.000, batch=284
# 123: loss=1.277, reward_mean=0.050, reward_bound=0.000, batch=289
# 124: loss=1.276, reward_mean=0.040, reward_bound=0.000, batch=293
# 125: loss=1.275, reward_mean=0.030, reward_bound=0.000, batch=296
# 126: loss=1.274, reward_mean=0.050, reward_bound=0.000, batch=301
# 127: loss=1.274, reward_mean=0.030, reward_bound=0.000, batch=304
# 128: loss=1.272, reward_mean=0.060, reward_bound=0.000, batch=310
# 129: loss=1.271, reward_mean=0.050, reward_bound=0.000, batch=315
# 130: loss=1.271, reward_mean=0.040, reward_bound=0.000, batch=319
# 131: loss=1.270, reward_mean=0.070, reward_bound=0.000, batch=326
# 132: loss=1.270, reward_mean=0.020, reward_bound=0.000, batch=328
# 133: loss=1.268, reward_mean=0.050, reward_bound=0.000, batch=333
# 134: loss=1.268, reward_mean=0.070, reward_bound=0.000, batch=340
# 135: loss=1.267, reward_mean=0.040, reward_bound=0.000, batch=344
# 136: loss=1.266, reward_mean=0.040, reward_bound=0.000, batch=348
# 137: loss=1.264, reward_mean=0.070, reward_bound=0.000, batch=355
# 138: loss=1.264, reward_mean=0.020, reward_bound=0.000, batch=357
# 139: loss=1.264, reward_mean=0.040, reward_bound=0.000, batch=361
# 140: loss=1.263, reward_mean=0.020, reward_bound=0.000, batch=363
# 141: loss=1.262, reward_mean=0.050, reward_bound=0.000, batch=368
# 142: loss=1.262, reward_mean=0.020, reward_bound=0.000, batch=370
# 143: loss=1.261, reward_mean=0.070, reward_bound=0.000, batch=377
# 144: loss=1.260, reward_mean=0.020, reward_bound=0.000, batch=379
# 145: loss=1.259, reward_mean=0.050, reward_bound=0.000, batch=384
# 146: loss=1.260, reward_mean=0.030, reward_bound=0.000, batch=387
# 147: loss=1.259, reward_mean=0.040, reward_bound=0.000, batch=391
# 148: loss=1.258, reward_mean=0.020, reward_bound=0.000, batch=393
# 149: loss=1.258, reward_mean=0.040, reward_bound=0.000, batch=397
# 150: loss=1.258, reward_mean=0.030, reward_bound=0.000, batch=400
# 151: loss=1.257, reward_mean=0.050, reward_bound=0.000, batch=405
# 152: loss=1.256, reward_mean=0.030, reward_bound=0.000, batch=408
# 153: loss=1.255, reward_mean=0.030, reward_bound=0.000, batch=411
# 154: loss=1.254, reward_mean=0.060, reward_bound=0.000, batch=417
# 155: loss=1.255, reward_mean=0.060, reward_bound=0.000, batch=423
# 156: loss=1.254, reward_mean=0.030, reward_bound=0.000, batch=426
# 157: loss=1.254, reward_mean=0.050, reward_bound=0.000, batch=431
# 158: loss=1.253, reward_mean=0.070, reward_bound=0.000, batch=438
# 159: loss=1.251, reward_mean=0.050, reward_bound=0.000, batch=443
# 160: loss=1.251, reward_mean=0.020, reward_bound=0.000, batch=445
# 161: loss=1.250, reward_mean=0.050, reward_bound=0.000, batch=450
# 162: loss=1.250, reward_mean=0.060, reward_bound=0.000, batch=456
# 163: loss=1.250, reward_mean=0.050, reward_bound=0.000, batch=461
# 164: loss=1.249, reward_mean=0.060, reward_bound=0.000, batch=467
# 165: loss=1.248, reward_mean=0.030, reward_bound=0.000, batch=470
# 166: loss=1.246, reward_mean=0.080, reward_bound=0.000, batch=478
# 167: loss=1.246, reward_mean=0.040, reward_bound=0.000, batch=482
# 168: loss=1.245, reward_mean=0.030, reward_bound=0.000, batch=485
# 169: loss=1.245, reward_mean=0.040, reward_bound=0.000, batch=489
# 170: loss=1.246, reward_mean=0.030, reward_bound=0.000, batch=492
# 171: loss=1.245, reward_mean=0.050, reward_bound=0.000, batch=497
# 172: loss=1.245, reward_mean=0.030, reward_bound=0.000, batch=500
# 173: loss=1.245, reward_mean=0.060, reward_bound=0.000, batch=500
# 174: loss=1.244, reward_mean=0.040, reward_bound=0.000, batch=500
# 175: loss=1.242, reward_mean=0.050, reward_bound=0.000, batch=500
# 176: loss=1.240, reward_mean=0.040, reward_bound=0.000, batch=500
# 177: loss=1.239, reward_mean=0.060, reward_bound=0.000, batch=500
# 178: loss=1.237, reward_mean=0.080, reward_bound=0.000, batch=500
# 179: loss=1.235, reward_mean=0.030, reward_bound=0.000, batch=500
# 180: loss=1.235, reward_mean=0.050, reward_bound=0.000, batch=500
# 181: loss=1.232, reward_mean=0.080, reward_bound=0.000, batch=500
# 182: loss=1.230, reward_mean=0.060, reward_bound=0.000, batch=500
# 183: loss=1.229, reward_mean=0.040, reward_bound=0.000, batch=500
# 184: loss=1.228, reward_mean=0.010, reward_bound=0.000, batch=500
# 185: loss=1.227, reward_mean=0.050, reward_bound=0.000, batch=500
# 186: loss=1.226, reward_mean=0.030, reward_bound=0.000, batch=500
# 187: loss=1.224, reward_mean=0.050, reward_bound=0.000, batch=500
# 188: loss=1.222, reward_mean=0.050, reward_bound=0.000, batch=500
# 189: loss=1.222, reward_mean=0.040, reward_bound=0.000, batch=500
# 190: loss=1.222, reward_mean=0.070, reward_bound=0.000, batch=500
# 191: loss=1.220, reward_mean=0.060, reward_bound=0.000, batch=500
# 192: loss=1.218, reward_mean=0.040, reward_bound=0.000, batch=500
# 193: loss=1.218, reward_mean=0.060, reward_bound=0.000, batch=500
# 194: loss=1.217, reward_mean=0.040, reward_bound=0.000, batch=500
# 195: loss=1.215, reward_mean=0.040, reward_bound=0.000, batch=500
# 196: loss=1.215, reward_mean=0.040, reward_bound=0.000, batch=500
# 197: loss=1.214, reward_mean=0.050, reward_bound=0.000, batch=500
# 198: loss=1.212, reward_mean=0.090, reward_bound=0.000, batch=500
# 199: loss=1.210, reward_mean=0.060, reward_bound=0.000, batch=500
# 200: loss=1.208, reward_mean=0.010, reward_bound=0.000, batch=500
# 201: loss=1.207, reward_mean=0.020, reward_bound=0.000, batch=500
# 202: loss=1.206, reward_mean=0.010, reward_bound=0.000, batch=500
# 203: loss=1.206, reward_mean=0.070, reward_bound=0.000, batch=500
# 204: loss=1.203, reward_mean=0.080, reward_bound=0.000, batch=500
# 205: loss=1.202, reward_mean=0.040, reward_bound=0.000, batch=500
# 206: loss=1.202, reward_mean=0.040, reward_bound=0.000, batch=500
# 207: loss=1.200, reward_mean=0.060, reward_bound=0.000, batch=500
# 208: loss=1.199, reward_mean=0.030, reward_bound=0.000, batch=500
# 209: loss=1.198, reward_mean=0.040, reward_bound=0.000, batch=500
# 210: loss=1.197, reward_mean=0.060, reward_bound=0.000, batch=500
# 211: loss=1.196, reward_mean=0.020, reward_bound=0.000, batch=500
# 212: loss=1.195, reward_mean=0.070, reward_bound=0.000, batch=500
# 213: loss=1.194, reward_mean=0.060, reward_bound=0.000, batch=500
# 214: loss=1.193, reward_mean=0.050, reward_bound=0.000, batch=500
# 215: loss=1.191, reward_mean=0.060, reward_bound=0.000, batch=500
# 216: loss=1.188, reward_mean=0.080, reward_bound=0.000, batch=500
# 217: loss=1.185, reward_mean=0.070, reward_bound=0.000, batch=500
# 218: loss=1.185, reward_mean=0.040, reward_bound=0.000, batch=500
# 219: loss=1.184, reward_mean=0.020, reward_bound=0.000, batch=500
# 220: loss=1.184, reward_mean=0.040, reward_bound=0.000, batch=500
# 221: loss=1.183, reward_mean=0.060, reward_bound=0.000, batch=500
# 222: loss=1.182, reward_mean=0.050, reward_bound=0.000, batch=500
# 223: loss=1.181, reward_mean=0.050, reward_bound=0.000, batch=500
# 224: loss=1.180, reward_mean=0.080, reward_bound=0.000, batch=500
# 225: loss=1.180, reward_mean=0.040, reward_bound=0.000, batch=500
# 226: loss=1.178, reward_mean=0.030, reward_bound=0.000, batch=500
# 227: loss=1.178, reward_mean=0.040, reward_bound=0.000, batch=500
# 228: loss=1.178, reward_mean=0.060, reward_bound=0.000, batch=500
# 229: loss=1.175, reward_mean=0.080, reward_bound=0.000, batch=500
# 230: loss=1.175, reward_mean=0.070, reward_bound=0.000, batch=500
# 231: loss=1.173, reward_mean=0.100, reward_bound=0.000, batch=500
# 232: loss=1.172, reward_mean=0.070, reward_bound=0.000, batch=500
# 233: loss=1.169, reward_mean=0.060, reward_bound=0.000, batch=500
# 234: loss=1.169, reward_mean=0.060, reward_bound=0.000, batch=500
# 235: loss=1.167, reward_mean=0.050, reward_bound=0.000, batch=500
# 236: loss=1.166, reward_mean=0.090, reward_bound=0.000, batch=500
# 237: loss=1.166, reward_mean=0.080, reward_bound=0.000, batch=500
# 238: loss=1.164, reward_mean=0.050, reward_bound=0.000, batch=500
# 239: loss=1.164, reward_mean=0.020, reward_bound=0.000, batch=500
# 240: loss=1.164, reward_mean=0.060, reward_bound=0.000, batch=500
# 241: loss=1.163, reward_mean=0.070, reward_bound=0.000, batch=500
# 242: loss=1.161, reward_mean=0.070, reward_bound=0.000, batch=500
# 243: loss=1.161, reward_mean=0.040, reward_bound=0.000, batch=500
# 244: loss=1.158, reward_mean=0.080, reward_bound=0.000, batch=500
# 245: loss=1.157, reward_mean=0.140, reward_bound=0.000, batch=500
# 246: loss=1.154, reward_mean=0.030, reward_bound=0.000, batch=500
# 247: loss=1.153, reward_mean=0.070, reward_bound=0.000, batch=500
# 248: loss=1.151, reward_mean=0.090, reward_bound=0.000, batch=500
# 249: loss=1.150, reward_mean=0.090, reward_bound=0.000, batch=500
# 250: loss=1.148, reward_mean=0.080, reward_bound=0.000, batch=500
# 251: loss=1.146, reward_mean=0.100, reward_bound=0.000, batch=500
# 252: loss=1.144, reward_mean=0.080, reward_bound=0.000, batch=500
# 253: loss=1.141, reward_mean=0.060, reward_bound=0.000, batch=500
# 254: loss=1.139, reward_mean=0.060, reward_bound=0.000, batch=500
# 255: loss=1.138, reward_mean=0.090, reward_bound=0.000, batch=500
# 256: loss=1.135, reward_mean=0.070, reward_bound=0.000, batch=500
# 257: loss=1.135, reward_mean=0.030, reward_bound=0.000, batch=500
# 258: loss=1.132, reward_mean=0.100, reward_bound=0.000, batch=500
# 259: loss=1.130, reward_mean=0.070, reward_bound=0.000, batch=500
# 260: loss=1.128, reward_mean=0.010, reward_bound=0.000, batch=500
# 261: loss=1.128, reward_mean=0.060, reward_bound=0.000, batch=500
# 262: loss=1.126, reward_mean=0.080, reward_bound=0.000, batch=500
# 263: loss=1.124, reward_mean=0.050, reward_bound=0.000, batch=500
# 264: loss=1.123, reward_mean=0.060, reward_bound=0.000, batch=500
# 265: loss=1.121, reward_mean=0.070, reward_bound=0.000, batch=500
# 266: loss=1.120, reward_mean=0.060, reward_bound=0.000, batch=500
# 267: loss=1.119, reward_mean=0.040, reward_bound=0.000, batch=500
# 268: loss=1.115, reward_mean=0.110, reward_bound=0.000, batch=500
# 269: loss=1.113, reward_mean=0.090, reward_bound=0.000, batch=500
# 270: loss=1.109, reward_mean=0.100, reward_bound=0.000, batch=500
# 271: loss=1.106, reward_mean=0.050, reward_bound=0.000, batch=500
# 272: loss=1.104, reward_mean=0.070, reward_bound=0.000, batch=500
# 273: loss=1.101, reward_mean=0.070, reward_bound=0.000, batch=500
# 274: loss=1.097, reward_mean=0.110, reward_bound=0.000, batch=500
# 275: loss=1.096, reward_mean=0.060, reward_bound=0.000, batch=500
# 276: loss=1.091, reward_mean=0.100, reward_bound=0.000, batch=500
# 277: loss=1.089, reward_mean=0.070, reward_bound=0.000, batch=500
# 278: loss=1.086, reward_mean=0.090, reward_bound=0.000, batch=500
# 279: loss=1.087, reward_mean=0.080, reward_bound=0.000, batch=500
# 280: loss=1.086, reward_mean=0.100, reward_bound=0.000, batch=500
# 281: loss=1.085, reward_mean=0.070, reward_bound=0.000, batch=500
# 282: loss=1.084, reward_mean=0.110, reward_bound=0.000, batch=500
# 283: loss=1.080, reward_mean=0.100, reward_bound=0.000, batch=500
# 284: loss=1.078, reward_mean=0.110, reward_bound=0.000, batch=500
# 285: loss=1.075, reward_mean=0.080, reward_bound=0.000, batch=500
# 286: loss=1.073, reward_mean=0.070, reward_bound=0.000, batch=500
# 287: loss=1.073, reward_mean=0.080, reward_bound=0.000, batch=500
# 288: loss=1.072, reward_mean=0.080, reward_bound=0.000, batch=500
# 289: loss=1.072, reward_mean=0.070, reward_bound=0.000, batch=500
# 290: loss=1.069, reward_mean=0.080, reward_bound=0.000, batch=500
# 291: loss=1.067, reward_mean=0.090, reward_bound=0.000, batch=500
# 292: loss=1.063, reward_mean=0.130, reward_bound=0.000, batch=500
# 293: loss=1.061, reward_mean=0.080, reward_bound=0.000, batch=500
# 294: loss=1.060, reward_mean=0.080, reward_bound=0.000, batch=500
# 295: loss=1.054, reward_mean=0.120, reward_bound=0.000, batch=500
# 296: loss=1.050, reward_mean=0.070, reward_bound=0.000, batch=500
# 297: loss=1.045, reward_mean=0.120, reward_bound=0.000, batch=500
# 298: loss=1.042, reward_mean=0.140, reward_bound=0.000, batch=500
# 299: loss=1.040, reward_mean=0.120, reward_bound=0.000, batch=500
# 300: loss=1.033, reward_mean=0.070, reward_bound=0.000, batch=500
# 301: loss=1.031, reward_mean=0.110, reward_bound=0.000, batch=500
# 302: loss=1.024, reward_mean=0.110, reward_bound=0.000, batch=500
# 303: loss=1.021, reward_mean=0.090, reward_bound=0.000, batch=500
# 304: loss=1.019, reward_mean=0.110, reward_bound=0.000, batch=500
# 305: loss=1.018, reward_mean=0.130, reward_bound=0.000, batch=500
# 306: loss=1.013, reward_mean=0.120, reward_bound=0.000, batch=500
# 307: loss=1.012, reward_mean=0.110, reward_bound=0.000, batch=500
# 308: loss=1.005, reward_mean=0.130, reward_bound=0.000, batch=500
# 309: loss=1.001, reward_mean=0.110, reward_bound=0.000, batch=500
# 310: loss=0.998, reward_mean=0.090, reward_bound=0.000, batch=500
# 311: loss=0.994, reward_mean=0.130, reward_bound=0.000, batch=500
# 312: loss=0.992, reward_mean=0.100, reward_bound=0.000, batch=500
# 313: loss=0.987, reward_mean=0.100, reward_bound=0.000, batch=500
# 314: loss=0.985, reward_mean=0.150, reward_bound=0.000, batch=500
# 315: loss=0.981, reward_mean=0.100, reward_bound=0.000, batch=500
# 316: loss=0.978, reward_mean=0.130, reward_bound=0.000, batch=500
# 317: loss=0.975, reward_mean=0.180, reward_bound=0.000, batch=500
# 318: loss=0.973, reward_mean=0.080, reward_bound=0.000, batch=500
# 319: loss=0.972, reward_mean=0.090, reward_bound=0.000, batch=500
# 320: loss=0.967, reward_mean=0.170, reward_bound=0.000, batch=500
# 321: loss=0.967, reward_mean=0.130, reward_bound=0.000, batch=500
# 322: loss=0.967, reward_mean=0.110, reward_bound=0.000, batch=500
# 323: loss=0.964, reward_mean=0.110, reward_bound=0.000, batch=500
# 324: loss=0.960, reward_mean=0.150, reward_bound=0.000, batch=500
# 325: loss=0.958, reward_mean=0.090, reward_bound=0.000, batch=500
# 326: loss=0.955, reward_mean=0.160, reward_bound=0.000, batch=500
# 327: loss=0.948, reward_mean=0.120, reward_bound=0.000, batch=500
# 328: loss=0.945, reward_mean=0.120, reward_bound=0.000, batch=500
# 329: loss=0.937, reward_mean=0.150, reward_bound=0.000, batch=500
# 330: loss=0.933, reward_mean=0.180, reward_bound=0.000, batch=500
# 331: loss=0.929, reward_mean=0.070, reward_bound=0.000, batch=500
# 332: loss=0.926, reward_mean=0.190, reward_bound=0.000, batch=500
# 333: loss=0.921, reward_mean=0.180, reward_bound=0.000, batch=500
# 334: loss=0.917, reward_mean=0.140, reward_bound=0.000, batch=500
# 335: loss=0.914, reward_mean=0.120, reward_bound=0.000, batch=500
# 336: loss=0.909, reward_mean=0.180, reward_bound=0.000, batch=500
# 337: loss=0.905, reward_mean=0.190, reward_bound=0.000, batch=500
# 338: loss=0.901, reward_mean=0.150, reward_bound=0.000, batch=500
# 339: loss=0.897, reward_mean=0.100, reward_bound=0.000, batch=500
# 340: loss=0.895, reward_mean=0.130, reward_bound=0.000, batch=500
# 341: loss=0.892, reward_mean=0.110, reward_bound=0.000, batch=500
# 342: loss=0.889, reward_mean=0.180, reward_bound=0.000, batch=500
# 343: loss=0.885, reward_mean=0.200, reward_bound=0.000, batch=500
# 344: loss=0.880, reward_mean=0.220, reward_bound=0.000, batch=500
# 345: loss=0.875, reward_mean=0.110, reward_bound=0.000, batch=500
# 346: loss=0.871, reward_mean=0.130, reward_bound=0.000, batch=500
# 347: loss=0.870, reward_mean=0.170, reward_bound=0.000, batch=500
# 348: loss=0.871, reward_mean=0.180, reward_bound=0.000, batch=500
# 349: loss=0.870, reward_mean=0.150, reward_bound=0.000, batch=500
# 350: loss=0.868, reward_mean=0.220, reward_bound=0.000, batch=500
# 351: loss=0.862, reward_mean=0.200, reward_bound=0.000, batch=500
# 352: loss=0.855, reward_mean=0.210, reward_bound=0.000, batch=500
# 353: loss=0.850, reward_mean=0.230, reward_bound=0.000, batch=500
# 354: loss=0.846, reward_mean=0.180, reward_bound=0.000, batch=500
# 355: loss=0.839, reward_mean=0.190, reward_bound=0.000, batch=500
# 356: loss=0.836, reward_mean=0.180, reward_bound=0.000, batch=500
# 357: loss=0.834, reward_mean=0.190, reward_bound=0.000, batch=500
# 358: loss=0.828, reward_mean=0.150, reward_bound=0.000, batch=500
# 359: loss=0.828, reward_mean=0.230, reward_bound=0.000, batch=500
# 360: loss=0.826, reward_mean=0.180, reward_bound=0.000, batch=500
# 361: loss=0.823, reward_mean=0.190, reward_bound=0.000, batch=500
# 362: loss=0.817, reward_mean=0.200, reward_bound=0.000, batch=500
# 363: loss=0.812, reward_mean=0.100, reward_bound=0.000, batch=500
# 364: loss=0.805, reward_mean=0.210, reward_bound=0.000, batch=500
# 365: loss=0.801, reward_mean=0.170, reward_bound=0.000, batch=500
# 366: loss=0.795, reward_mean=0.280, reward_bound=0.000, batch=500
# 367: loss=0.791, reward_mean=0.200, reward_bound=0.000, batch=500
# 368: loss=0.791, reward_mean=0.140, reward_bound=0.000, batch=500
# 369: loss=0.789, reward_mean=0.230, reward_bound=0.000, batch=500
# 370: loss=0.785, reward_mean=0.260, reward_bound=0.000, batch=500
# 371: loss=0.785, reward_mean=0.140, reward_bound=0.000, batch=500
# 372: loss=0.782, reward_mean=0.250, reward_bound=0.000, batch=500
# 373: loss=0.780, reward_mean=0.220, reward_bound=0.000, batch=500
# 374: loss=0.773, reward_mean=0.200, reward_bound=0.000, batch=500
# 375: loss=0.768, reward_mean=0.280, reward_bound=0.000, batch=500
# 376: loss=0.759, reward_mean=0.260, reward_bound=0.000, batch=500
# 377: loss=0.756, reward_mean=0.180, reward_bound=0.000, batch=500
# 378: loss=0.750, reward_mean=0.220, reward_bound=0.000, batch=500
# 379: loss=0.746, reward_mean=0.190, reward_bound=0.000, batch=500
# 380: loss=0.741, reward_mean=0.320, reward_bound=0.000, batch=500
# 381: loss=0.735, reward_mean=0.300, reward_bound=0.000, batch=500
# 382: loss=0.728, reward_mean=0.190, reward_bound=0.000, batch=500
# 383: loss=0.717, reward_mean=0.300, reward_bound=0.000, batch=500
# 384: loss=0.709, reward_mean=0.250, reward_bound=0.000, batch=500
# 385: loss=0.706, reward_mean=0.210, reward_bound=0.000, batch=500
# 386: loss=0.704, reward_mean=0.150, reward_bound=0.000, batch=500
# 387: loss=0.701, reward_mean=0.270, reward_bound=0.000, batch=500
# 388: loss=0.703, reward_mean=0.250, reward_bound=0.000, batch=500
# 389: loss=0.696, reward_mean=0.290, reward_bound=0.000, batch=500
# 390: loss=0.693, reward_mean=0.280, reward_bound=0.000, batch=500
# 391: loss=0.685, reward_mean=0.330, reward_bound=0.000, batch=500
# 392: loss=0.678, reward_mean=0.280, reward_bound=0.000, batch=500
# 393: loss=0.674, reward_mean=0.210, reward_bound=0.000, batch=500
# 394: loss=0.670, reward_mean=0.280, reward_bound=0.000, batch=500
# 395: loss=0.662, reward_mean=0.300, reward_bound=0.000, batch=500
# 396: loss=0.656, reward_mean=0.220, reward_bound=0.000, batch=500
# 397: loss=0.655, reward_mean=0.300, reward_bound=0.000, batch=500
# 398: loss=0.655, reward_mean=0.370, reward_bound=0.000, batch=500
# 399: loss=0.654, reward_mean=0.300, reward_bound=0.000, batch=500
# 400: loss=0.647, reward_mean=0.250, reward_bound=0.000, batch=500
# 401: loss=0.645, reward_mean=0.240, reward_bound=0.000, batch=500
# 402: loss=0.640, reward_mean=0.270, reward_bound=0.000, batch=500
# 403: loss=0.638, reward_mean=0.330, reward_bound=0.000, batch=500
# 404: loss=0.631, reward_mean=0.340, reward_bound=0.000, batch=500
# 405: loss=0.626, reward_mean=0.230, reward_bound=0.000, batch=500
# 406: loss=0.623, reward_mean=0.330, reward_bound=0.000, batch=500
# 407: loss=0.614, reward_mean=0.270, reward_bound=0.000, batch=500
# 408: loss=0.612, reward_mean=0.210, reward_bound=0.000, batch=500
# 409: loss=0.612, reward_mean=0.350, reward_bound=0.000, batch=500
# 410: loss=0.606, reward_mean=0.380, reward_bound=0.000, batch=500
# 411: loss=0.601, reward_mean=0.370, reward_bound=0.000, batch=500
# 412: loss=0.597, reward_mean=0.400, reward_bound=0.000, batch=500
# 413: loss=0.593, reward_mean=0.460, reward_bound=0.000, batch=500
# 414: loss=0.583, reward_mean=0.400, reward_bound=0.000, batch=500
# 415: loss=0.578, reward_mean=0.360, reward_bound=0.000, batch=500
# 416: loss=0.577, reward_mean=0.390, reward_bound=0.000, batch=500
# 417: loss=0.574, reward_mean=0.400, reward_bound=0.000, batch=500
# 418: loss=0.573, reward_mean=0.320, reward_bound=0.000, batch=500
# 419: loss=0.575, reward_mean=0.390, reward_bound=0.000, batch=500
# 420: loss=0.574, reward_mean=0.340, reward_bound=0.000, batch=500
# 421: loss=0.570, reward_mean=0.360, reward_bound=0.000, batch=500
# 422: loss=0.569, reward_mean=0.400, reward_bound=0.000, batch=500
# 423: loss=0.560, reward_mean=0.320, reward_bound=0.000, batch=500
# 424: loss=0.556, reward_mean=0.340, reward_bound=0.000, batch=500
# 425: loss=0.554, reward_mean=0.370, reward_bound=0.000, batch=500
# 426: loss=0.549, reward_mean=0.350, reward_bound=0.000, batch=500
# 427: loss=0.545, reward_mean=0.380, reward_bound=0.000, batch=500
# 428: loss=0.538, reward_mean=0.470, reward_bound=0.000, batch=500
# 429: loss=0.539, reward_mean=0.410, reward_bound=0.000, batch=500
# 430: loss=0.533, reward_mean=0.310, reward_bound=0.000, batch=500
# 431: loss=0.529, reward_mean=0.350, reward_bound=0.000, batch=500
# 432: loss=0.526, reward_mean=0.380, reward_bound=0.000, batch=500
# 433: loss=0.527, reward_mean=0.390, reward_bound=0.000, batch=500
# 434: loss=0.519, reward_mean=0.400, reward_bound=0.000, batch=500
# 435: loss=0.518, reward_mean=0.510, reward_bound=0.000, batch=500
# 436: loss=0.514, reward_mean=0.470, reward_bound=0.000, batch=500
# 437: loss=0.514, reward_mean=0.350, reward_bound=0.000, batch=500
# 438: loss=0.507, reward_mean=0.370, reward_bound=0.000, batch=500
# 439: loss=0.504, reward_mean=0.490, reward_bound=0.000, batch=500
# 440: loss=0.503, reward_mean=0.460, reward_bound=0.000, batch=500
# 441: loss=0.504, reward_mean=0.410, reward_bound=0.000, batch=500
# 442: loss=0.501, reward_mean=0.420, reward_bound=0.000, batch=500
# 443: loss=0.497, reward_mean=0.420, reward_bound=0.000, batch=500
# 444: loss=0.495, reward_mean=0.500, reward_bound=0.000, batch=500
# 445: loss=0.490, reward_mean=0.480, reward_bound=0.000, batch=500
# 446: loss=0.486, reward_mean=0.420, reward_bound=0.000, batch=500
# 447: loss=0.484, reward_mean=0.420, reward_bound=0.000, batch=500
# 448: loss=0.482, reward_mean=0.550, reward_bound=0.000, batch=500
# 449: loss=0.477, reward_mean=0.450, reward_bound=0.000, batch=500
# 450: loss=0.477, reward_mean=0.380, reward_bound=0.000, batch=500
# 451: loss=0.475, reward_mean=0.430, reward_bound=0.000, batch=500
# 452: loss=0.474, reward_mean=0.490, reward_bound=0.000, batch=500
# 453: loss=0.469, reward_mean=0.490, reward_bound=0.000, batch=500
# 454: loss=0.464, reward_mean=0.410, reward_bound=0.000, batch=500
# 455: loss=0.461, reward_mean=0.490, reward_bound=0.000, batch=500
# 456: loss=0.456, reward_mean=0.440, reward_bound=0.000, batch=500
# 457: loss=0.451, reward_mean=0.470, reward_bound=0.000, batch=500
# 458: loss=0.452, reward_mean=0.450, reward_bound=0.000, batch=500
# 459: loss=0.444, reward_mean=0.480, reward_bound=0.000, batch=500
# 460: loss=0.440, reward_mean=0.540, reward_bound=0.000, batch=500
# 461: loss=0.444, reward_mean=0.490, reward_bound=0.000, batch=500
# 462: loss=0.442, reward_mean=0.480, reward_bound=0.000, batch=500
# 463: loss=0.438, reward_mean=0.590, reward_bound=0.000, batch=500
# 464: loss=0.437, reward_mean=0.570, reward_bound=0.000, batch=500
# 465: loss=0.435, reward_mean=0.480, reward_bound=0.000, batch=500
# 466: loss=0.438, reward_mean=0.510, reward_bound=0.000, batch=500
# 467: loss=0.436, reward_mean=0.420, reward_bound=0.000, batch=500
# 468: loss=0.435, reward_mean=0.450, reward_bound=0.000, batch=500
# 469: loss=0.432, reward_mean=0.470, reward_bound=0.000, batch=500
# 470: loss=0.429, reward_mean=0.510, reward_bound=0.000, batch=500
# 471: loss=0.429, reward_mean=0.660, reward_bound=0.000, batch=500
# 472: loss=0.424, reward_mean=0.480, reward_bound=0.000, batch=500
# 473: loss=0.421, reward_mean=0.510, reward_bound=0.000, batch=500
# 474: loss=0.420, reward_mean=0.600, reward_bound=0.000, batch=500
# 475: loss=0.418, reward_mean=0.490, reward_bound=0.000, batch=500
# 476: loss=0.417, reward_mean=0.540, reward_bound=0.000, batch=500
# 477: loss=0.410, reward_mean=0.590, reward_bound=0.000, batch=500
# 478: loss=0.407, reward_mean=0.440, reward_bound=0.000, batch=500
# 479: loss=0.406, reward_mean=0.460, reward_bound=0.000, batch=500
# 480: loss=0.402, reward_mean=0.520, reward_bound=0.000, batch=500
# 481: loss=0.400, reward_mean=0.580, reward_bound=0.000, batch=500
# 482: loss=0.395, reward_mean=0.520, reward_bound=0.000, batch=500
# 483: loss=0.389, reward_mean=0.480, reward_bound=0.000, batch=500
# 484: loss=0.386, reward_mean=0.560, reward_bound=0.000, batch=500
# 485: loss=0.386, reward_mean=0.500, reward_bound=0.000, batch=500
# 486: loss=0.381, reward_mean=0.480, reward_bound=0.000, batch=500
# 487: loss=0.379, reward_mean=0.540, reward_bound=0.000, batch=500
# 488: loss=0.377, reward_mean=0.580, reward_bound=0.000, batch=500
# 489: loss=0.379, reward_mean=0.600, reward_bound=0.000, batch=500
# 490: loss=0.369, reward_mean=0.530, reward_bound=0.000, batch=500
# 491: loss=0.371, reward_mean=0.470, reward_bound=0.000, batch=500
# 492: loss=0.370, reward_mean=0.470, reward_bound=0.000, batch=500
# 493: loss=0.367, reward_mean=0.450, reward_bound=0.000, batch=500
# 494: loss=0.364, reward_mean=0.540, reward_bound=0.000, batch=500
# 495: loss=0.359, reward_mean=0.510, reward_bound=0.000, batch=500
# 496: loss=0.358, reward_mean=0.550, reward_bound=0.000, batch=500
# 497: loss=0.357, reward_mean=0.560, reward_bound=0.000, batch=500
# 498: loss=0.352, reward_mean=0.530, reward_bound=0.000, batch=500
# 499: loss=0.348, reward_mean=0.500, reward_bound=0.000, batch=500
# 500: loss=0.343, reward_mean=0.580, reward_bound=0.000, batch=500
# 501: loss=0.342, reward_mean=0.630, reward_bound=0.000, batch=500
# 502: loss=0.337, reward_mean=0.520, reward_bound=0.000, batch=500
# 503: loss=0.338, reward_mean=0.520, reward_bound=0.000, batch=500
# 504: loss=0.336, reward_mean=0.640, reward_bound=0.000, batch=500
# 505: loss=0.331, reward_mean=0.590, reward_bound=0.000, batch=500
# 506: loss=0.325, reward_mean=0.540, reward_bound=0.000, batch=500
# 507: loss=0.327, reward_mean=0.560, reward_bound=0.000, batch=500
# 508: loss=0.326, reward_mean=0.550, reward_bound=0.000, batch=500
# 509: loss=0.326, reward_mean=0.610, reward_bound=0.000, batch=500
# 510: loss=0.329, reward_mean=0.470, reward_bound=0.000, batch=500
# 511: loss=0.331, reward_mean=0.630, reward_bound=0.000, batch=500
# 512: loss=0.326, reward_mean=0.650, reward_bound=0.000, batch=500
# 513: loss=0.325, reward_mean=0.540, reward_bound=0.000, batch=500
# 514: loss=0.329, reward_mean=0.570, reward_bound=0.000, batch=500
# 515: loss=0.328, reward_mean=0.500, reward_bound=0.000, batch=500
# 516: loss=0.328, reward_mean=0.480, reward_bound=0.000, batch=500
# 517: loss=0.326, reward_mean=0.580, reward_bound=0.000, batch=500
# 518: loss=0.322, reward_mean=0.580, reward_bound=0.000, batch=500
# 519: loss=0.323, reward_mean=0.590, reward_bound=0.000, batch=500
# 520: loss=0.318, reward_mean=0.560, reward_bound=0.000, batch=500
# 521: loss=0.318, reward_mean=0.640, reward_bound=0.000, batch=500
# 522: loss=0.321, reward_mean=0.620, reward_bound=0.000, batch=500
# 523: loss=0.319, reward_mean=0.540, reward_bound=0.000, batch=500
# 524: loss=0.316, reward_mean=0.610, reward_bound=0.000, batch=500
# 525: loss=0.315, reward_mean=0.560, reward_bound=0.000, batch=500
# 526: loss=0.314, reward_mean=0.560, reward_bound=0.000, batch=500
# 527: loss=0.317, reward_mean=0.660, reward_bound=0.000, batch=500
# 528: loss=0.314, reward_mean=0.590, reward_bound=0.000, batch=500
# 529: loss=0.315, reward_mean=0.540, reward_bound=0.000, batch=500
# 530: loss=0.312, reward_mean=0.620, reward_bound=0.000, batch=500
# 531: loss=0.307, reward_mean=0.580, reward_bound=0.000, batch=500
# 532: loss=0.307, reward_mean=0.530, reward_bound=0.000, batch=500
# 533: loss=0.303, reward_mean=0.620, reward_bound=0.000, batch=500
# 534: loss=0.303, reward_mean=0.630, reward_bound=0.000, batch=500
# 535: loss=0.298, reward_mean=0.680, reward_bound=0.000, batch=500
# 536: loss=0.294, reward_mean=0.640, reward_bound=0.000, batch=500
# 537: loss=0.295, reward_mean=0.540, reward_bound=0.000, batch=500
# 538: loss=0.291, reward_mean=0.600, reward_bound=0.000, batch=500
# 539: loss=0.289, reward_mean=0.570, reward_bound=0.000, batch=500
# 540: loss=0.282, reward_mean=0.530, reward_bound=0.000, batch=500
# 541: loss=0.284, reward_mean=0.570, reward_bound=0.000, batch=500
# 542: loss=0.284, reward_mean=0.570, reward_bound=0.000, batch=500
# 543: loss=0.280, reward_mean=0.620, reward_bound=0.000, batch=500
# 544: loss=0.278, reward_mean=0.610, reward_bound=0.000, batch=500
# 545: loss=0.276, reward_mean=0.570, reward_bound=0.000, batch=500
# 546: loss=0.271, reward_mean=0.600, reward_bound=0.000, batch=500
# 547: loss=0.270, reward_mean=0.590, reward_bound=0.000, batch=500
# 548: loss=0.266, reward_mean=0.600, reward_bound=0.000, batch=500
# 549: loss=0.263, reward_mean=0.610, reward_bound=0.000, batch=500
# 550: loss=0.261, reward_mean=0.590, reward_bound=0.000, batch=500
# 551: loss=0.257, reward_mean=0.600, reward_bound=0.000, batch=500
# 552: loss=0.257, reward_mean=0.560, reward_bound=0.000, batch=500
# 553: loss=0.259, reward_mean=0.670, reward_bound=0.000, batch=500
# 554: loss=0.261, reward_mean=0.630, reward_bound=0.000, batch=500
# 555: loss=0.257, reward_mean=0.650, reward_bound=0.000, batch=500
# 556: loss=0.259, reward_mean=0.600, reward_bound=0.000, batch=500
# 557: loss=0.255, reward_mean=0.540, reward_bound=0.000, batch=500
# 558: loss=0.251, reward_mean=0.660, reward_bound=0.000, batch=500
# 559: loss=0.247, reward_mean=0.620, reward_bound=0.000, batch=500
# 560: loss=0.249, reward_mean=0.650, reward_bound=0.000, batch=500
# 561: loss=0.245, reward_mean=0.620, reward_bound=0.000, batch=500
# 562: loss=0.242, reward_mean=0.670, reward_bound=0.000, batch=500
# 563: loss=0.237, reward_mean=0.610, reward_bound=0.000, batch=500
# 564: loss=0.241, reward_mean=0.580, reward_bound=0.000, batch=500
# 565: loss=0.238, reward_mean=0.610, reward_bound=0.000, batch=500
# 566: loss=0.240, reward_mean=0.600, reward_bound=0.000, batch=500
# 567: loss=0.242, reward_mean=0.590, reward_bound=0.000, batch=500
# 568: loss=0.244, reward_mean=0.700, reward_bound=0.006, batch=500
# 569: loss=0.236, reward_mean=0.540, reward_bound=0.000, batch=500
# 570: loss=0.239, reward_mean=0.700, reward_bound=0.006, batch=500
# 571: loss=0.239, reward_mean=0.580, reward_bound=0.000, batch=500
# 572: loss=0.240, reward_mean=0.570, reward_bound=0.000, batch=500
# 573: loss=0.235, reward_mean=0.590, reward_bound=0.000, batch=500
# 574: loss=0.233, reward_mean=0.680, reward_bound=0.000, batch=500
# 575: loss=0.229, reward_mean=0.590, reward_bound=0.000, batch=500
# 576: loss=0.226, reward_mean=0.670, reward_bound=0.000, batch=500
# 577: loss=0.224, reward_mean=0.600, reward_bound=0.000, batch=500
# 578: loss=0.226, reward_mean=0.540, reward_bound=0.000, batch=500
# 579: loss=0.223, reward_mean=0.560, reward_bound=0.000, batch=500
# 580: loss=0.222, reward_mean=0.600, reward_bound=0.000, batch=500
# 581: loss=0.221, reward_mean=0.690, reward_bound=0.000, batch=500
# 582: loss=0.223, reward_mean=0.560, reward_bound=0.000, batch=500
# 583: loss=0.221, reward_mean=0.660, reward_bound=0.000, batch=500
# 584: loss=0.225, reward_mean=0.590, reward_bound=0.000, batch=500
# 585: loss=0.227, reward_mean=0.710, reward_bound=0.006, batch=500
# 586: loss=0.228, reward_mean=0.610, reward_bound=0.000, batch=500
# 587: loss=0.227, reward_mean=0.570, reward_bound=0.000, batch=500
# 588: loss=0.225, reward_mean=0.670, reward_bound=0.000, batch=500
# 589: loss=0.221, reward_mean=0.560, reward_bound=0.000, batch=500
# 590: loss=0.224, reward_mean=0.570, reward_bound=0.000, batch=500
# 591: loss=0.219, reward_mean=0.550, reward_bound=0.000, batch=500
# 592: loss=0.220, reward_mean=0.620, reward_bound=0.000, batch=500
# 593: loss=0.216, reward_mean=0.680, reward_bound=0.000, batch=500
# 594: loss=0.216, reward_mean=0.620, reward_bound=0.000, batch=500
# 595: loss=0.214, reward_mean=0.650, reward_bound=0.000, batch=500
# 596: loss=0.213, reward_mean=0.610, reward_bound=0.000, batch=500
# 597: loss=0.215, reward_mean=0.660, reward_bound=0.000, batch=500
# 598: loss=0.212, reward_mean=0.700, reward_bound=0.006, batch=500
# 599: loss=0.206, reward_mean=0.640, reward_bound=0.000, batch=500
# 600: loss=0.201, reward_mean=0.690, reward_bound=0.000, batch=500
# 601: loss=0.204, reward_mean=0.710, reward_bound=0.006, batch=500
# 602: loss=0.204, reward_mean=0.630, reward_bound=0.000, batch=500
# 603: loss=0.201, reward_mean=0.590, reward_bound=0.000, batch=500
# 604: loss=0.196, reward_mean=0.700, reward_bound=0.006, batch=500
# 605: loss=0.193, reward_mean=0.700, reward_bound=0.006, batch=500
# 606: loss=0.192, reward_mean=0.730, reward_bound=0.009, batch=500
# 607: loss=0.196, reward_mean=0.670, reward_bound=0.000, batch=500
# 608: loss=0.192, reward_mean=0.680, reward_bound=0.000, batch=500
# 609: loss=0.189, reward_mean=0.620, reward_bound=0.000, batch=500
# 610: loss=0.184, reward_mean=0.630, reward_bound=0.000, batch=500
# 611: loss=0.180, reward_mean=0.680, reward_bound=0.000, batch=500
# 612: loss=0.178, reward_mean=0.640, reward_bound=0.000, batch=500
# 613: loss=0.178, reward_mean=0.650, reward_bound=0.000, batch=500
# 614: loss=0.171, reward_mean=0.650, reward_bound=0.000, batch=500
# 615: loss=0.171, reward_mean=0.650, reward_bound=0.000, batch=500
# 616: loss=0.164, reward_mean=0.620, reward_bound=0.000, batch=500
# 617: loss=0.168, reward_mean=0.710, reward_bound=0.006, batch=500
# 618: loss=0.168, reward_mean=0.640, reward_bound=0.000, batch=500
# 619: loss=0.167, reward_mean=0.600, reward_bound=0.000, batch=500
# 620: loss=0.167, reward_mean=0.630, reward_bound=0.000, batch=500
# 621: loss=0.168, reward_mean=0.690, reward_bound=0.000, batch=500
# 622: loss=0.167, reward_mean=0.690, reward_bound=0.000, batch=500
# 623: loss=0.166, reward_mean=0.680, reward_bound=0.000, batch=500
# 624: loss=0.164, reward_mean=0.710, reward_bound=0.006, batch=500
# 625: loss=0.164, reward_mean=0.700, reward_bound=0.006, batch=500
# 626: loss=0.160, reward_mean=0.720, reward_bound=0.007, batch=500
# 627: loss=0.155, reward_mean=0.710, reward_bound=0.007, batch=500
# 628: loss=0.151, reward_mean=0.650, reward_bound=0.000, batch=500
# 629: loss=0.150, reward_mean=0.720, reward_bound=0.007, batch=500
# 630: loss=0.149, reward_mean=0.650, reward_bound=0.000, batch=500
# 631: loss=0.148, reward_mean=0.620, reward_bound=0.000, batch=500
# 632: loss=0.145, reward_mean=0.590, reward_bound=0.000, batch=500
# 633: loss=0.145, reward_mean=0.710, reward_bound=0.007, batch=500
# 634: loss=0.144, reward_mean=0.660, reward_bound=0.000, batch=500
# 635: loss=0.148, reward_mean=0.710, reward_bound=0.008, batch=500
# 636: loss=0.144, reward_mean=0.780, reward_bound=0.009, batch=500
# 637: loss=0.143, reward_mean=0.620, reward_bound=0.000, batch=500
# 638: loss=0.140, reward_mean=0.680, reward_bound=0.000, batch=500
# 639: loss=0.138, reward_mean=0.700, reward_bound=0.007, batch=500
# 640: loss=0.138, reward_mean=0.690, reward_bound=0.000, batch=500
# 641: loss=0.137, reward_mean=0.670, reward_bound=0.000, batch=500
# 642: loss=0.130, reward_mean=0.730, reward_bound=0.007, batch=500
# 643: loss=0.124, reward_mean=0.780, reward_bound=0.011, batch=500
# 644: loss=0.124, reward_mean=0.610, reward_bound=0.000, batch=500
# 645: loss=0.122, reward_mean=0.690, reward_bound=0.000, batch=500
# 646: loss=0.120, reward_mean=0.660, reward_bound=0.000, batch=500
# 647: loss=0.117, reward_mean=0.690, reward_bound=0.000, batch=500
# 648: loss=0.119, reward_mean=0.660, reward_bound=0.000, batch=500
# 649: loss=0.116, reward_mean=0.630, reward_bound=0.000, batch=500
# 650: loss=0.120, reward_mean=0.730, reward_bound=0.007, batch=500
# 651: loss=0.120, reward_mean=0.700, reward_bound=0.007, batch=500
# 652: loss=0.121, reward_mean=0.660, reward_bound=0.000, batch=500
# 653: loss=0.119, reward_mean=0.610, reward_bound=0.000, batch=500
# 654: loss=0.119, reward_mean=0.680, reward_bound=0.000, batch=500
# 655: loss=0.120, reward_mean=0.710, reward_bound=0.007, batch=500
# 656: loss=0.119, reward_mean=0.670, reward_bound=0.000, batch=500
# 657: loss=0.117, reward_mean=0.710, reward_bound=0.007, batch=500
# 658: loss=0.117, reward_mean=0.670, reward_bound=0.000, batch=500
# 659: loss=0.114, reward_mean=0.690, reward_bound=0.000, batch=500
# 660: loss=0.112, reward_mean=0.670, reward_bound=0.000, batch=500
# 661: loss=0.114, reward_mean=0.680, reward_bound=0.000, batch=500
# 662: loss=0.112, reward_mean=0.680, reward_bound=0.000, batch=500
# 663: loss=0.113, reward_mean=0.730, reward_bound=0.007, batch=500
# 664: loss=0.111, reward_mean=0.730, reward_bound=0.008, batch=500
# 665: loss=0.107, reward_mean=0.620, reward_bound=0.000, batch=500
# 666: loss=0.105, reward_mean=0.670, reward_bound=0.000, batch=500
# 667: loss=0.102, reward_mean=0.710, reward_bound=0.008, batch=500
# 668: loss=0.105, reward_mean=0.710, reward_bound=0.008, batch=500
# 669: loss=0.102, reward_mean=0.590, reward_bound=0.000, batch=500
# 670: loss=0.101, reward_mean=0.700, reward_bound=0.006, batch=500
# 671: loss=0.099, reward_mean=0.670, reward_bound=0.000, batch=500
# 672: loss=0.100, reward_mean=0.690, reward_bound=0.000, batch=500
# 673: loss=0.105, reward_mean=0.730, reward_bound=0.008, batch=500
# 674: loss=0.104, reward_mean=0.540, reward_bound=0.000, batch=500
# 675: loss=0.101, reward_mean=0.740, reward_bound=0.008, batch=500
# 676: loss=0.099, reward_mean=0.700, reward_bound=0.007, batch=500
# 677: loss=0.098, reward_mean=0.770, reward_bound=0.010, batch=500
# 678: loss=0.097, reward_mean=0.660, reward_bound=0.000, batch=500
# 679: loss=0.100, reward_mean=0.720, reward_bound=0.010, batch=500
# 680: loss=0.095, reward_mean=0.740, reward_bound=0.011, batch=500
# 681: loss=0.091, reward_mean=0.610, reward_bound=0.000, batch=500
# 682: loss=0.090, reward_mean=0.690, reward_bound=0.000, batch=500
# 683: loss=0.092, reward_mean=0.670, reward_bound=0.000, batch=500
# 684: loss=0.093, reward_mean=0.660, reward_bound=0.000, batch=500
# 685: loss=0.092, reward_mean=0.700, reward_bound=0.006, batch=500
# 686: loss=0.095, reward_mean=0.710, reward_bound=0.006, batch=500
# 687: loss=0.092, reward_mean=0.640, reward_bound=0.000, batch=500
# 688: loss=0.091, reward_mean=0.760, reward_bound=0.009, batch=500
# 689: loss=0.091, reward_mean=0.710, reward_bound=0.009, batch=500
# 690: loss=0.092, reward_mean=0.690, reward_bound=0.000, batch=500
# 691: loss=0.090, reward_mean=0.730, reward_bound=0.010, batch=500
# 692: loss=0.089, reward_mean=0.720, reward_bound=0.010, batch=500
# 693: loss=0.087, reward_mean=0.690, reward_bound=0.000, batch=500
# 694: loss=0.086, reward_mean=0.710, reward_bound=0.008, batch=500
# 695: loss=0.086, reward_mean=0.660, reward_bound=0.000, batch=500
# 696: loss=0.087, reward_mean=0.620, reward_bound=0.000, batch=500
# 697: loss=0.087, reward_mean=0.660, reward_bound=0.000, batch=500
# 698: loss=0.088, reward_mean=0.700, reward_bound=0.006, batch=500
# 699: loss=0.089, reward_mean=0.730, reward_bound=0.008, batch=500
# 700: loss=0.088, reward_mean=0.710, reward_bound=0.007, batch=500
# 701: loss=0.089, reward_mean=0.700, reward_bound=0.007, batch=500
# 702: loss=0.090, reward_mean=0.570, reward_bound=0.000, batch=500
# 703: loss=0.092, reward_mean=0.680, reward_bound=0.000, batch=500
# 704: loss=0.091, reward_mean=0.790, reward_bound=0.010, batch=500
# 705: loss=0.091, reward_mean=0.670, reward_bound=0.000, batch=500
# 706: loss=0.088, reward_mean=0.630, reward_bound=0.000, batch=500
# 707: loss=0.086, reward_mean=0.680, reward_bound=0.000, batch=500
# 708: loss=0.086, reward_mean=0.700, reward_bound=0.007, batch=500
# 709: loss=0.084, reward_mean=0.710, reward_bound=0.007, batch=500
# 710: loss=0.085, reward_mean=0.640, reward_bound=0.000, batch=500
# 711: loss=0.082, reward_mean=0.640, reward_bound=0.000, batch=500
# 712: loss=0.082, reward_mean=0.710, reward_bound=0.007, batch=500
# 713: loss=0.083, reward_mean=0.740, reward_bound=0.007, batch=500
# 714: loss=0.085, reward_mean=0.730, reward_bound=0.007, batch=500
# 715: loss=0.084, reward_mean=0.630, reward_bound=0.000, batch=500
# 716: loss=0.082, reward_mean=0.670, reward_bound=0.000, batch=500
# 717: loss=0.083, reward_mean=0.730, reward_bound=0.007, batch=500
# 718: loss=0.083, reward_mean=0.650, reward_bound=0.000, batch=500
# 719: loss=0.085, reward_mean=0.680, reward_bound=0.000, batch=500
# 720: loss=0.084, reward_mean=0.690, reward_bound=0.000, batch=500
# 721: loss=0.085, reward_mean=0.700, reward_bound=0.006, batch=500
# 722: loss=0.084, reward_mean=0.640, reward_bound=0.000, batch=500
# 723: loss=0.085, reward_mean=0.730, reward_bound=0.007, batch=500
# 724: loss=0.086, reward_mean=0.680, reward_bound=0.000, batch=500
# 725: loss=0.085, reward_mean=0.710, reward_bound=0.006, batch=500
# 726: loss=0.081, reward_mean=0.730, reward_bound=0.008, batch=500
# 727: loss=0.080, reward_mean=0.610, reward_bound=0.000, batch=500
# 728: loss=0.079, reward_mean=0.640, reward_bound=0.000, batch=500
# 729: loss=0.074, reward_mean=0.750, reward_bound=0.009, batch=500
# 730: loss=0.075, reward_mean=0.680, reward_bound=0.000, batch=500
# 731: loss=0.073, reward_mean=0.700, reward_bound=0.006, batch=500
# 732: loss=0.071, reward_mean=0.670, reward_bound=0.000, batch=500
# 733: loss=0.073, reward_mean=0.760, reward_bound=0.011, batch=500
# 734: loss=0.072, reward_mean=0.630, reward_bound=0.000, batch=500
# 735: loss=0.074, reward_mean=0.600, reward_bound=0.000, batch=500
# 736: loss=0.073, reward_mean=0.600, reward_bound=0.000, batch=500
# 737: loss=0.077, reward_mean=0.630, reward_bound=0.000, batch=500
# 738: loss=0.078, reward_mean=0.750, reward_bound=0.011, batch=500
# 739: loss=0.078, reward_mean=0.760, reward_bound=0.013, batch=500
# 740: loss=0.079, reward_mean=0.680, reward_bound=0.000, batch=500
# 741: loss=0.077, reward_mean=0.760, reward_bound=0.013, batch=500
# 742: loss=0.078, reward_mean=0.620, reward_bound=0.000, batch=500
# 743: loss=0.079, reward_mean=0.710, reward_bound=0.009, batch=500
# 744: loss=0.077, reward_mean=0.670, reward_bound=0.000, batch=500
# 745: loss=0.077, reward_mean=0.590, reward_bound=0.000, batch=500
# 746: loss=0.073, reward_mean=0.770, reward_bound=0.010, batch=500
# 747: loss=0.072, reward_mean=0.690, reward_bound=0.000, batch=500
# 748: loss=0.068, reward_mean=0.650, reward_bound=0.000, batch=500
# 749: loss=0.070, reward_mean=0.750, reward_bound=0.010, batch=500
# 750: loss=0.070, reward_mean=0.690, reward_bound=0.000, batch=500
# 751: loss=0.071, reward_mean=0.740, reward_bound=0.010, batch=500
# 752: loss=0.071, reward_mean=0.720, reward_bound=0.008, batch=500
# 753: loss=0.067, reward_mean=0.650, reward_bound=0.000, batch=500
# 754: loss=0.068, reward_mean=0.670, reward_bound=0.000, batch=500
# 755: loss=0.069, reward_mean=0.720, reward_bound=0.009, batch=500
# 756: loss=0.071, reward_mean=0.800, reward_bound=0.012, batch=500
# 757: loss=0.067, reward_mean=0.710, reward_bound=0.011, batch=500
# 758: loss=0.068, reward_mean=0.700, reward_bound=0.008, batch=500
# 759: loss=0.069, reward_mean=0.650, reward_bound=0.000, batch=500
# 760: loss=0.068, reward_mean=0.780, reward_bound=0.015, batch=500
# 761: loss=0.072, reward_mean=0.750, reward_bound=0.015, batch=500
# 762: loss=0.074, reward_mean=0.750, reward_bound=0.013, batch=500
# 763: loss=0.074, reward_mean=0.700, reward_bound=0.007, batch=500
# 764: loss=0.073, reward_mean=0.700, reward_bound=0.007, batch=500
# 765: loss=0.076, reward_mean=0.720, reward_bound=0.007, batch=500
# 766: loss=0.076, reward_mean=0.680, reward_bound=0.000, batch=500
# 767: loss=0.072, reward_mean=0.730, reward_bound=0.008, batch=500
# 768: loss=0.069, reward_mean=0.690, reward_bound=0.000, batch=500
# 769: loss=0.066, reward_mean=0.700, reward_bound=0.007, batch=500
# 770: loss=0.065, reward_mean=0.730, reward_bound=0.008, batch=500
# 771: loss=0.064, reward_mean=0.700, reward_bound=0.008, batch=500
# 772: loss=0.065, reward_mean=0.650, reward_bound=0.000, batch=500
# 773: loss=0.064, reward_mean=0.720, reward_bound=0.008, batch=500
# 774: loss=0.066, reward_mean=0.650, reward_bound=0.000, batch=500
# 775: loss=0.067, reward_mean=0.650, reward_bound=0.000, batch=500
# 776: loss=0.068, reward_mean=0.690, reward_bound=0.000, batch=500
# 777: loss=0.068, reward_mean=0.750, reward_bound=0.008, batch=500
# 778: loss=0.069, reward_mean=0.780, reward_bound=0.011, batch=500
# 779: loss=0.069, reward_mean=0.730, reward_bound=0.008, batch=500
# 780: loss=0.071, reward_mean=0.780, reward_bound=0.013, batch=500
# 781: loss=0.070, reward_mean=0.690, reward_bound=0.000, batch=500
# 782: loss=0.065, reward_mean=0.650, reward_bound=0.000, batch=500
# 783: loss=0.065, reward_mean=0.670, reward_bound=0.000, batch=500
# 784: loss=0.062, reward_mean=0.740, reward_bound=0.008, batch=500
# 785: loss=0.065, reward_mean=0.770, reward_bound=0.011, batch=500
# 786: loss=0.067, reward_mean=0.640, reward_bound=0.000, batch=500
# 787: loss=0.068, reward_mean=0.660, reward_bound=0.000, batch=500
# 788: loss=0.069, reward_mean=0.700, reward_bound=0.007, batch=500
# 789: loss=0.067, reward_mean=0.740, reward_bound=0.009, batch=500
# 790: loss=0.070, reward_mean=0.730, reward_bound=0.012, batch=500
# 791: loss=0.070, reward_mean=0.740, reward_bound=0.013, batch=500
# 792: loss=0.071, reward_mean=0.710, reward_bound=0.007, batch=500
# 793: loss=0.071, reward_mean=0.710, reward_bound=0.006, batch=500
# 794: loss=0.070, reward_mean=0.750, reward_bound=0.013, batch=500
# 795: loss=0.069, reward_mean=0.730, reward_bound=0.009, batch=500
# 796: loss=0.068, reward_mean=0.770, reward_bound=0.013, batch=500
# 797: loss=0.067, reward_mean=0.720, reward_bound=0.008, batch=500
# 798: loss=0.065, reward_mean=0.730, reward_bound=0.010, batch=500
# 799: loss=0.062, reward_mean=0.740, reward_bound=0.013, batch=500
# 800: loss=0.063, reward_mean=0.770, reward_bound=0.017, batch=500
# 801: loss=0.063, reward_mean=0.680, reward_bound=0.000, batch=500
# 802: loss=0.064, reward_mean=0.670, reward_bound=0.000, batch=500
# 803: loss=0.061, reward_mean=0.720, reward_bound=0.007, batch=500
# 804: loss=0.062, reward_mean=0.790, reward_bound=0.010, batch=500
# 805: loss=0.062, reward_mean=0.710, reward_bound=0.006, batch=500
# 806: loss=0.063, reward_mean=0.670, reward_bound=0.000, batch=500
# 807: loss=0.063, reward_mean=0.760, reward_bound=0.011, batch=500
# 808: loss=0.061, reward_mean=0.720, reward_bound=0.012, batch=500
# 809: loss=0.057, reward_mean=0.770, reward_bound=0.012, batch=500
# 810: loss=0.057, reward_mean=0.700, reward_bound=0.006, batch=500
# 811: loss=0.056, reward_mean=0.730, reward_bound=0.007, batch=500
# 812: loss=0.054, reward_mean=0.730, reward_bound=0.007, batch=500
# 813: loss=0.053, reward_mean=0.650, reward_bound=0.000, batch=500
# 814: loss=0.053, reward_mean=0.720, reward_bound=0.008, batch=500
# 815: loss=0.054, reward_mean=0.630, reward_bound=0.000, batch=500
# 816: loss=0.057, reward_mean=0.740, reward_bound=0.009, batch=500
# 817: loss=0.057, reward_mean=0.680, reward_bound=0.000, batch=500
# 818: loss=0.055, reward_mean=0.790, reward_bound=0.013, batch=500
# 819: loss=0.053, reward_mean=0.630, reward_bound=0.000, batch=500
# 820: loss=0.054, reward_mean=0.790, reward_bound=0.017, batch=500
# 821: loss=0.054, reward_mean=0.760, reward_bound=0.019, batch=500
# 822: loss=0.052, reward_mean=0.700, reward_bound=0.007, batch=500
# 823: loss=0.052, reward_mean=0.650, reward_bound=0.000, batch=500
# 824: loss=0.049, reward_mean=0.720, reward_bound=0.008, batch=500
# 825: loss=0.051, reward_mean=0.740, reward_bound=0.010, batch=500
# 826: loss=0.054, reward_mean=0.710, reward_bound=0.010, batch=500
# 827: loss=0.054, reward_mean=0.710, reward_bound=0.008, batch=500
# 828: loss=0.057, reward_mean=0.640, reward_bound=0.000, batch=500
# 829: loss=0.059, reward_mean=0.740, reward_bound=0.010, batch=500
# 830: loss=0.059, reward_mean=0.720, reward_bound=0.012, batch=500
# 831: loss=0.058, reward_mean=0.660, reward_bound=0.000, batch=500
# 832: loss=0.058, reward_mean=0.670, reward_bound=0.000, batch=500
# 833: loss=0.057, reward_mean=0.720, reward_bound=0.007, batch=500
# 834: loss=0.057, reward_mean=0.710, reward_bound=0.007, batch=500
# 835: loss=0.058, reward_mean=0.640, reward_bound=0.000, batch=500
# 836: loss=0.057, reward_mean=0.710, reward_bound=0.007, batch=500
# 837: loss=0.054, reward_mean=0.790, reward_bound=0.010, batch=500
# 838: loss=0.052, reward_mean=0.730, reward_bound=0.010, batch=500
# 839: loss=0.051, reward_mean=0.720, reward_bound=0.012, batch=500
# 840: loss=0.052, reward_mean=0.750, reward_bound=0.012, batch=500
# 841: loss=0.051, reward_mean=0.680, reward_bound=0.000, batch=500
# 842: loss=0.052, reward_mean=0.710, reward_bound=0.007, batch=500
# 843: loss=0.054, reward_mean=0.720, reward_bound=0.009, batch=500
# 844: loss=0.052, reward_mean=0.680, reward_bound=0.000, batch=500
# 845: loss=0.052, reward_mean=0.740, reward_bound=0.010, batch=500
# 846: loss=0.051, reward_mean=0.760, reward_bound=0.012, batch=500
# 847: loss=0.052, reward_mean=0.690, reward_bound=0.000, batch=500
# 848: loss=0.051, reward_mean=0.740, reward_bound=0.012, batch=500
# 849: loss=0.053, reward_mean=0.680, reward_bound=0.000, batch=500
# 850: loss=0.052, reward_mean=0.770, reward_bound=0.013, batch=500
# 851: loss=0.049, reward_mean=0.720, reward_bound=0.013, batch=500
# 852: loss=0.050, reward_mean=0.790, reward_bound=0.015, batch=500
# 853: loss=0.049, reward_mean=0.700, reward_bound=0.007, batch=500
# 854: loss=0.050, reward_mean=0.670, reward_bound=0.000, batch=500
# 855: loss=0.052, reward_mean=0.780, reward_bound=0.013, batch=500
# 856: loss=0.053, reward_mean=0.680, reward_bound=0.000, batch=500
# 857: loss=0.052, reward_mean=0.670, reward_bound=0.000, batch=500
# 858: loss=0.050, reward_mean=0.610, reward_bound=0.000, batch=500
# 859: loss=0.049, reward_mean=0.700, reward_bound=0.007, batch=500
# 860: loss=0.049, reward_mean=0.720, reward_bound=0.008, batch=500
# 861: loss=0.049, reward_mean=0.670, reward_bound=0.000, batch=500
# 862: loss=0.048, reward_mean=0.650, reward_bound=0.000, batch=500
# 863: loss=0.049, reward_mean=0.700, reward_bound=0.006, batch=500
# 864: loss=0.050, reward_mean=0.700, reward_bound=0.006, batch=500
# 865: loss=0.051, reward_mean=0.660, reward_bound=0.000, batch=500
# 866: loss=0.051, reward_mean=0.750, reward_bound=0.008, batch=500
# 867: loss=0.052, reward_mean=0.690, reward_bound=0.000, batch=500
# 868: loss=0.051, reward_mean=0.760, reward_bound=0.008, batch=500
# 869: loss=0.050, reward_mean=0.740, reward_bound=0.010, batch=500
# 870: loss=0.048, reward_mean=0.680, reward_bound=0.000, batch=500
# 871: loss=0.048, reward_mean=0.650, reward_bound=0.000, batch=500
# 872: loss=0.047, reward_mean=0.690, reward_bound=0.000, batch=500
# 873: loss=0.048, reward_mean=0.630, reward_bound=0.000, batch=500
# 874: loss=0.047, reward_mean=0.700, reward_bound=0.006, batch=500
# 875: loss=0.048, reward_mean=0.770, reward_bound=0.007, batch=500
# 876: loss=0.047, reward_mean=0.780, reward_bound=0.009, batch=500
# 877: loss=0.048, reward_mean=0.630, reward_bound=0.000, batch=500
# 878: loss=0.049, reward_mean=0.610, reward_bound=0.000, batch=500
# 879: loss=0.047, reward_mean=0.670, reward_bound=0.000, batch=500
# 880: loss=0.048, reward_mean=0.750, reward_bound=0.011, batch=500
# 881: loss=0.044, reward_mean=0.800, reward_bound=0.015, batch=500
# 882: loss=0.043, reward_mean=0.770, reward_bound=0.015, batch=500
# 883: loss=0.044, reward_mean=0.700, reward_bound=0.006, batch=500
# 884: loss=0.042, reward_mean=0.690, reward_bound=0.000, batch=500
# 885: loss=0.042, reward_mean=0.680, reward_bound=0.000, batch=500
# 886: loss=0.042, reward_mean=0.760, reward_bound=0.010, batch=500
# 887: loss=0.042, reward_mean=0.680, reward_bound=0.000, batch=500
# 888: loss=0.042, reward_mean=0.750, reward_bound=0.012, batch=500
# 889: loss=0.042, reward_mean=0.650, reward_bound=0.000, batch=500
# 890: loss=0.046, reward_mean=0.730, reward_bound=0.012, batch=500
# 891: loss=0.046, reward_mean=0.750, reward_bound=0.012, batch=500
# 892: loss=0.045, reward_mean=0.700, reward_bound=0.011, batch=500
# 893: loss=0.045, reward_mean=0.650, reward_bound=0.000, batch=500
# 894: loss=0.042, reward_mean=0.760, reward_bound=0.010, batch=500
# 895: loss=0.039, reward_mean=0.800, reward_bound=0.013, batch=500
# 896: loss=0.038, reward_mean=0.720, reward_bound=0.009, batch=500
# 897: loss=0.038, reward_mean=0.710, reward_bound=0.008, batch=500
# 898: loss=0.036, reward_mean=0.650, reward_bound=0.000, batch=500
# 899: loss=0.034, reward_mean=0.720, reward_bound=0.009, batch=500
# 900: loss=0.035, reward_mean=0.750, reward_bound=0.009, batch=500
# 901: loss=0.034, reward_mean=0.640, reward_bound=0.000, batch=500
# 902: loss=0.034, reward_mean=0.670, reward_bound=0.000, batch=500
# 903: loss=0.036, reward_mean=0.750, reward_bound=0.009, batch=500
# 904: loss=0.036, reward_mean=0.800, reward_bound=0.012, batch=500
# 905: loss=0.039, reward_mean=0.680, reward_bound=0.000, batch=500
# 906: loss=0.038, reward_mean=0.690, reward_bound=0.000, batch=500
# 907: loss=0.037, reward_mean=0.660, reward_bound=0.000, batch=500
# 908: loss=0.038, reward_mean=0.700, reward_bound=0.006, batch=500
# 909: loss=0.037, reward_mean=0.760, reward_bound=0.009, batch=500
# 910: loss=0.038, reward_mean=0.720, reward_bound=0.011, batch=500
# 911: loss=0.040, reward_mean=0.760, reward_bound=0.013, batch=500
# 912: loss=0.039, reward_mean=0.840, reward_bound=0.015, batch=500
# Solved!

# %% [markdown]
# To view Tensorboard:
#
# $ ``cd  cd .\OneDrive\Python\DeepRL\DeepRL\``
#
# $ `` tensorboard --logdir .\runs --host localhost``
#
# ![](img/Tensorboard-fig-2.png)
#
# ### Applying the trained model
# At this point after we trained neural net, we can play the game and measure our success:

# %%
nGames = 1000 #number of games/episodes to play

obs = env.reset() #resting the environment - return a list of 4 observed numbers
sm = nn.Softmax(dim=1) #creating a softmax function 
success = 0 #success counter
for game in (range(0,nGames)):
    while True:
        obs_v = torch.FloatTensor([obs]) #create a float tensor from the new observation - 1x16 tensor with theobserved loction of the tensor
        #print('obs=',obs)
        act_probs_v = sm(net(obs_v)) # execute the nn on the new observation and apply softmax on it
        act_probs = act_probs_v.data.numpy()[0] #Obtain the action probablities by accessing the output tensor data filed and create a numpy array from it
        #print('act_probs=', act_probs)
        action = np.random.choice(len(act_probs), p=act_probs) #select the action (number btwn 0 - n) by sampling from the return probablities
        #print('action=',action)
        next_obs, reward, game_over, _ = env.step(action) #making the next step on the enviroment with the selected action
        if game_over: 
            #print('Game ',game, 'over - reward=', reward)
            if reward == 1: #succesful game 
                success += 1;
            next_obs = env.reset() #resting the environment for a new game
            break
        obs = next_obs #assign next_obs to obs
print('Successful games ratio =', success/nGames)
# Out:
# Successful games ratio = 0.697
